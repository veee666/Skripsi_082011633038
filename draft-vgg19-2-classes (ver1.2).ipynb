# %%
import cv2
import datetime
import os
import pandas as pd
import numpy as np
import shutil
import seaborn as sns
import random
import math
import tensorflow as tf
import sys
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from matplotlib import pyplot as plt
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from keras import applications, regularizers
from keras.applications.vgg19 import VGG19
from keras.applications.mobilenet import MobileNet
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, LearningRateScheduler
from keras.models import Model, Sequential, load_model
from keras.layers import Conv2D, Dense, Flatten, MaxPooling2D, Dropout, Activation, BatchNormalization
from keras.optimizers import Adam, RMSprop, SGD
from keras.initializers import he_normal
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from tqdm import tqdm
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Import image description data
df_data = pd.read_csv("/kaggle/input/ocular-disease-recognition-odir5k/full_df.csv")

df_data2 = df_data.iloc[:, 1:7]

# "myopia", "hypertensive", "diabetic", "age-related macular degeneration", "glaucoma",

# Daftar kata kunci yang ingin dicari
keywords = ["cataract", "normal"]  # Ganti dengan kata kunci yang diinginkan

# Fungsi untuk mencari kata kunci dalam DataFrame
def search_keywords(data_frame, keyword):
    left_diagnosis = data_frame[data_frame['Left-Diagnostic Keywords'].str.contains(keyword)]
    right_diagnosis = data_frame[data_frame['Right-Diagnostic Keywords'].str.contains(keyword)]
    combined = pd.concat((left_diagnosis['Left-Fundus'], right_diagnosis['Right-Fundus']))

    df_result = pd.DataFrame(combined, columns=['fundus'])
    df_result['class'] = keyword
    return df_result

# Mencari semua kata kunci dalam satu langkah
dfs = []
for keyword in keywords:
    df_keyword = search_keywords(df_data2, keyword)
    dfs.append(df_keyword)

# Menggabungkan hasil pencarian kata kunci
result_df = pd.concat(dfs)

# Menyimpan DataFrame dalam file XLSX
result_df.to_excel('merge.xlsx', index=False)

# Convert DataFrame ke bentuk JSON
data_list = result_df.to_dict(orient='records')


def resize_image(img, target_size):
    # Mendapatkan dimensi gambar asli
    original_height, original_width = img.shape[:2]

    # Mendapatkan dimensi target
    target_width, target_height = target_size

    # Menghitung rasio skala lebar dan tinggi
    width_ratio = target_width / original_width
    height_ratio = target_height / original_height

    # Menentukan rasio skala yang akan digunakan untuk resizing
    scale_ratio = min(width_ratio, height_ratio)

    # Menghitung ukuran baru setelah penskalaan
    new_width = int(original_width * scale_ratio)
    new_height = int(original_height * scale_ratio)

    # Melakukan resizing gambar dengan opsi interporasi yang baik
    resized_img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_AREA)

    # Membuat latar belakang gambar dengan ukuran target
    background = (0, 0, 0)  # Hitam

    # Membuat gambar dengan ukuran target yang tepat
    top_padding = (target_height - new_height) // 2
    bottom_padding = target_height - new_height - top_padding
    left_padding = (target_width - new_width) // 2
    right_padding = target_width - new_width - left_padding

    # Menggunakan padding untuk membuat latar belakang dengan ukuran target
    background_img = cv2.copyMakeBorder(resized_img, top_padding, bottom_padding, left_padding, right_padding, cv2.BORDER_CONSTANT, value=background)

    return background_img

## Read image and preprocessing
def process_images(input_folder, output_folder):
    # Membuat folder output jika belum ada
    os.makedirs(output_folder, exist_ok=True)

    # Loop melalui semua file dalam folder
    for filename in os.listdir(output_folder):

        os.remove(os.path.join(output_folder, filename))

    print("Isi file dalam folder output telah dihapus.")

    # Mendapatkan daftar file gambar di dalam folder input
    image_files = [file for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

    # Loop melalui daftar file gambar
    for image_file in tqdm(image_files, desc="Processing images"):
        # Membaca gambar
        image_path = os.path.join(input_folder, image_file)
        image = cv2.imread(image_path)

        # Ubah ukuran gambar
        target_size = (224, 224)  # Ubah ukuran sesuai kebutuhan Anda
        resized_image = cv2.resize(image, target_size)
#         resized_image = resize_image(image, target_size)
        # cropped_image = crop_padding(resized_image)

        # Ubah format warna gambar
        colored_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

        # Simpan gambar ke folder output dengan nama yang sama
        output_path = os.path.join(output_folder, image_file)
        cv2.imwrite(output_path, colored_image)

    print("Proses selesai. Gambar-gambar telah disimpan di folder output.")

# Preprocessing gambar
input_folder = "/kaggle/input/ocular-disease-recognition-odir5k/ODIR-5K/ODIR-5K/Training Images"
output_folder = "/kaggle/working/output_preprocessing/"

process_images(input_folder, output_folder)
# Out:
# Isi file dalam folder output telah dihapus.
# Processing images: 100%|██████████| 7000/7000 [05:55<00:00, 19.69it/s]
# Proses selesai. Gambar-gambar telah disimpan di folder output.

# %%
# tracked_images = []
# for df in tqdm(data_list, desc="Tracking image label"):
#     fundus = df['fundus']
#     file_path = os.path.join(output_folder, fundus)
#     image = cv2.imread(file_path)
#     if image is not None:
#         label = df['class']
#         tracked_images.append((image, label))

# # Memisahkan gambar dan label menjadi dua array terpisah
# tracked_images_array = np.array([x[0] for x in tracked_images])
# labels_array = np.array([x[1] for x in tracked_images])

# # Fungsi untuk menyimpan gambar ke dalam folder
# def save_images(images, labels, output_folder):
#     for i, (image, label) in enumerate(zip(images, labels)):
#         fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
#         file_path = os.path.join(output_folder, fundus)
#         cv2.imwrite(file_path, image)

# # Fungsi untuk melakukan histogram equalization pada gambar
# def histogram_equalization(image):
#     # Ubah gambar ke skala keabuan jika belum
#     if len(image.shape) > 2:
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     else:
#         gray = image

#     # Lakukan histogram equalization
#     equalized = cv2.equalizeHist(gray)

#     equalized = cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

#     return equalized

# # Fungsi untuk melakukan histogram equalization pada gambar
# def clahe(image):
#     # Ubah gambar ke skala keabuan jika belum
#     if len(image.shape) > 2:
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     else:
#         gray = image

#     clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
#     enhanced_image = clahe.apply(gray)

#     enhanced_image = cv2.cvtColor(enhanced_image, cv2.COLOR_GRAY2BGR)
#     return image

# # Folder untuk menyimpan gambar-gambar hasil konversi
# output_folder_equalized = "/kaggle/working/output_equalized/"
# output_folder_clahe = "/kaggle/working/output_clahe/"

# # Membuat folder output jika belum ada
# os.makedirs(output_folder_equalized, exist_ok=True)
# os.makedirs(output_folder_clahe, exist_ok=True)

# # Melakukan histogram equalization pada gambar-gambar hasil tracking
# for i in tqdm(range(len(tracked_images_array)), desc="Equalizing Images"):
#     tracked_images_array[i] = histogram_equalization(tracked_images_array[i])

# # Menyimpan hasil histogram equalization
# save_images(tracked_images_array, labels_array, output_folder_equalized)

# # Melakukan CLAHE pada gambar-gambar hasil tracking
# for i in tqdm(range(len(tracked_images_array)), desc="CLAHE-ing Images"):
#     tracked_images_array[i] = clahe(tracked_images_array[i])
    
# # Menyimpan hasil CLAHE
# save_images(tracked_images_array, labels_array, output_folder_clahe)

# %%
# Folder untuk menyimpan gambar-gambar hasil konversi
output_folder_oversampled = "/kaggle/working/output_oversample/"
output_folder_undersampled = "/kaggle/working/output_undersample/"

# Membuat folder output jika belum ada
os.makedirs(output_folder_oversampled, exist_ok=True)
os.makedirs(output_folder_undersampled, exist_ok=True)

def oversample_images_generator(images, labels):
    oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
    oversampled_images, oversampled_labels = oversampler.fit_resample(images.reshape(len(images), -1), labels)
    for i in range(len(oversampled_images)):
        yield oversampled_images[i].reshape(images.shape[1:]), oversampled_labels[i]

def undersample_images_generator(images, labels):
    undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
    undersampled_images, undersampled_labels = undersampler.fit_resample(images.reshape(len(images), -1), labels)
    for i in range(len(undersampled_images)):
        yield undersampled_images[i].reshape(images.shape[1:]), undersampled_labels[i]

tracked_images = []
for df in tqdm(data_list, desc="Tracking image label"):
    fundus = df['fundus']
    file_path = os.path.join(output_folder, fundus)
    image = cv2.imread(file_path)
    if image is not None:
        label = df['class']
        tracked_images.append((image, label))

# Memisahkan gambar dan label menjadi dua list terpisah
tracked_images_list = [(x[0], x[1]) for x in tracked_images]
images_list, labels_list = zip(*tracked_images_list)

unique_classes = np.unique(labels_list)
num_classes = len(unique_classes)
print("Jumlah kelas: ", num_classes)

# Melakukan oversampling
oversampled_images_gen = oversample_images_generator(np.array(images_list), np.array(labels_list))
oversampled_images, oversampled_labels = zip(*oversampled_images_gen)
oversampled_images = list(oversampled_images)
oversampled_labels = list(oversampled_labels)
print("Proses selesai. Gambar telah di oversample.")

# Melakukan undersampling
undersampled_images_gen = undersample_images_generator(np.array(images_list), np.array(labels_list))
undersampled_images, undersampled_labels = zip(*undersampled_images_gen)
undersampled_images = list(undersampled_images)
undersampled_labels = list(undersampled_labels)
print("Proses selesai. Gambar telah di undersample.")

# Fungsi untuk menyimpan gambar ke dalam folder
def save_images(images, labels, output_folder):
    for i, (image, label) in enumerate(zip(images, labels)):
        fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
        file_path = os.path.join(output_folder, fundus)
        cv2.imwrite(file_path, image)

# Menyimpan hasil oversampling
save_images(oversampled_images, oversampled_labels, output_folder_oversampled)

# Menyimpan hasil undersampling
save_images(undersampled_images, undersampled_labels, output_folder_undersampled)

# Fungsi untuk melakukan histogram equalization pada gambar
def histogram_equalization(image):
    # Ubah gambar ke skala keabuan jika belum
    if len(image.shape) > 2:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image

    # Lakukan histogram equalization
    equalized = cv2.equalizeHist(gray)

    equalized = cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

    return equalized

# Fungsi untuk melakukan histogram equalization pada gambar
def clahe(image):
    # Ubah gambar ke skala keabuan jika belum
    if len(image.shape) > 2:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image

    clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
    enhanced_image = clahe.apply(gray)

    enhanced_image = cv2.cvtColor(enhanced_image, cv2.COLOR_GRAY2BGR)
    return image

# Folder untuk menyimpan gambar-gambar hasil konversi
output_folder_equalized = "/kaggle/working/output_equalized/"
output_folder_clahe = "/kaggle/working/output_clahe/"

# Membuat folder output jika belum ada
os.makedirs(output_folder_equalized, exist_ok=True)
os.makedirs(output_folder_clahe, exist_ok=True)

# Melakukan histogram equalization pada gambar-gambar hasil oversampling
oversampled_images_copy = list(oversampled_images)  # Buat salinan agar asli tidak berubah
for i in tqdm(range(len(oversampled_images_copy)), desc="CLAHE-ing Images"):
    oversampled_images_copy[i] = clahe(oversampled_images_copy[i])

# Menyimpan hasil histogram equalization
save_images(oversampled_images_copy, oversampled_labels, output_folder_clahe)

# Melakukan histogram equalization pada gambar-gambar hasil oversampling
oversampled_images_copy = list(oversampled_images)  # Buat salinan agar asli tidak berubah
for i in tqdm(range(len(oversampled_images_copy)), desc="Equalizing Images"):
    oversampled_images_copy[i] = histogram_equalization(oversampled_images_copy[i])

# Menyimpan hasil contrast stretching
save_images(oversampled_images_copy, oversampled_labels, output_folder_equalized)
# Out:
# Tracking image label: 100%|██████████| 6277/6277 [00:03<00:00, 1855.81it/s]
# Jumlah kelas:  2
# Proses selesai. Gambar telah di oversample.
# Proses selesai. Gambar telah di undersample.
# CLAHE-ing Images: 100%|██████████| 11366/11366 [00:03<00:00, 3097.28it/s]
# Equalizing Images: 100%|██████████| 11366/11366 [00:02<00:00, 4059.98it/s]

# %%
# # Folder untuk menyimpan gambar-gambar hasil konversi
# output_folder_oversampled = "/kaggle/working/output_oversample/"
# output_folder_undersampled = "/kaggle/working/output_undersample/"

# # Membuat folder output jika belum ada
# os.makedirs(output_folder_oversampled, exist_ok=True)
# os.makedirs(output_folder_undersampled, exist_ok=True)

# def oversample_images_generator(images, labels):
#     oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
#     oversampled_images, oversampled_labels = oversampler.fit_resample(images.reshape(len(images), -1), labels)
#     for oversampled_image, oversampled_label in zip(oversampled_images, oversampled_labels):
#         yield oversampled_image.reshape(images.shape[1:]), oversampled_label

# def undersample_images_generator(images, labels):
#     undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
#     undersampled_images, undersampled_labels = undersampler.fit_resample(images.reshape(len(images), -1), labels)
#     for undersampled_image, undersampled_label in zip(undersampled_images, undersampled_labels):
#         yield undersampled_image.reshape(images.shape[1:]), undersampled_label

# tracked_images = []
# for df in tqdm(data_list, desc="Tracking image label"):
#     fundus = df['fundus']
#     file_path = os.path.join(output_folder, fundus)
#     image = cv2.imread(file_path)
#     if image is not None:
#         label = df['class']
#         tracked_images.append((image, label))

# # Memisahkan gambar dan label menjadi dua array terpisah
# tracked_images_array = np.array([x[0] for x in tracked_images])
# labels_array = np.array([x[1] for x in tracked_images])

# unique_classes = np.unique(labels_array)
# num_classes = len(unique_classes)
# print("Jumlah kelas: ", num_classes)

# # Melakukan oversampling
# oversampled_images = np.array([oversampled_image for oversampled_image, _ in oversample_images_generator(tracked_images_array, labels_array)])
# oversampled_labels = np.array([oversampled_label for _, oversampled_label in oversample_images_generator(tracked_images_array, labels_array)])
# print("Proses selesai. Gambar telah di oversample.")

# # Melakukan undersampling
# undersampled_images = np.array([undersampled_image for undersampled_image, _ in undersample_images_generator(tracked_images_array, labels_array)])
# undersampled_labels = np.array([undersampled_label for _, undersampled_label in undersample_images_generator(tracked_images_array, labels_array)])
# print("Proses selesai. Gambar telah di undersample.")

# # Fungsi untuk menyimpan gambar ke dalam folder
# def save_images(images, labels, output_folder):
#     for i, (image, label) in enumerate(zip(images, labels)):
#         fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
#         file_path = os.path.join(output_folder, fundus)
#         cv2.imwrite(file_path, image)

# # Menyimpan hasil oversampling
# save_images(oversampled_images, oversampled_labels, output_folder_oversampled)

# # Menyimpan hasil undersampling
# save_images(undersampled_images, undersampled_labels, output_folder_undersampled)

# # Fungsi untuk melakukan histogram equalization pada gambar
# def histogram_equalization(image):
#     # Ubah gambar ke skala keabuan jika belum
#     if len(image.shape) > 2:
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     else:
#         gray = image

#     # Lakukan histogram equalization
#     equalized = cv2.equalizeHist(gray)

#     equalized = cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

#     return equalized

# # Fungsi untuk melakukan histogram equalization pada gambar
# def clahe(image):
#     # Ubah gambar ke skala keabuan jika belum
#     if len(image.shape) > 2:
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     else:
#         gray = image

#     clahe = cv2.createCLAHE(clipLimit=20, tileGridSize=(8,8))
#     enhanced_image = clahe.apply(gray)

#     enhanced_image = cv2.cvtColor(enhanced_image, cv2.COLOR_GRAY2BGR)
#     return image

# # Folder untuk menyimpan gambar-gambar hasil konversi
# output_folder_equalized = "/kaggle/working/output_equalized/"
# output_folder_clahe = "/kaggle/working/output_clahe/"

# # Membuat folder output jika belum ada
# os.makedirs(output_folder_equalized, exist_ok=True)
# os.makedirs(output_folder_clahe, exist_ok=True)

# # Fungsi untuk menyimpan gambar ke dalam folder
# def save_images(images, labels, output_folder):
#     for i, (image, label) in enumerate(zip(images, labels)):
#         fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
#         file_path = os.path.join(output_folder, fundus)
#         cv2.imwrite(file_path, image)

# # Melakukan histogram equalization pada gambar-gambar hasil oversampling
# for i in tqdm(range(len(oversampled_images)), desc="CLAHE-ing Images"):
#     oversampled_images[i] = clahe(oversampled_images[i])

# # Menyimpan hasil histogram equalization
# save_images(oversampled_images, oversampled_labels, output_folder_clahe)

# # Melakukan histogram equalization pada gambar-gambar hasil oversampling
# for i in tqdm(range(len(oversampled_images)), desc="Equalizing Images"):
#     oversampled_images[i] = histogram_equalization(oversampled_images[i])

# # Menyimpan hasil contrast stretching
# save_images(oversampled_images, oversampled_labels, output_folder_equalized)

# %%
def split_data(input_folder, output_folder, train_ratio, keywords):
    # Membuat folder output jika belum ada
    os.makedirs(output_folder, exist_ok=True)

    # Hapus konten folder output jika ada
    for filename in os.listdir(output_folder):
        file_path = os.path.join(output_folder, filename)
        if os.path.isfile(file_path):
            os.remove(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)

    # Daftar semua file gambar dalam folder input
    image_files = [file for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

    # Acak urutan file gambar
    random.shuffle(image_files)

    # Tentukan jumlah data training dan testing berdasarkan rasio yang diberikan
    num_train = int(len(image_files) * train_ratio)

    # Bagi data ke dalam folder training dan testing
    train_output_folder = os.path.join(output_folder, 'train')
    test_output_folder = os.path.join(output_folder, 'test')
    os.makedirs(train_output_folder, exist_ok=True)
    os.makedirs(test_output_folder, exist_ok=True)

    # Salin data training dan testing berdasarkan keyword
    for filename in tqdm(image_files[:num_train], desc="Splitting for training data"):
        src_path = os.path.join(input_folder, filename)
        for keyword in keywords:
            if keyword in filename:
                class_name = keyword
                break
        else:
            class_name = "other"

        dst_path = os.path.join(train_output_folder, class_name, filename)
        os.makedirs(os.path.join(train_output_folder, class_name), exist_ok=True)
        shutil.copy(src_path, dst_path)

    for filename in tqdm(image_files[num_train:], desc="Splitting for testing data"):
        src_path = os.path.join(input_folder, filename)
        for keyword in keywords:
            if keyword in filename:
                class_name = keyword
                break
        else:
            class_name = "other"

        dst_path = os.path.join(test_output_folder, class_name, filename)
        os.makedirs(os.path.join(test_output_folder, class_name), exist_ok=True)
        shutil.copy(src_path, dst_path)

    print("Proses split data selesai.")

# Splitting gambar
input_folder = "/kaggle/working/output_equalized/"
output_folder = "/kaggle/working/output_splitting/"
train_ratio = 0.7  # Rasio data training (0.7 = 70% training, 30% testing)

split_data(input_folder, output_folder, train_ratio, keywords)
# Out:
# Splitting for training data: 100%|██████████| 7956/7956 [00:01<00:00, 7449.51it/s]
# Splitting for testing data: 100%|██████████| 3410/3410 [00:00<00:00, 7540.00it/s]
# Proses split data selesai.

# %%
# # Definisikan path folder data training dan testing
# train_data_dir = '/kaggle/working/output_splitting/train/'
# test_data_dir = '/kaggle/working/output_splitting/test/'

# # Definisikan parameter untuk pelatihan model
# input_shape = (224, 224, 3)
# batch_size = 256
# epochs = 200
# num_classes = 7

# # test_datagen = ImageDataGenerator(rescale=1.0/255)

# # Buat generator data pelatihan dan pengujian tanpa augmentasi
# train_datagen = ImageDataGenerator(rescale=1.0/255)
# test_datagen = ImageDataGenerator(rescale=1.0/255)

# train_generator = train_datagen.flow_from_directory(
#     train_data_dir,
#     target_size=input_shape[:2],  # Sesuaikan dengan input_shape
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# test_generator = test_datagen.flow_from_directory(
#     test_data_dir,
#     target_size=input_shape[:2],  # Sesuaikan dengan input_shape
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# # Create a VGG19 model
# vgg = VGG19(input_shape=input_shape , weights='imagenet', include_top=False)

# # # This sets the base that the layers are not trainable. If we'd want to train the layers with custom data, these two lines can be ommitted. 
# # for layer in vgg.layers:
# #   layer.trainable = False

# # Unfreeze the last three blocks (15th to 17th blocks)
# for layer in vgg.layers[:-3]:
#     layer.trainable = False

# # Create a new model on top of VGG19
# model = Sequential()
# model.add(vgg)

# # Additional Convolutional Layers
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=(2, 2)))

# # Flatten and Fully Connected Layers
# model.add(Flatten())
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
# model.add(Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
# model.add(Dense(num_classes, activation='softmax'))

# model.summary()

# # Define callbacks
# checkpoint_vgg = ModelCheckpoint('model.save', monitor='val_loss', save_best_only=True, verbose=1)
# early_stopping_vgg = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)
# log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
# # lr_scheduler = LearningRateScheduler(lr_schedule)  # Learning Rate Scheduler callback

# callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback]
# # callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback, lr_scheduler]

# #Compile the model 
# # sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
# adam_optimizer = Adam(learning_rate=0.01)
# model.compile(loss='categorical_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
# history = model.fit(train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)

# # loss
# plt.plot(history.history['loss'], label='train loss')
# plt.plot(history.history['val_loss'], label='val loss')
# plt.legend()
# plt.show()
# plt.savefig("LossVal_loss.png")

# # accuracies
# plt.plot(history.history['accuracy'], label='train acc')
# plt.plot(history.history['val_accuracy'], label='val acc')
# plt.legend()
# plt.show()
# plt.savefig("AccVal_acc.png")

# # Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
# model = load_model('model.save')

# # Confusion Matrix and Classification Report
# Y_pred = model.predict(test_generator)
# y_pred = np.argmax(Y_pred, axis=1)
# print('Confusion Matrix')
# print(confusion_matrix(test_generator.classes, y_pred))
# print('Classification Report')
# print(classification_report(test_generator.classes, y_pred, target_names=train_generator.class_indices))

# # AUC-ROC Curve
# def plot_auc_roc_curve(model, test_generator):
#     y_true = test_generator.classes
#     y_score = model.predict(test_generator)
    
#     fpr, tpr, thresholds = roc_curve(y_true, y_score, pos_label=None)
#     auc = roc_auc_score(y_true, y_score, multi_class='ovr')
    
#     plt.figure(figsize=(8, 8))
#     plt.plot(fpr, tpr, color='darkorange', lw=2, label='AUC = {:.2f}'.format(auc))
#     plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.title('Receiver Operating Characteristic (ROC) Curve')
#     plt.legend(loc='lower right')
#     plt.show()

# plot_auc_roc_curve(model, test_generator)

# # Loss
# plt.plot(history.history['loss'], label='train loss')
# plt.plot(history.history['val_loss'], label='val loss')
# plt.legend()
# plt.show()
# plt.savefig("LossVal_loss.png")

# # Accuracies
# plt.plot(history.history['accuracy'], label='train acc')
# plt.plot(history.history['val_accuracy'], label='val acc')
# plt.legend()
# plt.show()
# plt.savefig("AccVal_acc.png")

# # # Evaluasi model pada data pelatihan
# # y_train_true = train_generator.classes
# # y_train_pred_probs = model.predict(train_generator)
# # y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# # # Confusion Matrix pada data pelatihan
# # conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)
# # plt.figure(figsize=(8, 6))
# # sns.heatmap(conf_matrix_train, annot=True, fmt='g', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
# # plt.title('Confusion Matrix (Training)')
# # plt.xlabel('Predicted')
# # plt.ylabel('True')
# # plt.show()
# # plt.savefig("Confusion_Matrix_Train.png")

# # # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix (Training)
# # accuracy_train = np.trace(conf_matrix_train) / np.sum(conf_matrix_train)
# # precision_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=0)
# # recall_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=1)
# # f1_score_train = 2 * (precision_train * recall_train) / (precision_train + recall_train)

# # # Calculate overall metrics
# # overall_precision_train = np.mean(precision_train)
# # overall_recall_train = np.mean(recall_train)
# # overall_f1_score_train = np.mean(f1_score_train)

# # # Calculate micro-average ROC-AUC
# # fpr_micro, tpr_micro, _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes).ravel(), y_train_pred_probs.ravel())
# # roc_auc_micro = auc(fpr_micro, tpr_micro)

# # # Print the overall values (Testing) including AUC-ROC
# # print('Overall Metrics (Testing):')
# # print(f'  Accuracy: {accuracy_train:.2f}')
# # print(f'  Precision: {overall_precision:.2f}')
# # print(f'  Recall: {overall_recall:.2f}')
# # print(f'  F1-Score: {overall_f1_score:.2f}')
# # print(f'  AUC-ROC: {roc_auc_micro:.2f}')

# # # AUC ROC pada data pelatihan
# # roc_auc_train_macro = roc_auc_score(to_categorical(y_train_true, num_classes=num_classes), y_train_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))

# # # Plot AUC for the macro average
# # fpr_train_macro, tpr_train_macro, _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes).ravel(), y_train_pred_probs.ravel())
# # roc_auc_train_macro = auc(fpr_train_macro, tpr_train_macro)
# # plt.plot(fpr_train_macro, tpr_train_macro, label=f'Macro (AUC = {roc_auc_train_macro:.2f})')

# # # Plot AUC for each class
# # fpr_train = dict()
# # tpr_train = dict()
# # roc_auc_train = dict()
# # for i in range(num_classes):
# #     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
# #     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])
# #     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Training)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Train.png")

# # # Print the values (Training)
# # for i, class_name in enumerate(train_generator.class_indices.keys()):
# #     print(f'Class: {class_name}')
# #     print(f'  Accuracy (Train): {accuracy_train:.2f}')
# #     print(f'  Precision (Train): {precision_train[i]:.2f}')
# #     print(f'  Recall (Train): {recall_train[i]:.2f}')
# #     print(f'  F1-Score (Train): {f1_score_train[i]:.2f}')

# # # ROC Curve and AUC pada data pelatihan
# # fpr_train = dict()
# # tpr_train = dict()
# # roc_auc_train = dict()

# # # AUC ROC pada data pelatihan
# # roc_auc_train_macro = roc_auc_score(to_categorical(y_train_true, num_classes=num_classes), y_train_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # plt.plot(fpr_train, tpr_train, label=f'Macro (AUC = {roc_auc_train_macro:.2f})')

# # for i in range(num_classes):
# #     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
# #     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # for i in range(num_classes):
# #     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Training)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Train.png")

# # # Evaluasi model pada data uji
# # y_true = test_generator.classes
# # y_pred_probs = model.predict(test_generator)
# # y_pred = np.argmax(y_pred_probs, axis=1)

# # # Confusion Matrix
# # conf_matrix = confusion_matrix(y_true, y_pred)
# # plt.figure(figsize=(8, 6))
# # sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
# # plt.title('Confusion Matrix')
# # plt.xlabel('Predicted')
# # plt.ylabel('True')
# # plt.show()
# # plt.savefig("Confusion_Matrix.png")

# # # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
# # accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
# # precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
# # recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
# # f1_score = 2 * (precision * recall) / (precision + recall)

# # # Calculate overall metrics
# # overall_precision = np.mean(precision)
# # overall_recall = np.mean(recall)
# # overall_f1_score = np.mean(f1_score)

# # # AUC-ROC
# # fpr = dict()
# # tpr = dict()
# # roc_auc = dict()

# # for i in range(num_classes):
# #     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
# #     roc_auc[i] = auc(fpr[i], tpr[i])

# # # Print the overall values (Testing) including AUC-ROC
# # print('Overall Metrics:')
# # print(f'  Accuracy: {accuracy:.2f}')
# # print(f'  Precision: {overall_precision:.2f}')
# # print(f'  Recall: {overall_recall:.2f}')
# # print(f'  F1-Score: {overall_f1_score:.2f}')
# # print(f'  AUC-ROC: {roc_auc:.2f}')

# # # Plot ROC Curve
# # plt.figure(figsize=(10, 8))
# # for i in range(num_classes):
# #     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve')
# # plt.legend()
# # plt.show()

# # # Classification Report
# # class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
# # print("Classification Report:\n", class_report)

# # # Print the values
# # for i, class_name in enumerate(test_generator.class_indices.keys()):
# #     print(f'Class: {class_name}')
# #     print(f'  Accuracy: {accuracy:.2f}')
# #     print(f'  Precision: {precision[i]:.2f}')
# #     print(f'  Recall: {recall[i]:.2f}')
# #     print(f'  F1-Score: {f1_score[i]:.2f}')

# # # ROC Curve and AUC
# # fpr = dict()
# # tpr = dict()
# # roc_auc = dict()

# # # AUC ROC pada data pelatihan
# # roc_auc_test_macro = roc_auc_score(to_categorical(y_true, num_classes=num_classes), y_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # plt.plot(fpr, tpr, label=f'Macro (AUC = {roc_auc_test_macro:.2f})')

# # # for i in range(num_classes):
# # #     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
# # #     roc_auc[i] = auc(fpr[i], tpr[i])

# # # # Plot ROC Curve
# # # plt.figure(figsize=(10, 8))
# # # for i in range(num_classes):
# # #     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Testing)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Test.png")

# %%
# # Evaluasi model pada data pelatihan
# y_train_true = train_generator.classes
# y_train_pred_probs = model.predict(train_generator)
# y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# # Confusion Matrix pada data pelatihan
# conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix_train, annot=True, fmt='g', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
# plt.title('Confusion Matrix (Training)')
# plt.xlabel('Predicted')
# plt.ylabel('True')
# plt.show()
# plt.savefig("Confusion_Matrix_Train.png")

# # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix (Training)
# accuracy_train = np.trace(conf_matrix_train) / np.sum(conf_matrix_train)
# precision_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=0)
# recall_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=1)
# f1_score_train = 2 * (precision_train * recall_train) / (precision_train + recall_train)

# # Print the values (Training)
# for i, class_name in enumerate(train_generator.class_indices.keys()):
#     print(f'Class: {class_name}')
#     print(f'  Accuracy (Train): {accuracy_train:.2f}')
#     print(f'  Precision (Train): {precision_train[i]:.2f}')
#     print(f'  Recall (Train): {recall_train[i]:.2f}')
#     print(f'  F1-Score (Train): {f1_score_train[i]:.2f}')

# # ROC Curve and AUC pada data pelatihan
# fpr_train = dict()
# tpr_train = dict()
# roc_auc_train = dict()

# for i in range(num_classes):
#     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
#     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])

# # Plot ROC Curve pada data pelatihan
# plt.figure(figsize=(10, 8))
# for i in range(num_classes):
#     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# plt.plot([0, 1], [0, 1], 'k--', label='Random')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve (Training)')
# plt.legend()
# plt.show()
# plt.savefig("ROC_Curve_Train.png")

# %%
# Definisikan path folder data training dan testing
train_data_dir = '/kaggle/working/output_splitting/train/'
test_data_dir = '/kaggle/working/output_splitting/test/'

# Definisikan parameter untuk pelatihan model
input_shape = (224, 224, 3)
batch_size = 256
epochs = 200
num_classes = 2

# test_datagen = ImageDataGenerator(rescale=1.0/255)

# Buat generator data pelatihan dan pengujian tanpa augmentasi
train_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=input_shape[:2],  # Sesuaikan dengan input_shape
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=input_shape[:2],  # Sesuaikan dengan input_shape
    batch_size=batch_size,
    class_mode='categorical'
)

# Create a VGG19 model
vgg = VGG19(input_shape=input_shape , weights='imagenet', include_top=False)

# # Unfreeze the last three blocks (15th to 17th blocks)
# for layer in vgg.layers[:-4]:
#     layer.trainable = False
    
# # Create a new model on top of VGG19
# model = Sequential()
# model.add(vgg)

# # Additional Convolutional Layers
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=(2, 2)))

# # Flatten and Fully Connected Layers
# model.add(Flatten())
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(num_classes, activation='softmax'))

# model.summary()  

# This sets the base that the layers are not trainable. If we'd want to train the layers with custom data, these two lines can be ommitted. 
for layer in vgg.layers:
  layer.trainable = False
    
# Stacking a new simple convolutional network on top of it    
x = Flatten()(vgg.output)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(num_classes, activation='softmax')(x)

#Creating model object 
model = Model(inputs=vgg.input, outputs=x)

model.summary()

# # Define learning rate schedule function
# def lr_schedule(epoch):
#     initial_lr = 0.01
#     drop_factor = 0.5
#     epochs_drop = 10.0
#     min_lr = 1e-5
    
#     lr = initial_lr * math.pow(drop_factor, math.floor((1 + epoch) / epochs_drop))
#     return max(lr, min_lr)

# Define callbacks
checkpoint_vgg = ModelCheckpoint('model.save', monitor='val_loss', save_best_only=True, verbose=1)
early_stopping_vgg = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
log_dir = "logs/fit_vgg/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
# lr_scheduler = LearningRateScheduler(lr_schedule)  # Learning Rate Scheduler callback

callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback]

#Compile the model 
sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
# adam_optimizer = Adam(learning_rate=0.01, clipnorm=1.0)
model.compile(loss='categorical_crossentropy', optimizer=sgd_optimizer, metrics=['accuracy'])
history = model.fit(train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)

# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig("LossVal_loss.png")

# accuracies
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig("AccVal_acc.png")

# Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
model = load_model('model.save')

# Evaluasi model pada data uji
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
plt.savefig("Confusion_Matrix.png")

# Classification Report
class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
print("Classification Report:\n", class_report)

# Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
f1_score = 2 * (precision * recall) / (precision + recall)

# Print the values
for i, class_name in enumerate(test_generator.class_indices.keys()):
    print(f'Class: {class_name}')
    print(f'  Accuracy: {accuracy:.2f}')
    print(f'  Precision: {precision[i]:.2f}')
    print(f'  Recall: {recall[i]:.2f}')
    print(f'  F1-Score: {f1_score[i]:.2f}')

# ROC Curve and AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curve
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
plt.savefig("ROC_Curve.png")
# Out:
# Found 7956 images belonging to 2 classes.
# Found 3410 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  batch_normalization (Batch  (None, 25088)             100352
#  Normalization)
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  batch_normalization_1 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 2)                 2050
#
# =================================================================
# Total params: 45822018 (174.80 MB)
# Trainable params: 25745410 (98.21 MB)
# Non-trainable params: 20076608 (76.59 MB)
# _________________________________________________________________
# Epoch 1/200
# 32/32 [==============================] - ETA: 0s - loss: 2.2660 - accuracy: 0.9219
# Epoch 1: val_loss improved from inf to 3.44743, saving model to model.save
# 32/32 [==============================] - 62s 1s/step - loss: 2.2660 - accuracy: 0.9219 - val_loss: 3.4474 - val_accuracy: 0.5472
# Epoch 2/200
# 32/32 [==============================] - ETA: 0s - loss: 2.0112 - accuracy: 0.9822
# Epoch 2: val_loss improved from 3.44743 to 2.16002, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 2.0112 - accuracy: 0.9822 - val_loss: 2.1600 - val_accuracy: 0.9103
# Epoch 3/200
# 32/32 [==============================] - ETA: 0s - loss: 1.9604 - accuracy: 0.9921
# Epoch 3: val_loss improved from 2.16002 to 2.04575, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.9604 - accuracy: 0.9921 - val_loss: 2.0457 - val_accuracy: 0.9566
# Epoch 4/200
# 32/32 [==============================] - ETA: 0s - loss: 1.9377 - accuracy: 0.9922
# Epoch 4: val_loss improved from 2.04575 to 1.99883, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.9377 - accuracy: 0.9922 - val_loss: 1.9988 - val_accuracy: 0.9698
# Epoch 5/200
# 32/32 [==============================] - ETA: 0s - loss: 1.9087 - accuracy: 0.9943
# Epoch 5: val_loss improved from 1.99883 to 1.98551, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.9087 - accuracy: 0.9943 - val_loss: 1.9855 - val_accuracy: 0.9628
# Epoch 6/200
# 32/32 [==============================] - ETA: 0s - loss: 1.9050 - accuracy: 0.9883
# Epoch 6: val_loss improved from 1.98551 to 1.96655, saving model to model.save
# 32/32 [==============================] - 34s 1s/step - loss: 1.9050 - accuracy: 0.9883 - val_loss: 1.9665 - val_accuracy: 0.9730
# Epoch 7/200
# 32/32 [==============================] - ETA: 0s - loss: 1.8751 - accuracy: 0.9918
# Epoch 7: val_loss improved from 1.96655 to 1.94535, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.8751 - accuracy: 0.9918 - val_loss: 1.9453 - val_accuracy: 0.9716
# Epoch 8/200
# 32/32 [==============================] - ETA: 0s - loss: 1.8511 - accuracy: 0.9951
# Epoch 8: val_loss improved from 1.94535 to 1.92123, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.8511 - accuracy: 0.9951 - val_loss: 1.9212 - val_accuracy: 0.9762
# Epoch 9/200
# 32/32 [==============================] - ETA: 0s - loss: 1.8223 - accuracy: 0.9967
# Epoch 9: val_loss improved from 1.92123 to 1.88285, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.8223 - accuracy: 0.9967 - val_loss: 1.8828 - val_accuracy: 0.9815
# Epoch 10/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7981 - accuracy: 0.9976
# Epoch 10: val_loss improved from 1.88285 to 1.85841, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.7981 - accuracy: 0.9976 - val_loss: 1.8584 - val_accuracy: 0.9848
# Epoch 11/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7718 - accuracy: 0.9989
# Epoch 11: val_loss improved from 1.85841 to 1.83469, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.7718 - accuracy: 0.9989 - val_loss: 1.8347 - val_accuracy: 0.9842
# Epoch 12/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7547 - accuracy: 0.9980
# Epoch 12: val_loss improved from 1.83469 to 1.83225, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.7547 - accuracy: 0.9980 - val_loss: 1.8322 - val_accuracy: 0.9765
# Epoch 13/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7319 - accuracy: 0.9984
# Epoch 13: val_loss improved from 1.83225 to 1.77493, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.7319 - accuracy: 0.9984 - val_loss: 1.7749 - val_accuracy: 0.9886
# Epoch 14/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7128 - accuracy: 0.9976
# Epoch 14: val_loss improved from 1.77493 to 1.74936, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.7128 - accuracy: 0.9976 - val_loss: 1.7494 - val_accuracy: 0.9889
# Epoch 15/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6881 - accuracy: 0.9985
# Epoch 15: val_loss improved from 1.74936 to 1.72694, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.6881 - accuracy: 0.9985 - val_loss: 1.7269 - val_accuracy: 0.9909
# Epoch 16/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6674 - accuracy: 0.9990
# Epoch 16: val_loss improved from 1.72694 to 1.70312, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.6674 - accuracy: 0.9990 - val_loss: 1.7031 - val_accuracy: 0.9915
# Epoch 17/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6552 - accuracy: 0.9976
# Epoch 17: val_loss improved from 1.70312 to 1.68026, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.6552 - accuracy: 0.9976 - val_loss: 1.6803 - val_accuracy: 0.9915
# Epoch 18/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6358 - accuracy: 0.9975
# Epoch 18: val_loss improved from 1.68026 to 1.66735, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.6358 - accuracy: 0.9975 - val_loss: 1.6673 - val_accuracy: 0.9915
# Epoch 19/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6202 - accuracy: 0.9961
# Epoch 19: val_loss improved from 1.66735 to 1.65772, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.6202 - accuracy: 0.9961 - val_loss: 1.6577 - val_accuracy: 0.9891
# Epoch 20/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6054 - accuracy: 0.9959
# Epoch 20: val_loss improved from 1.65772 to 1.65279, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.6054 - accuracy: 0.9959 - val_loss: 1.6528 - val_accuracy: 0.9886
# Epoch 21/200
# 32/32 [==============================] - ETA: 0s - loss: 1.5882 - accuracy: 0.9964
# Epoch 21: val_loss improved from 1.65279 to 1.61646, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.5882 - accuracy: 0.9964 - val_loss: 1.6165 - val_accuracy: 0.9912
# Epoch 22/200
# 32/32 [==============================] - ETA: 0s - loss: 1.5852 - accuracy: 0.9922
# Epoch 22: val_loss improved from 1.61646 to 1.60998, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.5852 - accuracy: 0.9922 - val_loss: 1.6100 - val_accuracy: 0.9897
# Epoch 23/200
# 32/32 [==============================] - ETA: 0s - loss: 1.5529 - accuracy: 0.9965
# Epoch 23: val_loss improved from 1.60998 to 1.59026, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.5529 - accuracy: 0.9965 - val_loss: 1.5903 - val_accuracy: 0.9912
# Epoch 24/200
# 32/32 [==============================] - ETA: 0s - loss: 1.5302 - accuracy: 0.9987
# Epoch 24: val_loss improved from 1.59026 to 1.58033, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.5302 - accuracy: 0.9987 - val_loss: 1.5803 - val_accuracy: 0.9909
# Epoch 25/200
# 32/32 [==============================] - ETA: 0s - loss: 1.5099 - accuracy: 0.9989
# Epoch 25: val_loss improved from 1.58033 to 1.56051, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.5099 - accuracy: 0.9989 - val_loss: 1.5605 - val_accuracy: 0.9897
# Epoch 26/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4947 - accuracy: 0.9980
# Epoch 26: val_loss did not improve from 1.56051
# 32/32 [==============================] - 32s 984ms/step - loss: 1.4947 - accuracy: 0.9980 - val_loss: 1.5632 - val_accuracy: 0.9880
# Epoch 27/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4786 - accuracy: 0.9974
# Epoch 27: val_loss improved from 1.56051 to 1.52181, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.4786 - accuracy: 0.9974 - val_loss: 1.5218 - val_accuracy: 0.9927
# Epoch 28/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4660 - accuracy: 0.9966
# Epoch 28: val_loss improved from 1.52181 to 1.50712, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.4660 - accuracy: 0.9966 - val_loss: 1.5071 - val_accuracy: 0.9921
# Epoch 29/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4490 - accuracy: 0.9967
# Epoch 29: val_loss did not improve from 1.50712
# 32/32 [==============================] - 32s 1s/step - loss: 1.4490 - accuracy: 0.9967 - val_loss: 1.5092 - val_accuracy: 0.9915
# Epoch 30/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4317 - accuracy: 0.9975
# Epoch 30: val_loss improved from 1.50712 to 1.49034, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.4317 - accuracy: 0.9975 - val_loss: 1.4903 - val_accuracy: 0.9903
# Epoch 31/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4217 - accuracy: 0.9960
# Epoch 31: val_loss improved from 1.49034 to 1.44904, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.4217 - accuracy: 0.9960 - val_loss: 1.4490 - val_accuracy: 0.9912
# Epoch 32/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4006 - accuracy: 0.9972
# Epoch 32: val_loss improved from 1.44904 to 1.44059, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.4006 - accuracy: 0.9972 - val_loss: 1.4406 - val_accuracy: 0.9930
# Epoch 33/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3779 - accuracy: 0.9989
# Epoch 33: val_loss improved from 1.44059 to 1.43972, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.3779 - accuracy: 0.9989 - val_loss: 1.4397 - val_accuracy: 0.9912
# Epoch 34/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3645 - accuracy: 0.9980
# Epoch 34: val_loss improved from 1.43972 to 1.42021, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.3645 - accuracy: 0.9980 - val_loss: 1.4202 - val_accuracy: 0.9915
# Epoch 35/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3521 - accuracy: 0.9974
# Epoch 35: val_loss improved from 1.42021 to 1.40069, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.3521 - accuracy: 0.9974 - val_loss: 1.4007 - val_accuracy: 0.9918
# Epoch 36/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3378 - accuracy: 0.9974
# Epoch 36: val_loss improved from 1.40069 to 1.38381, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.3378 - accuracy: 0.9974 - val_loss: 1.3838 - val_accuracy: 0.9918
# Epoch 37/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3208 - accuracy: 0.9979
# Epoch 37: val_loss improved from 1.38381 to 1.36153, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.3208 - accuracy: 0.9979 - val_loss: 1.3615 - val_accuracy: 0.9921
# Epoch 38/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3149 - accuracy: 0.9953
# Epoch 38: val_loss improved from 1.36153 to 1.35783, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.3149 - accuracy: 0.9953 - val_loss: 1.3578 - val_accuracy: 0.9912
# Epoch 39/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2888 - accuracy: 0.9992
# Epoch 39: val_loss improved from 1.35783 to 1.33852, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.2888 - accuracy: 0.9992 - val_loss: 1.3385 - val_accuracy: 0.9909
# Epoch 40/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2812 - accuracy: 0.9975
# Epoch 40: val_loss improved from 1.33852 to 1.31416, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.2812 - accuracy: 0.9975 - val_loss: 1.3142 - val_accuracy: 0.9933
# Epoch 41/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2638 - accuracy: 0.9980
# Epoch 41: val_loss improved from 1.31416 to 1.30856, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.2638 - accuracy: 0.9980 - val_loss: 1.3086 - val_accuracy: 0.9915
# Epoch 42/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2551 - accuracy: 0.9971
# Epoch 42: val_loss improved from 1.30856 to 1.30490, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.2551 - accuracy: 0.9971 - val_loss: 1.3049 - val_accuracy: 0.9927
# Epoch 43/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2326 - accuracy: 0.9987
# Epoch 43: val_loss improved from 1.30490 to 1.28236, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.2326 - accuracy: 0.9987 - val_loss: 1.2824 - val_accuracy: 0.9909
# Epoch 44/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2188 - accuracy: 0.9985
# Epoch 44: val_loss improved from 1.28236 to 1.27603, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.2188 - accuracy: 0.9985 - val_loss: 1.2760 - val_accuracy: 0.9912
# Epoch 45/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2082 - accuracy: 0.9985
# Epoch 45: val_loss improved from 1.27603 to 1.23809, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.2082 - accuracy: 0.9985 - val_loss: 1.2381 - val_accuracy: 0.9924
# Epoch 46/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2038 - accuracy: 0.9961
# Epoch 46: val_loss improved from 1.23809 to 1.22943, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.2038 - accuracy: 0.9961 - val_loss: 1.2294 - val_accuracy: 0.9918
# Epoch 47/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1792 - accuracy: 0.9986
# Epoch 47: val_loss did not improve from 1.22943
# 32/32 [==============================] - 32s 998ms/step - loss: 1.1792 - accuracy: 0.9986 - val_loss: 1.2352 - val_accuracy: 0.9924
# Epoch 48/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1704 - accuracy: 0.9975
# Epoch 48: val_loss improved from 1.22943 to 1.21895, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.1704 - accuracy: 0.9975 - val_loss: 1.2190 - val_accuracy: 0.9924
# Epoch 49/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1507 - accuracy: 0.9994
# Epoch 49: val_loss improved from 1.21895 to 1.20398, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.1507 - accuracy: 0.9994 - val_loss: 1.2040 - val_accuracy: 0.9918
# Epoch 50/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1376 - accuracy: 0.9986
# Epoch 50: val_loss improved from 1.20398 to 1.18468, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.1376 - accuracy: 0.9986 - val_loss: 1.1847 - val_accuracy: 0.9924
# Epoch 51/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1227 - accuracy: 0.9994
# Epoch 51: val_loss improved from 1.18468 to 1.17631, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.1227 - accuracy: 0.9994 - val_loss: 1.1763 - val_accuracy: 0.9921
# Epoch 52/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1127 - accuracy: 0.9985
# Epoch 52: val_loss improved from 1.17631 to 1.17548, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.1127 - accuracy: 0.9985 - val_loss: 1.1755 - val_accuracy: 0.9906
# Epoch 53/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1047 - accuracy: 0.9977
# Epoch 53: val_loss improved from 1.17548 to 1.16184, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.1047 - accuracy: 0.9977 - val_loss: 1.1618 - val_accuracy: 0.9894
# Epoch 54/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0940 - accuracy: 0.9967
# Epoch 54: val_loss improved from 1.16184 to 1.12661, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.0940 - accuracy: 0.9967 - val_loss: 1.1266 - val_accuracy: 0.9906
# Epoch 55/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0747 - accuracy: 0.9985
# Epoch 55: val_loss improved from 1.12661 to 1.12360, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.0747 - accuracy: 0.9985 - val_loss: 1.1236 - val_accuracy: 0.9909
# Epoch 56/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0657 - accuracy: 0.9980
# Epoch 56: val_loss did not improve from 1.12360
# 32/32 [==============================] - 32s 991ms/step - loss: 1.0657 - accuracy: 0.9980 - val_loss: 1.1354 - val_accuracy: 0.9897
# Epoch 57/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0566 - accuracy: 0.9985
# Epoch 57: val_loss improved from 1.12360 to 1.10251, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.0566 - accuracy: 0.9985 - val_loss: 1.1025 - val_accuracy: 0.9906
# Epoch 58/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0358 - accuracy: 0.9991
# Epoch 58: val_loss improved from 1.10251 to 1.08380, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.0358 - accuracy: 0.9991 - val_loss: 1.0838 - val_accuracy: 0.9912
# Epoch 59/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0281 - accuracy: 0.9987
# Epoch 59: val_loss improved from 1.08380 to 1.07331, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.0281 - accuracy: 0.9987 - val_loss: 1.0733 - val_accuracy: 0.9889
# Epoch 60/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0196 - accuracy: 0.9970
# Epoch 60: val_loss did not improve from 1.07331
# 32/32 [==============================] - 32s 983ms/step - loss: 1.0196 - accuracy: 0.9970 - val_loss: 1.0852 - val_accuracy: 0.9906
# Epoch 61/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0032 - accuracy: 0.9986
# Epoch 61: val_loss did not improve from 1.07331
# 32/32 [==============================] - 32s 992ms/step - loss: 1.0032 - accuracy: 0.9986 - val_loss: 1.0827 - val_accuracy: 0.9903
# Epoch 62/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9902 - accuracy: 0.9987
# Epoch 62: val_loss improved from 1.07331 to 1.05435, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.9902 - accuracy: 0.9987 - val_loss: 1.0544 - val_accuracy: 0.9927
# Epoch 63/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9887 - accuracy: 0.9966
# Epoch 63: val_loss improved from 1.05435 to 1.04733, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.9887 - accuracy: 0.9966 - val_loss: 1.0473 - val_accuracy: 0.9918
# Epoch 64/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9678 - accuracy: 0.9985
# Epoch 64: val_loss improved from 1.04733 to 1.02921, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.9678 - accuracy: 0.9985 - val_loss: 1.0292 - val_accuracy: 0.9924
# Epoch 65/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9629 - accuracy: 0.9979
# Epoch 65: val_loss improved from 1.02921 to 1.01464, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.9629 - accuracy: 0.9979 - val_loss: 1.0146 - val_accuracy: 0.9889
# Epoch 66/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9481 - accuracy: 0.9987
# Epoch 66: val_loss improved from 1.01464 to 1.00632, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.9481 - accuracy: 0.9987 - val_loss: 1.0063 - val_accuracy: 0.9930
# Epoch 67/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9446 - accuracy: 0.9967
# Epoch 67: val_loss improved from 1.00632 to 0.98131, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.9446 - accuracy: 0.9967 - val_loss: 0.9813 - val_accuracy: 0.9933
# Epoch 68/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9267 - accuracy: 0.9991
# Epoch 68: val_loss improved from 0.98131 to 0.96966, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.9267 - accuracy: 0.9991 - val_loss: 0.9697 - val_accuracy: 0.9918
# Epoch 69/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9179 - accuracy: 0.9985
# Epoch 69: val_loss improved from 0.96966 to 0.94561, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.9179 - accuracy: 0.9985 - val_loss: 0.9456 - val_accuracy: 0.9944
# Epoch 70/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9133 - accuracy: 0.9972
# Epoch 70: val_loss did not improve from 0.94561
# 32/32 [==============================] - 32s 1s/step - loss: 0.9133 - accuracy: 0.9972 - val_loss: 0.9970 - val_accuracy: 0.9889
# Epoch 71/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8976 - accuracy: 0.9986
# Epoch 71: val_loss did not improve from 0.94561
# 32/32 [==============================] - 32s 1s/step - loss: 0.8976 - accuracy: 0.9986 - val_loss: 0.9752 - val_accuracy: 0.9900
# Epoch 72/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8931 - accuracy: 0.9976
# Epoch 72: val_loss did not improve from 0.94561
# 32/32 [==============================] - 32s 997ms/step - loss: 0.8931 - accuracy: 0.9976 - val_loss: 0.9560 - val_accuracy: 0.9909
# Epoch 73/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8890 - accuracy: 0.9967
# Epoch 73: val_loss did not improve from 0.94561
# 32/32 [==============================] - 32s 1s/step - loss: 0.8890 - accuracy: 0.9967 - val_loss: 0.9458 - val_accuracy: 0.9906
# Epoch 74/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8696 - accuracy: 0.9984
# Epoch 74: val_loss improved from 0.94561 to 0.93047, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.8696 - accuracy: 0.9984 - val_loss: 0.9305 - val_accuracy: 0.9909
# Epoch 75/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8560 - accuracy: 0.9997
# Epoch 75: val_loss improved from 0.93047 to 0.90917, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.8560 - accuracy: 0.9997 - val_loss: 0.9092 - val_accuracy: 0.9912
# Epoch 76/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8528 - accuracy: 0.9985
# Epoch 76: val_loss did not improve from 0.90917
# 32/32 [==============================] - 32s 1s/step - loss: 0.8528 - accuracy: 0.9985 - val_loss: 0.9105 - val_accuracy: 0.9877
# Epoch 77/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8426 - accuracy: 0.9975
# Epoch 77: val_loss improved from 0.90917 to 0.88019, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.8426 - accuracy: 0.9975 - val_loss: 0.8802 - val_accuracy: 0.9918
# Epoch 78/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8398 - accuracy: 0.9960
# Epoch 78: val_loss did not improve from 0.88019
# 32/32 [==============================] - 32s 1s/step - loss: 0.8398 - accuracy: 0.9960 - val_loss: 0.8931 - val_accuracy: 0.9894
# Epoch 79/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8319 - accuracy: 0.9965
# Epoch 79: val_loss did not improve from 0.88019
# 32/32 [==============================] - 32s 1s/step - loss: 0.8319 - accuracy: 0.9965 - val_loss: 0.9074 - val_accuracy: 0.9871
# Epoch 80/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8136 - accuracy: 0.9989
# Epoch 80: val_loss did not improve from 0.88019
# 32/32 [==============================] - 32s 1s/step - loss: 0.8136 - accuracy: 0.9989 - val_loss: 0.9043 - val_accuracy: 0.9883
# Epoch 81/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8094 - accuracy: 0.9984
# Epoch 81: val_loss did not improve from 0.88019
# 32/32 [==============================] - 32s 1s/step - loss: 0.8094 - accuracy: 0.9984 - val_loss: 0.9029 - val_accuracy: 0.9836
# Epoch 82/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8066 - accuracy: 0.9962
# Epoch 82: val_loss improved from 0.88019 to 0.87311, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.8066 - accuracy: 0.9962 - val_loss: 0.8731 - val_accuracy: 0.9871
# Epoch 83/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7907 - accuracy: 0.9982
# Epoch 83: val_loss improved from 0.87311 to 0.82831, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.7907 - accuracy: 0.9982 - val_loss: 0.8283 - val_accuracy: 0.9930
# Epoch 84/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7832 - accuracy: 0.9985
# Epoch 84: val_loss did not improve from 0.82831
# 32/32 [==============================] - 32s 1s/step - loss: 0.7832 - accuracy: 0.9985 - val_loss: 0.8357 - val_accuracy: 0.9912
# Epoch 85/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7740 - accuracy: 0.9984
# Epoch 85: val_loss improved from 0.82831 to 0.81215, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.7740 - accuracy: 0.9984 - val_loss: 0.8122 - val_accuracy: 0.9941
# Epoch 86/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7647 - accuracy: 0.9992
# Epoch 86: val_loss did not improve from 0.81215
# 32/32 [==============================] - 32s 996ms/step - loss: 0.7647 - accuracy: 0.9992 - val_loss: 0.8466 - val_accuracy: 0.9891
# Epoch 87/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7537 - accuracy: 0.9995
# Epoch 87: val_loss did not improve from 0.81215
# 32/32 [==============================] - 32s 992ms/step - loss: 0.7537 - accuracy: 0.9995 - val_loss: 0.8363 - val_accuracy: 0.9894
# Epoch 88/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7435 - accuracy: 0.9999
# Epoch 88: val_loss did not improve from 0.81215
# 32/32 [==============================] - 32s 991ms/step - loss: 0.7435 - accuracy: 0.9999 - val_loss: 0.8131 - val_accuracy: 0.9915
# Epoch 89/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7390 - accuracy: 0.9996
# Epoch 89: val_loss improved from 0.81215 to 0.80888, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.7390 - accuracy: 0.9996 - val_loss: 0.8089 - val_accuracy: 0.9894
# Epoch 90/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7269 - accuracy: 0.9995
# Epoch 90: val_loss improved from 0.80888 to 0.78989, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.7269 - accuracy: 0.9995 - val_loss: 0.7899 - val_accuracy: 0.9927
# Epoch 91/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7231 - accuracy: 0.9984
# Epoch 91: val_loss improved from 0.78989 to 0.77074, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.7231 - accuracy: 0.9984 - val_loss: 0.7707 - val_accuracy: 0.9930
# Epoch 92/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7145 - accuracy: 0.9989
# Epoch 92: val_loss improved from 0.77074 to 0.75223, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.7145 - accuracy: 0.9989 - val_loss: 0.7522 - val_accuracy: 0.9912
# Epoch 93/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7043 - accuracy: 0.9991
# Epoch 93: val_loss did not improve from 0.75223
# 32/32 [==============================] - 32s 1s/step - loss: 0.7043 - accuracy: 0.9991 - val_loss: 0.7702 - val_accuracy: 0.9918
# Epoch 94/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7075 - accuracy: 0.9967
# Epoch 94: val_loss did not improve from 0.75223
# 32/32 [==============================] - 32s 1s/step - loss: 0.7075 - accuracy: 0.9967 - val_loss: 0.7640 - val_accuracy: 0.9903
# Epoch 95/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.9982
# Epoch 95: val_loss improved from 0.75223 to 0.73847, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6940 - accuracy: 0.9982 - val_loss: 0.7385 - val_accuracy: 0.9894
# Epoch 96/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6860 - accuracy: 0.9986
# Epoch 96: val_loss improved from 0.73847 to 0.73187, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.6860 - accuracy: 0.9986 - val_loss: 0.7319 - val_accuracy: 0.9912
# Epoch 97/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6762 - accuracy: 0.9992
# Epoch 97: val_loss improved from 0.73187 to 0.72356, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6762 - accuracy: 0.9992 - val_loss: 0.7236 - val_accuracy: 0.9906
# Epoch 98/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6674 - accuracy: 0.9996
# Epoch 98: val_loss improved from 0.72356 to 0.69923, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.6674 - accuracy: 0.9996 - val_loss: 0.6992 - val_accuracy: 0.9918
# Epoch 99/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6644 - accuracy: 0.9987
# Epoch 99: val_loss did not improve from 0.69923
# 32/32 [==============================] - 32s 1s/step - loss: 0.6644 - accuracy: 0.9987 - val_loss: 0.7094 - val_accuracy: 0.9924
# Epoch 100/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6571 - accuracy: 0.9986
# Epoch 100: val_loss did not improve from 0.69923
# 32/32 [==============================] - 32s 998ms/step - loss: 0.6571 - accuracy: 0.9986 - val_loss: 0.7006 - val_accuracy: 0.9909
# Epoch 101/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6479 - accuracy: 0.9991
# Epoch 101: val_loss did not improve from 0.69923
# 32/32 [==============================] - 33s 1s/step - loss: 0.6479 - accuracy: 0.9991 - val_loss: 0.7114 - val_accuracy: 0.9842
# Epoch 102/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6536 - accuracy: 0.9960
# Epoch 102: val_loss did not improve from 0.69923
# 32/32 [==============================] - 32s 1s/step - loss: 0.6536 - accuracy: 0.9960 - val_loss: 0.7507 - val_accuracy: 0.9856
# Epoch 103/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6397 - accuracy: 0.9981
# Epoch 103: val_loss did not improve from 0.69923
# 32/32 [==============================] - 32s 995ms/step - loss: 0.6397 - accuracy: 0.9981 - val_loss: 0.7647 - val_accuracy: 0.9853
# Epoch 104/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6282 - accuracy: 0.9989
# Epoch 104: val_loss did not improve from 0.69923
# 32/32 [==============================] - 32s 998ms/step - loss: 0.6282 - accuracy: 0.9989 - val_loss: 0.7198 - val_accuracy: 0.9889
# Epoch 105/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6264 - accuracy: 0.9976
# Epoch 105: val_loss improved from 0.69923 to 0.68516, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6264 - accuracy: 0.9976 - val_loss: 0.6852 - val_accuracy: 0.9935
# Epoch 106/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6195 - accuracy: 0.9980
# Epoch 106: val_loss improved from 0.68516 to 0.68181, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.6195 - accuracy: 0.9980 - val_loss: 0.6818 - val_accuracy: 0.9912
# Epoch 107/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6147 - accuracy: 0.9974
# Epoch 107: val_loss did not improve from 0.68181
# 32/32 [==============================] - 32s 1s/step - loss: 0.6147 - accuracy: 0.9974 - val_loss: 0.6896 - val_accuracy: 0.9909
# Epoch 108/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6037 - accuracy: 0.9987
# Epoch 108: val_loss improved from 0.68181 to 0.66072, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6037 - accuracy: 0.9987 - val_loss: 0.6607 - val_accuracy: 0.9906
# Epoch 109/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5998 - accuracy: 0.9991
# Epoch 109: val_loss did not improve from 0.66072
# 32/32 [==============================] - 32s 1s/step - loss: 0.5998 - accuracy: 0.9991 - val_loss: 0.6670 - val_accuracy: 0.9921
# Epoch 110/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6007 - accuracy: 0.9965
# Epoch 110: val_loss improved from 0.66072 to 0.65784, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.6007 - accuracy: 0.9965 - val_loss: 0.6578 - val_accuracy: 0.9897
# Epoch 111/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5870 - accuracy: 0.9987
# Epoch 111: val_loss improved from 0.65784 to 0.65002, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.5870 - accuracy: 0.9987 - val_loss: 0.6500 - val_accuracy: 0.9889
# Epoch 112/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5848 - accuracy: 0.9986
# Epoch 112: val_loss improved from 0.65002 to 0.63396, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.5848 - accuracy: 0.9986 - val_loss: 0.6340 - val_accuracy: 0.9918
# Epoch 113/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5763 - accuracy: 0.9985
# Epoch 113: val_loss improved from 0.63396 to 0.62262, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.5763 - accuracy: 0.9985 - val_loss: 0.6226 - val_accuracy: 0.9897
# Epoch 114/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5714 - accuracy: 0.9989
# Epoch 114: val_loss improved from 0.62262 to 0.61755, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.5714 - accuracy: 0.9989 - val_loss: 0.6175 - val_accuracy: 0.9918
# Epoch 115/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5676 - accuracy: 0.9980
# Epoch 115: val_loss improved from 0.61755 to 0.60798, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.5676 - accuracy: 0.9980 - val_loss: 0.6080 - val_accuracy: 0.9930
# Epoch 116/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5575 - accuracy: 0.9990
# Epoch 116: val_loss did not improve from 0.60798
# 32/32 [==============================] - 32s 1s/step - loss: 0.5575 - accuracy: 0.9990 - val_loss: 0.6208 - val_accuracy: 0.9891
# Epoch 117/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5598 - accuracy: 0.9977
# Epoch 117: val_loss improved from 0.60798 to 0.60771, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.5598 - accuracy: 0.9977 - val_loss: 0.6077 - val_accuracy: 0.9909
# Epoch 118/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5526 - accuracy: 0.9985
# Epoch 118: val_loss did not improve from 0.60771
# 32/32 [==============================] - 32s 1s/step - loss: 0.5526 - accuracy: 0.9985 - val_loss: 0.6081 - val_accuracy: 0.9935
# Epoch 119/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5410 - accuracy: 0.9991
# Epoch 119: val_loss improved from 0.60771 to 0.59233, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.5410 - accuracy: 0.9991 - val_loss: 0.5923 - val_accuracy: 0.9900
# Epoch 120/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5361 - accuracy: 0.9980
# Epoch 120: val_loss did not improve from 0.59233
# 32/32 [==============================] - 32s 987ms/step - loss: 0.5361 - accuracy: 0.9980 - val_loss: 0.5976 - val_accuracy: 0.9918
# Epoch 121/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5334 - accuracy: 0.9985
# Epoch 121: val_loss improved from 0.59233 to 0.58509, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.5334 - accuracy: 0.9985 - val_loss: 0.5851 - val_accuracy: 0.9912
# Epoch 122/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5230 - accuracy: 0.9996
# Epoch 122: val_loss did not improve from 0.58509
# 32/32 [==============================] - 32s 995ms/step - loss: 0.5230 - accuracy: 0.9996 - val_loss: 0.6000 - val_accuracy: 0.9900
# Epoch 123/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5216 - accuracy: 0.9981
# Epoch 123: val_loss improved from 0.58509 to 0.58286, saving model to model.save
# 32/32 [==============================] - 34s 1s/step - loss: 0.5216 - accuracy: 0.9981 - val_loss: 0.5829 - val_accuracy: 0.9897
# Epoch 124/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5166 - accuracy: 0.9977
# Epoch 124: val_loss improved from 0.58286 to 0.57201, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.5166 - accuracy: 0.9977 - val_loss: 0.5720 - val_accuracy: 0.9909
# Epoch 125/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5127 - accuracy: 0.9982
# Epoch 125: val_loss did not improve from 0.57201
# 32/32 [==============================] - 31s 976ms/step - loss: 0.5127 - accuracy: 0.9982 - val_loss: 0.5787 - val_accuracy: 0.9874
# Epoch 126/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5089 - accuracy: 0.9974
# Epoch 126: val_loss improved from 0.57201 to 0.57085, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.5089 - accuracy: 0.9974 - val_loss: 0.5708 - val_accuracy: 0.9894
# Epoch 127/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4975 - accuracy: 0.9987
# Epoch 127: val_loss improved from 0.57085 to 0.57051, saving model to model.save
# 32/32 [==============================] - 34s 1s/step - loss: 0.4975 - accuracy: 0.9987 - val_loss: 0.5705 - val_accuracy: 0.9900
# Epoch 128/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.9990
# Epoch 128: val_loss improved from 0.57051 to 0.53750, saving model to model.save
# 32/32 [==============================] - 34s 1s/step - loss: 0.4934 - accuracy: 0.9990 - val_loss: 0.5375 - val_accuracy: 0.9906
# Epoch 129/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.9982
# Epoch 129: val_loss did not improve from 0.53750
# 32/32 [==============================] - 32s 983ms/step - loss: 0.4893 - accuracy: 0.9982 - val_loss: 0.5534 - val_accuracy: 0.9927
# Epoch 130/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4833 - accuracy: 0.9989
# Epoch 130: val_loss improved from 0.53750 to 0.53116, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4833 - accuracy: 0.9989 - val_loss: 0.5312 - val_accuracy: 0.9924
# Epoch 131/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4808 - accuracy: 0.9975
# Epoch 131: val_loss improved from 0.53116 to 0.52076, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4808 - accuracy: 0.9975 - val_loss: 0.5208 - val_accuracy: 0.9909
# Epoch 132/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4724 - accuracy: 0.9985
# Epoch 132: val_loss improved from 0.52076 to 0.52015, saving model to model.save
# 32/32 [==============================] - 34s 1s/step - loss: 0.4724 - accuracy: 0.9985 - val_loss: 0.5201 - val_accuracy: 0.9918
# Epoch 133/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4735 - accuracy: 0.9976
# Epoch 133: val_loss did not improve from 0.52015
# 32/32 [==============================] - 31s 978ms/step - loss: 0.4735 - accuracy: 0.9976 - val_loss: 0.5253 - val_accuracy: 0.9894
# Epoch 134/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.9991
# Epoch 134: val_loss did not improve from 0.52015
# 32/32 [==============================] - 32s 990ms/step - loss: 0.4659 - accuracy: 0.9991 - val_loss: 0.5361 - val_accuracy: 0.9889
# Epoch 135/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4680 - accuracy: 0.9967
# Epoch 135: val_loss did not improve from 0.52015
# 32/32 [==============================] - 31s 975ms/step - loss: 0.4680 - accuracy: 0.9967 - val_loss: 0.5470 - val_accuracy: 0.9883
# Epoch 136/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4562 - accuracy: 0.9994
# Epoch 136: val_loss improved from 0.52015 to 0.51387, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4562 - accuracy: 0.9994 - val_loss: 0.5139 - val_accuracy: 0.9906
# Epoch 137/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4503 - accuracy: 0.9992
# Epoch 137: val_loss improved from 0.51387 to 0.48861, saving model to model.save
# 32/32 [==============================] - 34s 1s/step - loss: 0.4503 - accuracy: 0.9992 - val_loss: 0.4886 - val_accuracy: 0.9930
# Epoch 138/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4473 - accuracy: 0.9990
# Epoch 138: val_loss did not improve from 0.48861
# 32/32 [==============================] - 31s 980ms/step - loss: 0.4473 - accuracy: 0.9990 - val_loss: 0.5062 - val_accuracy: 0.9909
# Epoch 139/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4405 - accuracy: 0.9990
# Epoch 139: val_loss improved from 0.48861 to 0.48596, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4405 - accuracy: 0.9990 - val_loss: 0.4860 - val_accuracy: 0.9924
# Epoch 140/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4378 - accuracy: 0.9990
# Epoch 140: val_loss improved from 0.48596 to 0.47607, saving model to model.save
# 32/32 [==============================] - 34s 1s/step - loss: 0.4378 - accuracy: 0.9990 - val_loss: 0.4761 - val_accuracy: 0.9924
# Epoch 141/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4313 - accuracy: 0.9992
# Epoch 141: val_loss improved from 0.47607 to 0.46393, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4313 - accuracy: 0.9992 - val_loss: 0.4639 - val_accuracy: 0.9921
# Epoch 142/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4275 - accuracy: 0.9989
# Epoch 142: val_loss did not improve from 0.46393
# 32/32 [==============================] - 31s 965ms/step - loss: 0.4275 - accuracy: 0.9989 - val_loss: 0.4683 - val_accuracy: 0.9938
# Epoch 143/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4253 - accuracy: 0.9986
# Epoch 143: val_loss did not improve from 0.46393
# 32/32 [==============================] - 31s 981ms/step - loss: 0.4253 - accuracy: 0.9986 - val_loss: 0.4946 - val_accuracy: 0.9894
# Epoch 144/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4235 - accuracy: 0.9985
# Epoch 144: val_loss did not improve from 0.46393
# 32/32 [==============================] - 33s 1s/step - loss: 0.4235 - accuracy: 0.9985 - val_loss: 0.4739 - val_accuracy: 0.9935
# Epoch 145/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.9971
# Epoch 145: val_loss improved from 0.46393 to 0.46053, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4246 - accuracy: 0.9971 - val_loss: 0.4605 - val_accuracy: 0.9930
# Epoch 146/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4124 - accuracy: 0.9989
# Epoch 146: val_loss did not improve from 0.46053
# ...
# 32/32 [==============================] - 36s 1s/step - loss: 0.4084 - accuracy: 0.9992 - val_loss: 0.4587 - val_accuracy: 0.9933
# Epoch 148/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4023 - accuracy: 0.9994
# Epoch 148: val_loss improved from 0.45869 to 0.45162, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.4023 - accuracy: 0.9994 - val_loss: 0.4516 - val_accuracy: 0.9915
# Epoch 149/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3982 - accuracy: 0.9991
# Epoch 149: val_loss did not improve from 0.45162
# 32/32 [==============================] - 32s 983ms/step - loss: 0.3982 - accuracy: 0.9991 - val_loss: 0.4665 - val_accuracy: 0.9912
# Epoch 150/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3952 - accuracy: 0.9989
# Epoch 150: val_loss did not improve from 0.45162
# 32/32 [==============================] - 32s 986ms/step - loss: 0.3952 - accuracy: 0.9989 - val_loss: 0.4685 - val_accuracy: 0.9915
# Epoch 151/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3930 - accuracy: 0.9981
# Epoch 151: val_loss improved from 0.45162 to 0.43519, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3930 - accuracy: 0.9981 - val_loss: 0.4352 - val_accuracy: 0.9921
# Epoch 152/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3869 - accuracy: 0.9995
# Epoch 152: val_loss improved from 0.43519 to 0.43249, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3869 - accuracy: 0.9995 - val_loss: 0.4325 - val_accuracy: 0.9921
# Epoch 153/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3862 - accuracy: 0.9986
# Epoch 153: val_loss did not improve from 0.43249
# 32/32 [==============================] - 31s 981ms/step - loss: 0.3862 - accuracy: 0.9986 - val_loss: 0.4498 - val_accuracy: 0.9906
# Epoch 154/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3891 - accuracy: 0.9964
# Epoch 154: val_loss did not improve from 0.43249
# 32/32 [==============================] - 31s 981ms/step - loss: 0.3891 - accuracy: 0.9964 - val_loss: 0.4543 - val_accuracy: 0.9906
# Epoch 155/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3859 - accuracy: 0.9980
# Epoch 155: val_loss improved from 0.43249 to 0.43242, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3859 - accuracy: 0.9980 - val_loss: 0.4324 - val_accuracy: 0.9933
# Epoch 156/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3766 - accuracy: 0.9985
# Epoch 156: val_loss did not improve from 0.43242
# 32/32 [==============================] - 31s 978ms/step - loss: 0.3766 - accuracy: 0.9985 - val_loss: 0.4350 - val_accuracy: 0.9889
# Epoch 157/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3734 - accuracy: 0.9984
# Epoch 157: val_loss improved from 0.43242 to 0.43055, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3734 - accuracy: 0.9984 - val_loss: 0.4305 - val_accuracy: 0.9900
# Epoch 158/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3689 - accuracy: 0.9990
# Epoch 158: val_loss improved from 0.43055 to 0.40769, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3689 - accuracy: 0.9990 - val_loss: 0.4077 - val_accuracy: 0.9930
# Epoch 159/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3672 - accuracy: 0.9987
# Epoch 159: val_loss did not improve from 0.40769
# 32/32 [==============================] - 32s 987ms/step - loss: 0.3672 - accuracy: 0.9987 - val_loss: 0.4213 - val_accuracy: 0.9906
# Epoch 160/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3621 - accuracy: 0.9995
# Epoch 160: val_loss improved from 0.40769 to 0.40079, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3621 - accuracy: 0.9995 - val_loss: 0.4008 - val_accuracy: 0.9930
# Epoch 161/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3579 - accuracy: 0.9992
# Epoch 161: val_loss did not improve from 0.40079
# 32/32 [==============================] - 31s 983ms/step - loss: 0.3579 - accuracy: 0.9992 - val_loss: 0.4073 - val_accuracy: 0.9915
# Epoch 162/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3596 - accuracy: 0.9967
# Epoch 162: val_loss did not improve from 0.40079
# 32/32 [==============================] - 31s 979ms/step - loss: 0.3596 - accuracy: 0.9967 - val_loss: 0.4317 - val_accuracy: 0.9930
# Epoch 163/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3569 - accuracy: 0.9980
# Epoch 163: val_loss did not improve from 0.40079
# 32/32 [==============================] - 31s 964ms/step - loss: 0.3569 - accuracy: 0.9980 - val_loss: 0.4309 - val_accuracy: 0.9909
# Epoch 164/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3546 - accuracy: 0.9976
# Epoch 164: val_loss did not improve from 0.40079
# 32/32 [==============================] - 31s 967ms/step - loss: 0.3546 - accuracy: 0.9976 - val_loss: 0.4163 - val_accuracy: 0.9935
# Epoch 165/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3481 - accuracy: 0.9990
# Epoch 165: val_loss did not improve from 0.40079
# 32/32 [==============================] - 31s 979ms/step - loss: 0.3481 - accuracy: 0.9990 - val_loss: 0.4222 - val_accuracy: 0.9918
# Epoch 166/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3427 - accuracy: 0.9992
# Epoch 166: val_loss did not improve from 0.40079
# 32/32 [==============================] - 31s 976ms/step - loss: 0.3427 - accuracy: 0.9992 - val_loss: 0.4207 - val_accuracy: 0.9906
# Epoch 167/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3435 - accuracy: 0.9989
# Epoch 167: val_loss improved from 0.40079 to 0.39852, saving model to model.save
# 32/32 [==============================] - 34s 1s/step - loss: 0.3435 - accuracy: 0.9989 - val_loss: 0.3985 - val_accuracy: 0.9915
# Epoch 168/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.9994
# Epoch 168: val_loss improved from 0.39852 to 0.39285, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3369 - accuracy: 0.9994 - val_loss: 0.3928 - val_accuracy: 0.9915
# Epoch 169/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3322 - accuracy: 0.9995
# Epoch 169: val_loss did not improve from 0.39285
# 32/32 [==============================] - 31s 970ms/step - loss: 0.3322 - accuracy: 0.9995 - val_loss: 0.3998 - val_accuracy: 0.9900
# Epoch 170/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3380 - accuracy: 0.9971
# Epoch 170: val_loss did not improve from 0.39285
# 32/32 [==============================] - 31s 1s/step - loss: 0.3380 - accuracy: 0.9971 - val_loss: 0.4015 - val_accuracy: 0.9891
# Epoch 171/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3318 - accuracy: 0.9981
# Epoch 171: val_loss did not improve from 0.39285
# 32/32 [==============================] - 31s 975ms/step - loss: 0.3318 - accuracy: 0.9981 - val_loss: 0.3974 - val_accuracy: 0.9903
# Epoch 172/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3230 - accuracy: 0.9997
# Epoch 172: val_loss improved from 0.39285 to 0.39165, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3230 - accuracy: 0.9997 - val_loss: 0.3917 - val_accuracy: 0.9889
# Epoch 173/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3204 - accuracy: 0.9991
# Epoch 173: val_loss did not improve from 0.39165
# 32/32 [==============================] - 31s 978ms/step - loss: 0.3204 - accuracy: 0.9991 - val_loss: 0.3941 - val_accuracy: 0.9906
# Epoch 174/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.9984
# Epoch 174: val_loss improved from 0.39165 to 0.37975, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3222 - accuracy: 0.9984 - val_loss: 0.3798 - val_accuracy: 0.9930
# Epoch 175/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.9992
# Epoch 175: val_loss improved from 0.37975 to 0.36356, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3156 - accuracy: 0.9992 - val_loss: 0.3636 - val_accuracy: 0.9921
# Epoch 176/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.9995
# Epoch 176: val_loss improved from 0.36356 to 0.36205, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3121 - accuracy: 0.9995 - val_loss: 0.3621 - val_accuracy: 0.9909
# Epoch 177/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3080 - accuracy: 0.9996
# Epoch 177: val_loss did not improve from 0.36205
# 32/32 [==============================] - 31s 976ms/step - loss: 0.3080 - accuracy: 0.9996 - val_loss: 0.3669 - val_accuracy: 0.9909
# Epoch 178/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3045 - accuracy: 0.9996
# Epoch 178: val_loss did not improve from 0.36205
# 32/32 [==============================] - 31s 971ms/step - loss: 0.3045 - accuracy: 0.9996 - val_loss: 0.3860 - val_accuracy: 0.9903
# Epoch 179/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3024 - accuracy: 0.9994
# Epoch 179: val_loss improved from 0.36205 to 0.36110, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3024 - accuracy: 0.9994 - val_loss: 0.3611 - val_accuracy: 0.9897
# Epoch 180/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3006 - accuracy: 0.9992
# Epoch 180: val_loss improved from 0.36110 to 0.34592, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.3006 - accuracy: 0.9992 - val_loss: 0.3459 - val_accuracy: 0.9909
# Epoch 181/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.9995
# Epoch 181: val_loss improved from 0.34592 to 0.34103, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.2948 - accuracy: 0.9995 - val_loss: 0.3410 - val_accuracy: 0.9935
# Epoch 182/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2914 - accuracy: 0.9996
# Epoch 182: val_loss did not improve from 0.34103
# 32/32 [==============================] - 31s 978ms/step - loss: 0.2914 - accuracy: 0.9996 - val_loss: 0.3437 - val_accuracy: 0.9927
# Epoch 183/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2904 - accuracy: 0.9989
# Epoch 183: val_loss improved from 0.34103 to 0.34000, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.2904 - accuracy: 0.9989 - val_loss: 0.3400 - val_accuracy: 0.9921
# Epoch 184/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2886 - accuracy: 0.9990
# Epoch 184: val_loss did not improve from 0.34000
# 32/32 [==============================] - 32s 981ms/step - loss: 0.2886 - accuracy: 0.9990 - val_loss: 0.3528 - val_accuracy: 0.9912
# Epoch 185/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2851 - accuracy: 0.9990
# Epoch 185: val_loss did not improve from 0.34000
# 32/32 [==============================] - 31s 982ms/step - loss: 0.2851 - accuracy: 0.9990 - val_loss: 0.3506 - val_accuracy: 0.9903
# Epoch 186/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2841 - accuracy: 0.9984
# Epoch 186: val_loss did not improve from 0.34000
# 32/32 [==============================] - 31s 976ms/step - loss: 0.2841 - accuracy: 0.9984 - val_loss: 0.3422 - val_accuracy: 0.9921
# Epoch 187/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.9985
# Epoch 187: val_loss did not improve from 0.34000
# 32/32 [==============================] - 31s 978ms/step - loss: 0.2842 - accuracy: 0.9985 - val_loss: 0.3606 - val_accuracy: 0.9889
# Epoch 188/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.9994
# Epoch 188: val_loss did not improve from 0.34000
# 32/32 [==============================] - 32s 983ms/step - loss: 0.2768 - accuracy: 0.9994 - val_loss: 0.3430 - val_accuracy: 0.9900
# Epoch 189/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2800 - accuracy: 0.9985
# Epoch 189: val_loss did not improve from 0.34000
# 32/32 [==============================] - 31s 978ms/step - loss: 0.2800 - accuracy: 0.9985 - val_loss: 0.3623 - val_accuracy: 0.9891
# Epoch 190/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.9994
# Epoch 190: val_loss did not improve from 0.34000
# 32/32 [==============================] - 31s 979ms/step - loss: 0.2727 - accuracy: 0.9994 - val_loss: 0.3573 - val_accuracy: 0.9874
# Epoch 191/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2688 - accuracy: 0.9995
# Epoch 191: val_loss improved from 0.34000 to 0.33724, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.2688 - accuracy: 0.9995 - val_loss: 0.3372 - val_accuracy: 0.9906
# Epoch 192/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.9986
# Epoch 192: val_loss did not improve from 0.33724
# 32/32 [==============================] - 31s 970ms/step - loss: 0.2689 - accuracy: 0.9986 - val_loss: 0.3431 - val_accuracy: 0.9900
# Epoch 193/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.9982
# Epoch 193: val_loss did not improve from 0.33724
# 32/32 [==============================] - 31s 979ms/step - loss: 0.2729 - accuracy: 0.9982 - val_loss: 0.3510 - val_accuracy: 0.9903
# Epoch 194/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2688 - accuracy: 0.9984
# Epoch 194: val_loss improved from 0.33724 to 0.32434, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.2688 - accuracy: 0.9984 - val_loss: 0.3243 - val_accuracy: 0.9897
# Epoch 195/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.9976
# Epoch 195: val_loss did not improve from 0.32434
# 32/32 [==============================] - 31s 977ms/step - loss: 0.2692 - accuracy: 0.9976 - val_loss: 0.3489 - val_accuracy: 0.9894
# Epoch 196/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.9975
# Epoch 196: val_loss did not improve from 0.32434
# 32/32 [==============================] - 31s 980ms/step - loss: 0.2736 - accuracy: 0.9975 - val_loss: 0.3839 - val_accuracy: 0.9877
# Epoch 197/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.9981
# Epoch 197: val_loss did not improve from 0.32434
# 32/32 [==============================] - 31s 966ms/step - loss: 0.2661 - accuracy: 0.9981 - val_loss: 0.3426 - val_accuracy: 0.9924
# Epoch 198/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2614 - accuracy: 0.9994
# Epoch 198: val_loss did not improve from 0.32434
# 32/32 [==============================] - 31s 963ms/step - loss: 0.2614 - accuracy: 0.9994 - val_loss: 0.3343 - val_accuracy: 0.9912
# Epoch 199/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.9995
# Epoch 199: val_loss did not improve from 0.32434
# 32/32 [==============================] - 31s 979ms/step - loss: 0.2577 - accuracy: 0.9995 - val_loss: 0.3334 - val_accuracy: 0.9915
# Epoch 200/200
# 32/32 [==============================] - ETA: 0s - loss: 0.2552 - accuracy: 0.9990
# Epoch 200: val_loss did not improve from 0.32434
# 32/32 [==============================] - 31s 976ms/step - loss: 0.2552 - accuracy: 0.9990 - val_loss: 0.3319 - val_accuracy: 0.9915
# 14/14 [==============================] - 8s 524ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#     cataract       0.50      0.51      0.51      1713
#       normal       0.50      0.49      0.49      1697
#
#     accuracy                           0.50      3410
#    macro avg       0.50      0.50      0.50      3410
# weighted avg       0.50      0.50      0.50      3410
#
# Class: cataract
#   Accuracy: 0.50
#   Precision: 0.50
#   Recall: 0.51
#   F1-Score: 0.51
# Class: normal
#   Accuracy: 0.50
#   Precision: 0.50
#   Recall: 0.49
#   F1-Score: 0.49

# %%
# # Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
# model = load_model('model.save')

# # Evaluasi model pada data uji
# y_true = test_generator.classes
# y_pred_probs = model.predict(test_generator)
# y_pred = np.argmax(y_pred_probs, axis=1)

# # Confusion Matrix
# conf_matrix = confusion_matrix(y_true, y_pred)
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
# plt.title('Confusion Matrix')
# plt.xlabel('Predicted')
# plt.ylabel('True')
# plt.show()
# plt.savefig("Confusion_Matrix.png")

# # Classification Report
# class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
# print("Classification Report:\n", class_report)

# # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
# accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
# precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
# recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
# f1_score = 2 * (precision * recall) / (precision + recall)

# # Print the values
# for i, class_name in enumerate(test_generator.class_indices.keys()):
#     print(f'Class: {class_name}')
#     print(f'  Accuracy: {accuracy:.2f}')
#     print(f'  Precision: {precision[i]:.2f}')
#     print(f'  Recall: {recall[i]:.2f}')
#     print(f'  F1-Score: {f1_score[i]:.2f}')

# # ROC Curve and AUC
# fpr = dict()
# tpr = dict()
# roc_auc = dict()

# for i in range(num_classes):
#     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
#     roc_auc[i] = auc(fpr[i], tpr[i])

# # Plot ROC Curve
# plt.figure(figsize=(10, 8))
# for i in range(num_classes):
#     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# plt.plot([0, 1], [0, 1], 'k--', label='Random')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve')
# plt.legend()
# plt.show()
# plt.savefig("ROC_Curve.png")

# %%
# import zipfile
# import os
# from IPython.display import FileLink

# def zip_dir(directory = os.curdir, file_name = 'directory.zip'):
#     os.chdir(directory)
#     zip_ref = zipfile.ZipFile(file_name, mode='w')
#     for folder, _, files in os.walk(directory):
#         for file in files:
#             if file_name in file:
#                 pass
#             else:
#                 zip_ref.write(os.path.join(folder, file))

#     return FileLink(file_name)

# zip_dir()
