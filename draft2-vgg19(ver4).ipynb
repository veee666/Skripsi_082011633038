# %%
import cv2
import datetime
import os
import pandas as pd
import numpy as np
import shutil
import seaborn as sns
import random
import math
import tensorflow as tf
import sys
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from matplotlib import pyplot as plt
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from keras import applications, regularizers
from keras.applications.vgg19 import VGG19
from keras.applications.mobilenet import MobileNet
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, LearningRateScheduler
from keras.models import Model, Sequential, load_model
from keras.layers import Conv2D, Dense, Flatten, MaxPooling2D, Dropout, Activation, BatchNormalization
from keras.optimizers import Adam, RMSprop, SGD
from keras.initializers import he_normal
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from tqdm import tqdm
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Import image description data
df_data = pd.read_csv("/kaggle/input/ocular-disease-recognition-odir5k/full_df.csv")

df_data2 = df_data.iloc[:, 1:7]

# "myopia", "hypertensive", "diabetic", "age-related macular degeneration", "glaucoma",

# Daftar kata kunci yang ingin dicari
keywords = ["cataract", "normal", "myopia", "hypertensive", "diabetic", "age-related macular degeneration", "glaucoma"]  # Ganti dengan kata kunci yang diinginkan

# Fungsi untuk mencari kata kunci dalam DataFrame
def search_keywords(data_frame, keyword):
    left_diagnosis = data_frame[data_frame['Left-Diagnostic Keywords'].str.contains(keyword)]
    right_diagnosis = data_frame[data_frame['Right-Diagnostic Keywords'].str.contains(keyword)]
    combined = pd.concat((left_diagnosis['Left-Fundus'], right_diagnosis['Right-Fundus']))

    df_result = pd.DataFrame(combined, columns=['fundus'])
    df_result['class'] = keyword
    return df_result

# Mencari semua kata kunci dalam satu langkah
dfs = []
for keyword in keywords:
    df_keyword = search_keywords(df_data2, keyword)
    dfs.append(df_keyword)

# Menggabungkan hasil pencarian kata kunci
result_df = pd.concat(dfs)

# Menyimpan DataFrame dalam file XLSX
result_df.to_excel('merge.xlsx', index=False)

# Convert DataFrame ke bentuk JSON
data_list = result_df.to_dict(orient='records')


def resize_image(img, target_size):
    # Mendapatkan dimensi gambar asli
    original_height, original_width = img.shape[:2]

    # Mendapatkan dimensi target
    target_width, target_height = target_size

    # Menghitung rasio skala lebar dan tinggi
    width_ratio = target_width / original_width
    height_ratio = target_height / original_height

    # Menentukan rasio skala yang akan digunakan untuk resizing
    scale_ratio = min(width_ratio, height_ratio)

    # Menghitung ukuran baru setelah penskalaan
    new_width = int(original_width * scale_ratio)
    new_height = int(original_height * scale_ratio)

    # Melakukan resizing gambar dengan opsi interporasi yang baik
    resized_img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_AREA)

    # Membuat latar belakang gambar dengan ukuran target
    background = (0, 0, 0)  # Hitam

    # Membuat gambar dengan ukuran target yang tepat
    top_padding = (target_height - new_height) // 2
    bottom_padding = target_height - new_height - top_padding
    left_padding = (target_width - new_width) // 2
    right_padding = target_width - new_width - left_padding

    # Menggunakan padding untuk membuat latar belakang dengan ukuran target
    background_img = cv2.copyMakeBorder(resized_img, top_padding, bottom_padding, left_padding, right_padding, cv2.BORDER_CONSTANT, value=background)

    return background_img

## Read image and preprocessing
def process_images(input_folder, output_folder):
    # Membuat folder output jika belum ada
    os.makedirs(output_folder, exist_ok=True)

    # Loop melalui semua file dalam folder
    for filename in os.listdir(output_folder):

        os.remove(os.path.join(output_folder, filename))

    print("Isi file dalam folder output telah dihapus.")

    # Mendapatkan daftar file gambar di dalam folder input
    image_files = [file for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

    # Loop melalui daftar file gambar
    for image_file in tqdm(image_files, desc="Processing images"):
        # Membaca gambar
        image_path = os.path.join(input_folder, image_file)
        image = cv2.imread(image_path)

        # Ubah ukuran gambar
        target_size = (224, 224)  # Ubah ukuran sesuai kebutuhan Anda
        # resized_image = cv2.resize(image, target_size)
        resized_image = resize_image(image, target_size)
        # cropped_image = crop_padding(resized_image)

        # Ubah format warna gambar
        colored_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

        # Simpan gambar ke folder output dengan nama yang sama
        output_path = os.path.join(output_folder, image_file)
        cv2.imwrite(output_path, colored_image)

    print("Proses selesai. Gambar-gambar telah disimpan di folder output.")

# Preprocessing gambar
input_folder = "/kaggle/input/ocular-disease-recognition-odir5k/ODIR-5K/ODIR-5K/Training Images"
output_folder = "/kaggle/working/output_preprocessing/"

process_images(input_folder, output_folder)
# Out:
# Isi file dalam folder output telah dihapus.
# Processing images: 100%|██████████| 7000/7000 [09:43<00:00, 11.99it/s]
# Proses selesai. Gambar-gambar telah disimpan di folder output.

# %%
# Folder untuk menyimpan gambar-gambar hasil konversi
output_folder_oversampled = "/kaggle/working/output_oversample/"
output_folder_undersampled = "/kaggle/working/output_undersample/"

# Membuat folder output jika belum ada
os.makedirs(output_folder_oversampled, exist_ok=True)
os.makedirs(output_folder_undersampled, exist_ok=True)

def oversample_images_generator(images, labels):
    oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
    oversampled_images, oversampled_labels = oversampler.fit_resample(images.reshape(len(images), -1), labels)
    for oversampled_image, oversampled_label in zip(oversampled_images, oversampled_labels):
        yield oversampled_image.reshape(images.shape[1:]), oversampled_label

def undersample_images_generator(images, labels):
    undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
    undersampled_images, undersampled_labels = undersampler.fit_resample(images.reshape(len(images), -1), labels)
    for undersampled_image, undersampled_label in zip(undersampled_images, undersampled_labels):
        yield undersampled_image.reshape(images.shape[1:]), undersampled_label

tracked_images = []
for df in tqdm(data_list, desc="Tracking image label"):
    fundus = df['fundus']
    file_path = os.path.join(output_folder, fundus)
    image = cv2.imread(file_path)
    if image is not None:
        label = df['class']
        tracked_images.append((image, label))

# Memisahkan gambar dan label menjadi dua array terpisah
tracked_images_array = np.array([x[0] for x in tracked_images])
labels_array = np.array([x[1] for x in tracked_images])

unique_classes = np.unique(labels_array)
num_classes = len(unique_classes)
print("Jumlah kelas: ", num_classes)

# Melakukan oversampling
oversampled_images = np.array([oversampled_image for oversampled_image, _ in oversample_images_generator(tracked_images_array, labels_array)])
oversampled_labels = np.array([oversampled_label for _, oversampled_label in oversample_images_generator(tracked_images_array, labels_array)])
print("Proses selesai. Gambar telah di oversample.")

# Melakukan undersampling
undersampled_images = np.array([undersampled_image for undersampled_image, _ in undersample_images_generator(tracked_images_array, labels_array)])
undersampled_labels = np.array([undersampled_label for _, undersampled_label in undersample_images_generator(tracked_images_array, labels_array)])
print("Proses selesai. Gambar telah di undersample.")

# Fungsi untuk menyimpan gambar ke dalam folder
def save_images(images, labels, output_folder):
    for i, (image, label) in enumerate(zip(images, labels)):
        fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
        file_path = os.path.join(output_folder, fundus)
        cv2.imwrite(file_path, image)

# Menyimpan hasil oversampling
save_images(oversampled_images, oversampled_labels, output_folder_oversampled)

# Menyimpan hasil undersampling
save_images(undersampled_images, undersampled_labels, output_folder_undersampled)

# Fungsi untuk melakukan histogram equalization pada gambar
def histogram_equalization(image):
    # Ubah gambar ke skala keabuan jika belum
    if len(image.shape) > 2:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image

    # Lakukan histogram equalization
    equalized = cv2.equalizeHist(gray)

    equalized = cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

    return equalized

# Fungsi untuk melakukan histogram equalization pada gambar
def clahe(image):
    clahe = cv2.createCLAHE(clipLimit=10, tileGridSize=(8,8))
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)  # convert from BGR to LAB color space
    l, a, b = cv2.split(lab)  # split on 3 different channels
    l2 = clahe.apply(l)  # apply CLAHE to the L-channel
    lab = cv2.merge((l2,a,b))  # merge channels
    image = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)  # convert from LAB to BGR
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# Folder untuk menyimpan gambar-gambar hasil konversi
output_folder_equalized = "/kaggle/working/output_equalized/"
output_folder_clahe = "/kaggle/working/output_clahe/"

# Membuat folder output jika belum ada
os.makedirs(output_folder_equalized, exist_ok=True)
os.makedirs(output_folder_clahe, exist_ok=True)

# Fungsi untuk menyimpan gambar ke dalam folder
def save_images(images, labels, output_folder):
    for i, (image, label) in enumerate(zip(images, labels)):
        fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
        file_path = os.path.join(output_folder, fundus)
        cv2.imwrite(file_path, image)

# Melakukan histogram equalization pada gambar-gambar hasil oversampling
for i in tqdm(range(len(oversampled_images)), desc="CLAHE-ing Images"):
    oversampled_images[i] = clahe(oversampled_images[i])

# Menyimpan hasil histogram equalization
save_images(oversampled_images, oversampled_labels, output_folder_clahe)

# Melakukan histogram equalization pada gambar-gambar hasil oversampling
for i in tqdm(range(len(oversampled_images)), desc="Equalizing Images"):
    oversampled_images[i] = histogram_equalization(oversampled_images[i])

# Menyimpan hasil contrast stretching
save_images(oversampled_images, oversampled_labels, output_folder_equalized)
# Out:
# Tracking image label: 100%|██████████| 8470/8470 [00:03<00:00, 2191.70it/s]
# Jumlah kelas:  7
# Proses selesai. Gambar telah di oversample.
# Proses selesai. Gambar telah di undersample.
# CLAHE-ing Images: 100%|██████████| 39781/39781 [01:13<00:00, 544.47it/s]
# Equalizing Images: 100%|██████████| 39781/39781 [00:06<00:00, 6522.54it/s]

# %%
def split_data(input_folder, output_folder, train_ratio, keywords):
    # Membuat folder output jika belum ada
    os.makedirs(output_folder, exist_ok=True)

    # Hapus konten folder output jika ada
    for filename in os.listdir(output_folder):
        file_path = os.path.join(output_folder, filename)
        if os.path.isfile(file_path):
            os.remove(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)

    # Daftar semua file gambar dalam folder input
    image_files = [file for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

    # Acak urutan file gambar
    random.shuffle(image_files)

    # Tentukan jumlah data training dan testing berdasarkan rasio yang diberikan
    num_train = int(len(image_files) * train_ratio)

    # Bagi data ke dalam folder training dan testing
    train_output_folder = os.path.join(output_folder, 'train')
    test_output_folder = os.path.join(output_folder, 'test')
    os.makedirs(train_output_folder, exist_ok=True)
    os.makedirs(test_output_folder, exist_ok=True)

    # Salin data training dan testing berdasarkan keyword
    for filename in tqdm(image_files[:num_train], desc="Splitting for training data"):
        src_path = os.path.join(input_folder, filename)
        for keyword in keywords:
            if keyword in filename:
                class_name = keyword
                break
        else:
            class_name = "other"

        dst_path = os.path.join(train_output_folder, class_name, filename)
        os.makedirs(os.path.join(train_output_folder, class_name), exist_ok=True)
        shutil.copy(src_path, dst_path)

    for filename in tqdm(image_files[num_train:], desc="Splitting for testing data"):
        src_path = os.path.join(input_folder, filename)
        for keyword in keywords:
            if keyword in filename:
                class_name = keyword
                break
        else:
            class_name = "other"

        dst_path = os.path.join(test_output_folder, class_name, filename)
        os.makedirs(os.path.join(test_output_folder, class_name), exist_ok=True)
        shutil.copy(src_path, dst_path)

    print("Proses split data selesai.")

# Splitting gambar
input_folder = "/kaggle/working/output_clahe/"
output_folder = "/kaggle/working/output_splitting/"
train_ratio = 0.7  # Rasio data training (0.7 = 70% training, 20% testing)

split_data(input_folder, output_folder, train_ratio, keywords)
# Out:
# Splitting for training data: 100%|██████████| 27846/27846 [00:03<00:00, 7388.43it/s]
# Splitting for testing data: 100%|██████████| 11935/11935 [00:01<00:00, 7523.37it/s]
# Proses split data selesai.

# %%
# # Definisikan path folder data training dan testing
# train_data_dir = '/kaggle/working/output_splitting/train/'
# test_data_dir = '/kaggle/working/output_splitting/test/'

# # Definisikan parameter untuk pelatihan model
# input_shape = (224, 224, 3)
# batch_size = 256
# epochs = 200
# num_classes = 7

# # test_datagen = ImageDataGenerator(rescale=1.0/255)

# # Buat generator data pelatihan dan pengujian tanpa augmentasi
# train_datagen = ImageDataGenerator(rescale=1.0/255)
# test_datagen = ImageDataGenerator(rescale=1.0/255)

# train_generator = train_datagen.flow_from_directory(
#     train_data_dir,
#     target_size=input_shape[:2],  # Sesuaikan dengan input_shape
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# test_generator = test_datagen.flow_from_directory(
#     test_data_dir,
#     target_size=input_shape[:2],  # Sesuaikan dengan input_shape
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# # Create a VGG19 model
# vgg = VGG19(input_shape=input_shape , weights='imagenet', include_top=False)

# # # This sets the base that the layers are not trainable. If we'd want to train the layers with custom data, these two lines can be ommitted. 
# # for layer in vgg.layers:
# #   layer.trainable = False

# # Unfreeze the last three blocks (15th to 17th blocks)
# for layer in vgg.layers[:-3]:
#     layer.trainable = False

# # Create a new model on top of VGG19
# model = Sequential()
# model.add(vgg)

# # Additional Convolutional Layers
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=(2, 2)))

# # Flatten and Fully Connected Layers
# model.add(Flatten())
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
# model.add(Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
# model.add(Dense(num_classes, activation='softmax'))

# model.summary()

# # Define callbacks
# checkpoint_vgg = ModelCheckpoint('model.save', monitor='val_loss', save_best_only=True, verbose=1)
# early_stopping_vgg = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)
# log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
# # lr_scheduler = LearningRateScheduler(lr_schedule)  # Learning Rate Scheduler callback

# callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback]
# # callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback, lr_scheduler]

# #Compile the model 
# # sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
# adam_optimizer = Adam(learning_rate=0.01)
# model.compile(loss='categorical_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
# history = model.fit(train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)

# # loss
# plt.plot(history.history['loss'], label='train loss')
# plt.plot(history.history['val_loss'], label='val loss')
# plt.legend()
# plt.show()
# plt.savefig("LossVal_loss.png")

# # accuracies
# plt.plot(history.history['accuracy'], label='train acc')
# plt.plot(history.history['val_accuracy'], label='val acc')
# plt.legend()
# plt.show()
# plt.savefig("AccVal_acc.png")

# # Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
# model = load_model('model.save')

# # Confusion Matrix and Classification Report
# Y_pred = model.predict(test_generator)
# y_pred = np.argmax(Y_pred, axis=1)
# print('Confusion Matrix')
# print(confusion_matrix(test_generator.classes, y_pred))
# print('Classification Report')
# print(classification_report(test_generator.classes, y_pred, target_names=train_generator.class_indices))

# # AUC-ROC Curve
# def plot_auc_roc_curve(model, test_generator):
#     y_true = test_generator.classes
#     y_score = model.predict(test_generator)
    
#     fpr, tpr, thresholds = roc_curve(y_true, y_score, pos_label=None)
#     auc = roc_auc_score(y_true, y_score, multi_class='ovr')
    
#     plt.figure(figsize=(8, 8))
#     plt.plot(fpr, tpr, color='darkorange', lw=2, label='AUC = {:.2f}'.format(auc))
#     plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.title('Receiver Operating Characteristic (ROC) Curve')
#     plt.legend(loc='lower right')
#     plt.show()

# plot_auc_roc_curve(model, test_generator)

# # Loss
# plt.plot(history.history['loss'], label='train loss')
# plt.plot(history.history['val_loss'], label='val loss')
# plt.legend()
# plt.show()
# plt.savefig("LossVal_loss.png")

# # Accuracies
# plt.plot(history.history['accuracy'], label='train acc')
# plt.plot(history.history['val_accuracy'], label='val acc')
# plt.legend()
# plt.show()
# plt.savefig("AccVal_acc.png")

# # # Evaluasi model pada data pelatihan
# # y_train_true = train_generator.classes
# # y_train_pred_probs = model.predict(train_generator)
# # y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# # # Confusion Matrix pada data pelatihan
# # conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)
# # plt.figure(figsize=(8, 6))
# # sns.heatmap(conf_matrix_train, annot=True, fmt='g', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
# # plt.title('Confusion Matrix (Training)')
# # plt.xlabel('Predicted')
# # plt.ylabel('True')
# # plt.show()
# # plt.savefig("Confusion_Matrix_Train.png")

# # # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix (Training)
# # accuracy_train = np.trace(conf_matrix_train) / np.sum(conf_matrix_train)
# # precision_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=0)
# # recall_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=1)
# # f1_score_train = 2 * (precision_train * recall_train) / (precision_train + recall_train)

# # # Calculate overall metrics
# # overall_precision_train = np.mean(precision_train)
# # overall_recall_train = np.mean(recall_train)
# # overall_f1_score_train = np.mean(f1_score_train)

# # # Calculate micro-average ROC-AUC
# # fpr_micro, tpr_micro, _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes).ravel(), y_train_pred_probs.ravel())
# # roc_auc_micro = auc(fpr_micro, tpr_micro)

# # # Print the overall values (Testing) including AUC-ROC
# # print('Overall Metrics (Testing):')
# # print(f'  Accuracy: {accuracy_train:.2f}')
# # print(f'  Precision: {overall_precision:.2f}')
# # print(f'  Recall: {overall_recall:.2f}')
# # print(f'  F1-Score: {overall_f1_score:.2f}')
# # print(f'  AUC-ROC: {roc_auc_micro:.2f}')

# # # AUC ROC pada data pelatihan
# # roc_auc_train_macro = roc_auc_score(to_categorical(y_train_true, num_classes=num_classes), y_train_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))

# # # Plot AUC for the macro average
# # fpr_train_macro, tpr_train_macro, _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes).ravel(), y_train_pred_probs.ravel())
# # roc_auc_train_macro = auc(fpr_train_macro, tpr_train_macro)
# # plt.plot(fpr_train_macro, tpr_train_macro, label=f'Macro (AUC = {roc_auc_train_macro:.2f})')

# # # Plot AUC for each class
# # fpr_train = dict()
# # tpr_train = dict()
# # roc_auc_train = dict()
# # for i in range(num_classes):
# #     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
# #     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])
# #     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Training)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Train.png")

# # # Print the values (Training)
# # for i, class_name in enumerate(train_generator.class_indices.keys()):
# #     print(f'Class: {class_name}')
# #     print(f'  Accuracy (Train): {accuracy_train:.2f}')
# #     print(f'  Precision (Train): {precision_train[i]:.2f}')
# #     print(f'  Recall (Train): {recall_train[i]:.2f}')
# #     print(f'  F1-Score (Train): {f1_score_train[i]:.2f}')

# # # ROC Curve and AUC pada data pelatihan
# # fpr_train = dict()
# # tpr_train = dict()
# # roc_auc_train = dict()

# # # AUC ROC pada data pelatihan
# # roc_auc_train_macro = roc_auc_score(to_categorical(y_train_true, num_classes=num_classes), y_train_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # plt.plot(fpr_train, tpr_train, label=f'Macro (AUC = {roc_auc_train_macro:.2f})')

# # for i in range(num_classes):
# #     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
# #     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # for i in range(num_classes):
# #     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Training)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Train.png")

# # # Evaluasi model pada data uji
# # y_true = test_generator.classes
# # y_pred_probs = model.predict(test_generator)
# # y_pred = np.argmax(y_pred_probs, axis=1)

# # # Confusion Matrix
# # conf_matrix = confusion_matrix(y_true, y_pred)
# # plt.figure(figsize=(8, 6))
# # sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
# # plt.title('Confusion Matrix')
# # plt.xlabel('Predicted')
# # plt.ylabel('True')
# # plt.show()
# # plt.savefig("Confusion_Matrix.png")

# # # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
# # accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
# # precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
# # recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
# # f1_score = 2 * (precision * recall) / (precision + recall)

# # # Calculate overall metrics
# # overall_precision = np.mean(precision)
# # overall_recall = np.mean(recall)
# # overall_f1_score = np.mean(f1_score)

# # # AUC-ROC
# # fpr = dict()
# # tpr = dict()
# # roc_auc = dict()

# # for i in range(num_classes):
# #     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
# #     roc_auc[i] = auc(fpr[i], tpr[i])

# # # Print the overall values (Testing) including AUC-ROC
# # print('Overall Metrics:')
# # print(f'  Accuracy: {accuracy:.2f}')
# # print(f'  Precision: {overall_precision:.2f}')
# # print(f'  Recall: {overall_recall:.2f}')
# # print(f'  F1-Score: {overall_f1_score:.2f}')
# # print(f'  AUC-ROC: {roc_auc:.2f}')

# # # Plot ROC Curve
# # plt.figure(figsize=(10, 8))
# # for i in range(num_classes):
# #     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve')
# # plt.legend()
# # plt.show()

# # # Classification Report
# # class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
# # print("Classification Report:\n", class_report)

# # # Print the values
# # for i, class_name in enumerate(test_generator.class_indices.keys()):
# #     print(f'Class: {class_name}')
# #     print(f'  Accuracy: {accuracy:.2f}')
# #     print(f'  Precision: {precision[i]:.2f}')
# #     print(f'  Recall: {recall[i]:.2f}')
# #     print(f'  F1-Score: {f1_score[i]:.2f}')

# # # ROC Curve and AUC
# # fpr = dict()
# # tpr = dict()
# # roc_auc = dict()

# # # AUC ROC pada data pelatihan
# # roc_auc_test_macro = roc_auc_score(to_categorical(y_true, num_classes=num_classes), y_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # plt.plot(fpr, tpr, label=f'Macro (AUC = {roc_auc_test_macro:.2f})')

# # # for i in range(num_classes):
# # #     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
# # #     roc_auc[i] = auc(fpr[i], tpr[i])

# # # # Plot ROC Curve
# # # plt.figure(figsize=(10, 8))
# # # for i in range(num_classes):
# # #     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Testing)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Test.png")

# %%
# # Evaluasi model pada data pelatihan
# y_train_true = train_generator.classes
# y_train_pred_probs = model.predict(train_generator)
# y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# # Confusion Matrix pada data pelatihan
# conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix_train, annot=True, fmt='g', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
# plt.title('Confusion Matrix (Training)')
# plt.xlabel('Predicted')
# plt.ylabel('True')
# plt.show()
# plt.savefig("Confusion_Matrix_Train.png")

# # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix (Training)
# accuracy_train = np.trace(conf_matrix_train) / np.sum(conf_matrix_train)
# precision_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=0)
# recall_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=1)
# f1_score_train = 2 * (precision_train * recall_train) / (precision_train + recall_train)

# # Print the values (Training)
# for i, class_name in enumerate(train_generator.class_indices.keys()):
#     print(f'Class: {class_name}')
#     print(f'  Accuracy (Train): {accuracy_train:.2f}')
#     print(f'  Precision (Train): {precision_train[i]:.2f}')
#     print(f'  Recall (Train): {recall_train[i]:.2f}')
#     print(f'  F1-Score (Train): {f1_score_train[i]:.2f}')

# # ROC Curve and AUC pada data pelatihan
# fpr_train = dict()
# tpr_train = dict()
# roc_auc_train = dict()

# for i in range(num_classes):
#     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
#     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])

# # Plot ROC Curve pada data pelatihan
# plt.figure(figsize=(10, 8))
# for i in range(num_classes):
#     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# plt.plot([0, 1], [0, 1], 'k--', label='Random')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve (Training)')
# plt.legend()
# plt.show()
# plt.savefig("ROC_Curve_Train.png")

# %%
# Definisikan path folder data training dan testing
train_data_dir = '/kaggle/working/output_splitting/train/'
test_data_dir = '/kaggle/working/output_splitting/test/'

# Definisikan parameter untuk pelatihan model
input_shape = (224, 224, 3)
batch_size = 256
epochs = 200
num_classes = 7

# test_datagen = ImageDataGenerator(rescale=1.0/255)

# Buat generator data pelatihan dan pengujian tanpa augmentasi
train_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=input_shape[:2],  # Sesuaikan dengan input_shape
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=input_shape[:2],  # Sesuaikan dengan input_shape
    batch_size=batch_size,
    class_mode='categorical'
)

# Create a VGG19 model
vgg = VGG19(input_shape=input_shape , weights='imagenet', include_top=False)

# Unfreeze the last three blocks (15th to 17th blocks)
for layer in vgg.layers[:-3]:
    layer.trainable = False

# Stacking a new simple convolutional network on top of it    
x = Flatten()(vgg.output)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(num_classes, activation='softmax')(x)

#Creating model object 
model = Model(inputs=vgg.input, outputs=x)

model.summary()

# Define callbacks
checkpoint_vgg = ModelCheckpoint('model.save', monitor='val_loss', save_best_only=True, verbose=1)
early_stopping_vgg = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
# lr_scheduler = LearningRateScheduler(lr_schedule)  # Learning Rate Scheduler callback

callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback]

#Compile the model 
sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd_optimizer, metrics=['accuracy'])
# adam_optimizer = Adam(learning_rate=0.0001)
history = model.fit(train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)

# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig("LossVal_loss.png")

# accuracies
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig("AccVal_acc.png")

# Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
model = load_model('model.save')

# Evaluasi model pada data uji
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
plt.savefig("Confusion_Matrix.png")

# Classification Report
class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
print("Classification Report:\n", class_report)

# Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
f1_score = 2 * (precision * recall) / (precision + recall)

# Print the values
for i, class_name in enumerate(test_generator.class_indices.keys()):
    print(f'Class: {class_name}')
    print(f'  Accuracy: {accuracy:.2f}')
    print(f'  Precision: {precision[i]:.2f}')
    print(f'  Recall: {recall[i]:.2f}')
    print(f'  F1-Score: {f1_score[i]:.2f}')

# ROC Curve and AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curve
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
plt.savefig("ROC_Curve.png")
# Out:
# Found 27846 images belonging to 7 classes.
# Found 11935 images belonging to 7 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 3s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  batch_normalization (Batch  (None, 25088)             100352
#  Normalization)
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  batch_normalization_1 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 45827143 (174.82 MB)
# Trainable params: 30470151 (116.23 MB)
# Non-trainable params: 15356992 (58.58 MB)
# _________________________________________________________________
# Epoch 1/200
# 109/109 [==============================] - ETA: 0s - loss: 3.0137 - accuracy: 0.6417
# Epoch 1: val_loss improved from inf to 4.23489, saving model to model.save
# 109/109 [==============================] - 138s 1s/step - loss: 3.0137 - accuracy: 0.6417 - val_loss: 4.2349 - val_accuracy: 0.5045
# Epoch 2/200
# 109/109 [==============================] - ETA: 0s - loss: 2.3970 - accuracy: 0.8238
# Epoch 2: val_loss improved from 4.23489 to 3.40926, saving model to model.save
# 109/109 [==============================] - 99s 903ms/step - loss: 2.3970 - accuracy: 0.8238 - val_loss: 3.4093 - val_accuracy: 0.6040
# Epoch 3/200
# 109/109 [==============================] - ETA: 0s - loss: 2.1665 - accuracy: 0.8804
# Epoch 3: val_loss improved from 3.40926 to 2.55726, saving model to model.save
# 109/109 [==============================] - 99s 902ms/step - loss: 2.1665 - accuracy: 0.8804 - val_loss: 2.5573 - val_accuracy: 0.7328
# Epoch 4/200
# 109/109 [==============================] - ETA: 0s - loss: 2.0283 - accuracy: 0.9025
# Epoch 4: val_loss did not improve from 2.55726
# 109/109 [==============================] - 94s 863ms/step - loss: 2.0283 - accuracy: 0.9025 - val_loss: 2.8065 - val_accuracy: 0.6398
# Epoch 5/200
# 109/109 [==============================] - ETA: 0s - loss: 1.9179 - accuracy: 0.9153
# Epoch 5: val_loss improved from 2.55726 to 2.10730, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 1.9179 - accuracy: 0.9153 - val_loss: 2.1073 - val_accuracy: 0.8375
# Epoch 6/200
# 109/109 [==============================] - ETA: 0s - loss: 1.8146 - accuracy: 0.9258
# Epoch 6: val_loss improved from 2.10730 to 1.99109, saving model to model.save
# 109/109 [==============================] - 98s 895ms/step - loss: 1.8146 - accuracy: 0.9258 - val_loss: 1.9911 - val_accuracy: 0.8250
# Epoch 7/200
# 109/109 [==============================] - ETA: 0s - loss: 1.7246 - accuracy: 0.9328
# Epoch 7: val_loss improved from 1.99109 to 1.81554, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 1.7246 - accuracy: 0.9328 - val_loss: 1.8155 - val_accuracy: 0.9031
# Epoch 8/200
# 109/109 [==============================] - ETA: 0s - loss: 1.6467 - accuracy: 0.9381
# Epoch 8: val_loss did not improve from 1.81554
# 109/109 [==============================] - 95s 871ms/step - loss: 1.6467 - accuracy: 0.9381 - val_loss: 1.9583 - val_accuracy: 0.8398
# Epoch 9/200
# 109/109 [==============================] - ETA: 0s - loss: 1.5751 - accuracy: 0.9403
# Epoch 9: val_loss improved from 1.81554 to 1.64522, saving model to model.save
# 109/109 [==============================] - 98s 900ms/step - loss: 1.5751 - accuracy: 0.9403 - val_loss: 1.6452 - val_accuracy: 0.8981
# Epoch 10/200
# 109/109 [==============================] - ETA: 0s - loss: 1.5060 - accuracy: 0.9428
# Epoch 10: val_loss did not improve from 1.64522
# 109/109 [==============================] - 94s 865ms/step - loss: 1.5060 - accuracy: 0.9428 - val_loss: 1.6771 - val_accuracy: 0.8731
# Epoch 11/200
# 109/109 [==============================] - ETA: 0s - loss: 1.4465 - accuracy: 0.9447
# Epoch 11: val_loss did not improve from 1.64522
# 109/109 [==============================] - 95s 866ms/step - loss: 1.4465 - accuracy: 0.9447 - val_loss: 1.7838 - val_accuracy: 0.8426
# Epoch 12/200
# 109/109 [==============================] - ETA: 0s - loss: 1.3895 - accuracy: 0.9442
# Epoch 12: val_loss improved from 1.64522 to 1.44065, saving model to model.save
# 109/109 [==============================] - 98s 896ms/step - loss: 1.3895 - accuracy: 0.9442 - val_loss: 1.4406 - val_accuracy: 0.9129
# Epoch 13/200
# 109/109 [==============================] - ETA: 0s - loss: 1.3257 - accuracy: 0.9468
# Epoch 13: val_loss did not improve from 1.44065
# 109/109 [==============================] - 95s 870ms/step - loss: 1.3257 - accuracy: 0.9468 - val_loss: 1.4546 - val_accuracy: 0.9028
# Epoch 14/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2758 - accuracy: 0.9476
# Epoch 14: val_loss improved from 1.44065 to 1.34203, saving model to model.save
# 109/109 [==============================] - 97s 890ms/step - loss: 1.2758 - accuracy: 0.9476 - val_loss: 1.3420 - val_accuracy: 0.9281
# Epoch 15/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2222 - accuracy: 0.9493
# Epoch 15: val_loss did not improve from 1.34203
# 109/109 [==============================] - 94s 864ms/step - loss: 1.2222 - accuracy: 0.9493 - val_loss: 1.3577 - val_accuracy: 0.9034
# Epoch 16/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1877 - accuracy: 0.9454
# Epoch 16: val_loss did not improve from 1.34203
# 109/109 [==============================] - 94s 864ms/step - loss: 1.1877 - accuracy: 0.9454 - val_loss: 1.3622 - val_accuracy: 0.8823
# Epoch 17/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1390 - accuracy: 0.9479
# Epoch 17: val_loss improved from 1.34203 to 1.24445, saving model to model.save
# 109/109 [==============================] - 98s 893ms/step - loss: 1.1390 - accuracy: 0.9479 - val_loss: 1.2444 - val_accuracy: 0.9047
# Epoch 18/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0945 - accuracy: 0.9471
# Epoch 18: val_loss improved from 1.24445 to 1.12422, saving model to model.save
# 109/109 [==============================] - 98s 898ms/step - loss: 1.0945 - accuracy: 0.9471 - val_loss: 1.1242 - val_accuracy: 0.9349
# Epoch 19/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0400 - accuracy: 0.9518
# Epoch 19: val_loss improved from 1.12422 to 1.05177, saving model to model.save
# 109/109 [==============================] - 98s 894ms/step - loss: 1.0400 - accuracy: 0.9518 - val_loss: 1.0518 - val_accuracy: 0.9455
# Epoch 20/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0001 - accuracy: 0.9520
# Epoch 20: val_loss improved from 1.05177 to 1.01427, saving model to model.save
# 109/109 [==============================] - 98s 898ms/step - loss: 1.0001 - accuracy: 0.9520 - val_loss: 1.0143 - val_accuracy: 0.9429
# Epoch 21/200
# 109/109 [==============================] - ETA: 0s - loss: 0.9600 - accuracy: 0.9528
# Epoch 21: val_loss did not improve from 1.01427
# 109/109 [==============================] - 94s 863ms/step - loss: 0.9600 - accuracy: 0.9528 - val_loss: 1.0340 - val_accuracy: 0.9258
# Epoch 22/200
# 109/109 [==============================] - ETA: 0s - loss: 0.9245 - accuracy: 0.9513
# Epoch 22: val_loss improved from 1.01427 to 0.95912, saving model to model.save
# 109/109 [==============================] - 97s 892ms/step - loss: 0.9245 - accuracy: 0.9513 - val_loss: 0.9591 - val_accuracy: 0.9398
# Epoch 23/200
# 109/109 [==============================] - ETA: 0s - loss: 0.8884 - accuracy: 0.9509
# Epoch 23: val_loss improved from 0.95912 to 0.89642, saving model to model.save
# 109/109 [==============================] - 98s 897ms/step - loss: 0.8884 - accuracy: 0.9509 - val_loss: 0.8964 - val_accuracy: 0.9466
# Epoch 24/200
# 109/109 [==============================] - ETA: 0s - loss: 0.8552 - accuracy: 0.9521
# Epoch 24: val_loss did not improve from 0.89642
# 109/109 [==============================] - 94s 863ms/step - loss: 0.8552 - accuracy: 0.9521 - val_loss: 0.9436 - val_accuracy: 0.9108
# Epoch 25/200
# 109/109 [==============================] - ETA: 0s - loss: 0.8270 - accuracy: 0.9529
# Epoch 25: val_loss improved from 0.89642 to 0.85318, saving model to model.save
# 109/109 [==============================] - 97s 890ms/step - loss: 0.8270 - accuracy: 0.9529 - val_loss: 0.8532 - val_accuracy: 0.9427
# Epoch 26/200
# 109/109 [==============================] - ETA: 0s - loss: 0.7974 - accuracy: 0.9510
# Epoch 26: val_loss improved from 0.85318 to 0.83034, saving model to model.save
# 109/109 [==============================] - 98s 896ms/step - loss: 0.7974 - accuracy: 0.9510 - val_loss: 0.8303 - val_accuracy: 0.9425
# Epoch 27/200
# 109/109 [==============================] - ETA: 0s - loss: 0.7608 - accuracy: 0.9531
# Epoch 27: val_loss improved from 0.83034 to 0.79367, saving model to model.save
# 109/109 [==============================] - 98s 900ms/step - loss: 0.7608 - accuracy: 0.9531 - val_loss: 0.7937 - val_accuracy: 0.9416
# Epoch 28/200
# 109/109 [==============================] - ETA: 0s - loss: 0.7360 - accuracy: 0.9527
# Epoch 28: val_loss improved from 0.79367 to 0.76833, saving model to model.save
# 109/109 [==============================] - 98s 897ms/step - loss: 0.7360 - accuracy: 0.9527 - val_loss: 0.7683 - val_accuracy: 0.9462
# Epoch 29/200
# 109/109 [==============================] - ETA: 0s - loss: 0.7093 - accuracy: 0.9534
# Epoch 29: val_loss improved from 0.76833 to 0.72069, saving model to model.save
# 109/109 [==============================] - 98s 902ms/step - loss: 0.7093 - accuracy: 0.9534 - val_loss: 0.7207 - val_accuracy: 0.9458
# Epoch 30/200
# 109/109 [==============================] - ETA: 0s - loss: 0.6792 - accuracy: 0.9546
# Epoch 30: val_loss improved from 0.72069 to 0.69696, saving model to model.save
# 109/109 [==============================] - 98s 898ms/step - loss: 0.6792 - accuracy: 0.9546 - val_loss: 0.6970 - val_accuracy: 0.9440
# Epoch 31/200
# 109/109 [==============================] - ETA: 0s - loss: 0.6582 - accuracy: 0.9532
# Epoch 31: val_loss improved from 0.69696 to 0.68220, saving model to model.save
# 109/109 [==============================] - 98s 894ms/step - loss: 0.6582 - accuracy: 0.9532 - val_loss: 0.6822 - val_accuracy: 0.9463
# Epoch 32/200
# 109/109 [==============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.9523
# Epoch 32: val_loss improved from 0.68220 to 0.65381, saving model to model.save
# 109/109 [==============================] - 98s 898ms/step - loss: 0.6331 - accuracy: 0.9523 - val_loss: 0.6538 - val_accuracy: 0.9475
# Epoch 33/200
# 109/109 [==============================] - ETA: 0s - loss: 0.6118 - accuracy: 0.9544
# Epoch 33: val_loss improved from 0.65381 to 0.64095, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 0.6118 - accuracy: 0.9544 - val_loss: 0.6409 - val_accuracy: 0.9445
# Epoch 34/200
# 109/109 [==============================] - ETA: 0s - loss: 0.5881 - accuracy: 0.9542
# Epoch 34: val_loss improved from 0.64095 to 0.63672, saving model to model.save
# 109/109 [==============================] - 98s 894ms/step - loss: 0.5881 - accuracy: 0.9542 - val_loss: 0.6367 - val_accuracy: 0.9365
# Epoch 35/200
# 109/109 [==============================] - ETA: 0s - loss: 0.5748 - accuracy: 0.9520
# Epoch 35: val_loss improved from 0.63672 to 0.58690, saving model to model.save
# 109/109 [==============================] - 98s 895ms/step - loss: 0.5748 - accuracy: 0.9520 - val_loss: 0.5869 - val_accuracy: 0.9454
# Epoch 36/200
# 109/109 [==============================] - ETA: 0s - loss: 0.5495 - accuracy: 0.9535
# Epoch 36: val_loss improved from 0.58690 to 0.58236, saving model to model.save
# 109/109 [==============================] - 98s 898ms/step - loss: 0.5495 - accuracy: 0.9535 - val_loss: 0.5824 - val_accuracy: 0.9416
# Epoch 37/200
# 109/109 [==============================] - ETA: 0s - loss: 0.5295 - accuracy: 0.9544
# Epoch 37: val_loss improved from 0.58236 to 0.55729, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 0.5295 - accuracy: 0.9544 - val_loss: 0.5573 - val_accuracy: 0.9486
# Epoch 38/200
# 109/109 [==============================] - ETA: 0s - loss: 0.5111 - accuracy: 0.9554
# Epoch 38: val_loss improved from 0.55729 to 0.52684, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 0.5111 - accuracy: 0.9554 - val_loss: 0.5268 - val_accuracy: 0.9504
# Epoch 39/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.9536
# Epoch 39: val_loss improved from 0.52684 to 0.51448, saving model to model.save
# 109/109 [==============================] - 98s 897ms/step - loss: 0.4929 - accuracy: 0.9536 - val_loss: 0.5145 - val_accuracy: 0.9499
# Epoch 40/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4732 - accuracy: 0.9558
# Epoch 40: val_loss did not improve from 0.51448
# 109/109 [==============================] - 95s 867ms/step - loss: 0.4732 - accuracy: 0.9558 - val_loss: 0.5428 - val_accuracy: 0.9371
# Epoch 41/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.9548
# Epoch 41: val_loss improved from 0.51448 to 0.48091, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 0.4600 - accuracy: 0.9548 - val_loss: 0.4809 - val_accuracy: 0.9476
# Epoch 42/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4515 - accuracy: 0.9530
# Epoch 42: val_loss improved from 0.48091 to 0.45912, saving model to model.save
# 109/109 [==============================] - 98s 895ms/step - loss: 0.4515 - accuracy: 0.9530 - val_loss: 0.4591 - val_accuracy: 0.9496
# Epoch 43/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4320 - accuracy: 0.9541
# Epoch 43: val_loss improved from 0.45912 to 0.45867, saving model to model.save
# 109/109 [==============================] - 98s 894ms/step - loss: 0.4320 - accuracy: 0.9541 - val_loss: 0.4587 - val_accuracy: 0.9470
# Epoch 44/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4186 - accuracy: 0.9544
# Epoch 44: val_loss improved from 0.45867 to 0.45754, saving model to model.save
# 109/109 [==============================] - 99s 908ms/step - loss: 0.4186 - accuracy: 0.9544 - val_loss: 0.4575 - val_accuracy: 0.9436
# Epoch 45/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4035 - accuracy: 0.9551
# Epoch 45: val_loss improved from 0.45754 to 0.42962, saving model to model.save
# 109/109 [==============================] - 98s 897ms/step - loss: 0.4035 - accuracy: 0.9551 - val_loss: 0.4296 - val_accuracy: 0.9502
# Epoch 46/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3889 - accuracy: 0.9556
# Epoch 46: val_loss did not improve from 0.42962
# 109/109 [==============================] - 95s 867ms/step - loss: 0.3889 - accuracy: 0.9556 - val_loss: 0.5341 - val_accuracy: 0.8949
# Epoch 47/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3931 - accuracy: 0.9516
# Epoch 47: val_loss did not improve from 0.42962
# 109/109 [==============================] - 95s 868ms/step - loss: 0.3931 - accuracy: 0.9516 - val_loss: 0.4627 - val_accuracy: 0.9369
# Epoch 48/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3801 - accuracy: 0.9516
# Epoch 48: val_loss did not improve from 0.42962
# 109/109 [==============================] - 95s 869ms/step - loss: 0.3801 - accuracy: 0.9516 - val_loss: 0.4431 - val_accuracy: 0.9341
# Epoch 49/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3632 - accuracy: 0.9539
# Epoch 49: val_loss did not improve from 0.42962
# 109/109 [==============================] - 95s 869ms/step - loss: 0.3632 - accuracy: 0.9539 - val_loss: 0.4611 - val_accuracy: 0.9341
# Epoch 50/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3544 - accuracy: 0.9532
# Epoch 50: val_loss improved from 0.42962 to 0.41369, saving model to model.save
# 109/109 [==============================] - 98s 898ms/step - loss: 0.3544 - accuracy: 0.9532 - val_loss: 0.4137 - val_accuracy: 0.9394
# Epoch 51/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3424 - accuracy: 0.9533
# Epoch 51: val_loss improved from 0.41369 to 0.36166, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 0.3424 - accuracy: 0.9533 - val_loss: 0.3617 - val_accuracy: 0.9498
# Epoch 52/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.9556
# Epoch 52: val_loss did not improve from 0.36166
# 109/109 [==============================] - 95s 866ms/step - loss: 0.3274 - accuracy: 0.9556 - val_loss: 0.4077 - val_accuracy: 0.9295
# Epoch 53/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3203 - accuracy: 0.9545
# Epoch 53: val_loss improved from 0.36166 to 0.34024, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 0.3203 - accuracy: 0.9545 - val_loss: 0.3402 - val_accuracy: 0.9500
# Epoch 54/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3086 - accuracy: 0.9548
# Epoch 54: val_loss improved from 0.34024 to 0.34009, saving model to model.save
# 109/109 [==============================] - 98s 895ms/step - loss: 0.3086 - accuracy: 0.9548 - val_loss: 0.3401 - val_accuracy: 0.9483
# Epoch 55/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3040 - accuracy: 0.9550
# Epoch 55: val_loss improved from 0.34009 to 0.32382, saving model to model.save
# 109/109 [==============================] - 98s 896ms/step - loss: 0.3040 - accuracy: 0.9550 - val_loss: 0.3238 - val_accuracy: 0.9473
# Epoch 56/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.9561
# Epoch 56: val_loss improved from 0.32382 to 0.32080, saving model to model.save
# 109/109 [==============================] - 98s 897ms/step - loss: 0.2922 - accuracy: 0.9561 - val_loss: 0.3208 - val_accuracy: 0.9480
# Epoch 57/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2820 - accuracy: 0.9565
# Epoch 57: val_loss improved from 0.32080 to 0.30599, saving model to model.save
# 109/109 [==============================] - 98s 896ms/step - loss: 0.2820 - accuracy: 0.9565 - val_loss: 0.3060 - val_accuracy: 0.9470
# Epoch 58/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.9562
# Epoch 58: val_loss improved from 0.30599 to 0.30100, saving model to model.save
# 109/109 [==============================] - 98s 898ms/step - loss: 0.2745 - accuracy: 0.9562 - val_loss: 0.3010 - val_accuracy: 0.9478
# Epoch 59/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2658 - accuracy: 0.9565
# Epoch 59: val_loss did not improve from 0.30100
# 109/109 [==============================] - 95s 867ms/step - loss: 0.2658 - accuracy: 0.9565 - val_loss: 0.3098 - val_accuracy: 0.9462
# Epoch 60/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2591 - accuracy: 0.9561
# Epoch 60: val_loss improved from 0.30100 to 0.29032, saving model to model.save
# 109/109 [==============================] - 98s 894ms/step - loss: 0.2591 - accuracy: 0.9561 - val_loss: 0.2903 - val_accuracy: 0.9475
# Epoch 61/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2528 - accuracy: 0.9563
# Epoch 61: val_loss did not improve from 0.29032
# 109/109 [==============================] - 95s 866ms/step - loss: 0.2528 - accuracy: 0.9563 - val_loss: 0.2982 - val_accuracy: 0.9455
# Epoch 62/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2460 - accuracy: 0.9551
# Epoch 62: val_loss did not improve from 0.29032
# 109/109 [==============================] - 95s 866ms/step - loss: 0.2460 - accuracy: 0.9551 - val_loss: 0.2917 - val_accuracy: 0.9473
# Epoch 63/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2404 - accuracy: 0.9558
# Epoch 63: val_loss did not improve from 0.29032
# 109/109 [==============================] - 94s 862ms/step - loss: 0.2404 - accuracy: 0.9558 - val_loss: 0.3269 - val_accuracy: 0.9261
# Epoch 64/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.9545
# Epoch 64: val_loss improved from 0.29032 to 0.26762, saving model to model.save
# 109/109 [==============================] - 99s 908ms/step - loss: 0.2371 - accuracy: 0.9545 - val_loss: 0.2676 - val_accuracy: 0.9493
# Epoch 65/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9568
# Epoch 65: val_loss improved from 0.26762 to 0.25495, saving model to model.save
# 109/109 [==============================] - 99s 908ms/step - loss: 0.2291 - accuracy: 0.9568 - val_loss: 0.2550 - val_accuracy: 0.9506
# Epoch 66/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2229 - accuracy: 0.9570
# Epoch 66: val_loss did not improve from 0.25495
# 109/109 [==============================] - 94s 864ms/step - loss: 0.2229 - accuracy: 0.9570 - val_loss: 0.2618 - val_accuracy: 0.9473
# Epoch 67/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2201 - accuracy: 0.9543
# Epoch 67: val_loss improved from 0.25495 to 0.24731, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 0.2201 - accuracy: 0.9543 - val_loss: 0.2473 - val_accuracy: 0.9508
# Epoch 68/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2150 - accuracy: 0.9551
# Epoch 68: val_loss did not improve from 0.24731
# 109/109 [==============================] - 95s 870ms/step - loss: 0.2150 - accuracy: 0.9551 - val_loss: 0.2695 - val_accuracy: 0.9434
# Epoch 69/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2095 - accuracy: 0.9547
# Epoch 69: val_loss improved from 0.24731 to 0.23705, saving model to model.save
# 109/109 [==============================] - 99s 909ms/step - loss: 0.2095 - accuracy: 0.9547 - val_loss: 0.2371 - val_accuracy: 0.9496
# Epoch 70/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.9566
# Epoch 70: val_loss did not improve from 0.23705
# 109/109 [==============================] - 95s 866ms/step - loss: 0.2020 - accuracy: 0.9566 - val_loss: 0.3128 - val_accuracy: 0.9315
# Epoch 71/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2000 - accuracy: 0.9557
# Epoch 71: val_loss did not improve from 0.23705
# 109/109 [==============================] - 96s 876ms/step - loss: 0.2000 - accuracy: 0.9557 - val_loss: 0.2603 - val_accuracy: 0.9396
# Epoch 72/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2017 - accuracy: 0.9555
# Epoch 72: val_loss did not improve from 0.23705
# 109/109 [==============================] - 95s 869ms/step - loss: 0.2017 - accuracy: 0.9555 - val_loss: 0.2375 - val_accuracy: 0.9469
# Epoch 73/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2011 - accuracy: 0.9539
# Epoch 73: val_loss did not improve from 0.23705
# 109/109 [==============================] - 95s 867ms/step - loss: 0.2011 - accuracy: 0.9539 - val_loss: 0.2418 - val_accuracy: 0.9470
# Epoch 74/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.9526
# Epoch 74: val_loss did not improve from 0.23705
# 109/109 [==============================] - 94s 861ms/step - loss: 0.1999 - accuracy: 0.9526 - val_loss: 0.3181 - val_accuracy: 0.9277
# Epoch 75/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2004 - accuracy: 0.9530
# Epoch 75: val_loss did not improve from 0.23705
# 109/109 [==============================] - 95s 868ms/step - loss: 0.2004 - accuracy: 0.9530 - val_loss: 0.2455 - val_accuracy: 0.9438
# Epoch 76/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1919 - accuracy: 0.9544
# Epoch 76: val_loss did not improve from 0.23705
# 109/109 [==============================] - 94s 863ms/step - loss: 0.1919 - accuracy: 0.9544 - val_loss: 0.6718 - val_accuracy: 0.8814
# Epoch 77/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1916 - accuracy: 0.9544
# Epoch 77: val_loss did not improve from 0.23705
# 109/109 [==============================] - 95s 869ms/step - loss: 0.1916 - accuracy: 0.9544 - val_loss: 0.2716 - val_accuracy: 0.9351
# Epoch 78/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1873 - accuracy: 0.9531
# Epoch 78: val_loss improved from 0.23705 to 0.21533, saving model to model.save
# 109/109 [==============================] - 98s 900ms/step - loss: 0.1873 - accuracy: 0.9531 - val_loss: 0.2153 - val_accuracy: 0.9459
# Epoch 79/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1787 - accuracy: 0.9551
# Epoch 79: val_loss did not improve from 0.21533
# 109/109 [==============================] - 95s 869ms/step - loss: 0.1787 - accuracy: 0.9551 - val_loss: 0.2460 - val_accuracy: 0.9418
# Epoch 80/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9546
# Epoch 80: val_loss improved from 0.21533 to 0.19322, saving model to model.save
# 109/109 [==============================] - 98s 902ms/step - loss: 0.1802 - accuracy: 0.9546 - val_loss: 0.1932 - val_accuracy: 0.9502
# Epoch 81/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1721 - accuracy: 0.9563
# Epoch 81: val_loss did not improve from 0.19322
# 109/109 [==============================] - 95s 873ms/step - loss: 0.1721 - accuracy: 0.9563 - val_loss: 0.2645 - val_accuracy: 0.9351
# Epoch 82/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9551
# Epoch 82: val_loss did not improve from 0.19322
# 109/109 [==============================] - 95s 872ms/step - loss: 0.1704 - accuracy: 0.9551 - val_loss: 0.2134 - val_accuracy: 0.9403
# Epoch 83/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9558
# Epoch 83: val_loss did not improve from 0.19322
# 109/109 [==============================] - 95s 870ms/step - loss: 0.1671 - accuracy: 0.9558 - val_loss: 0.2083 - val_accuracy: 0.9472
# Epoch 84/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.9555
# Epoch 84: val_loss did not improve from 0.19322
# 109/109 [==============================] - 95s 868ms/step - loss: 0.1632 - accuracy: 0.9555 - val_loss: 0.2196 - val_accuracy: 0.9415
# Epoch 85/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1599 - accuracy: 0.9558
# Epoch 85: val_loss did not improve from 0.19322
# 109/109 [==============================] - 95s 870ms/step - loss: 0.1599 - accuracy: 0.9558 - val_loss: 0.2301 - val_accuracy: 0.9433
# Epoch 86/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1586 - accuracy: 0.9556
# Epoch 86: val_loss improved from 0.19322 to 0.18263, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 0.1586 - accuracy: 0.9556 - val_loss: 0.1826 - val_accuracy: 0.9475
# Epoch 87/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9558
# Epoch 87: val_loss did not improve from 0.18263
# 109/109 [==============================] - 95s 870ms/step - loss: 0.1544 - accuracy: 0.9558 - val_loss: 0.2156 - val_accuracy: 0.9443
# Epoch 88/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9562
# Epoch 88: val_loss did not improve from 0.18263
# 109/109 [==============================] - 95s 867ms/step - loss: 0.1540 - accuracy: 0.9562 - val_loss: 0.1943 - val_accuracy: 0.9473
# Epoch 89/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9580
# Epoch 89: val_loss did not improve from 0.18263
# 109/109 [==============================] - 95s 871ms/step - loss: 0.1485 - accuracy: 0.9580 - val_loss: 0.1885 - val_accuracy: 0.9475
# Epoch 90/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.9576
# Epoch 90: val_loss did not improve from 0.18263
# 109/109 [==============================] - 95s 871ms/step - loss: 0.1477 - accuracy: 0.9576 - val_loss: 0.3968 - val_accuracy: 0.8828
# Epoch 91/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1478 - accuracy: 0.9550
# Epoch 91: val_loss improved from 0.18263 to 0.17567, saving model to model.save
# 109/109 [==============================] - 99s 902ms/step - loss: 0.1478 - accuracy: 0.9550 - val_loss: 0.1757 - val_accuracy: 0.9455
# Epoch 92/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9544
# Epoch 92: val_loss did not improve from 0.17567
# 109/109 [==============================] - 95s 869ms/step - loss: 0.1495 - accuracy: 0.9544 - val_loss: 0.2302 - val_accuracy: 0.9343
# Epoch 93/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9551
# Epoch 93: val_loss did not improve from 0.17567
# 109/109 [==============================] - 95s 865ms/step - loss: 0.1465 - accuracy: 0.9551 - val_loss: 0.2655 - val_accuracy: 0.9313
# Epoch 94/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1437 - accuracy: 0.9551
# Epoch 94: val_loss did not improve from 0.17567
# 109/109 [==============================] - 95s 869ms/step - loss: 0.1437 - accuracy: 0.9551 - val_loss: 0.1782 - val_accuracy: 0.9468
# Epoch 95/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9563
# Epoch 95: val_loss did not improve from 0.17567
# 109/109 [==============================] - 94s 863ms/step - loss: 0.1403 - accuracy: 0.9563 - val_loss: 0.1762 - val_accuracy: 0.9486
# Epoch 96/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9558
# Epoch 96: val_loss did not improve from 0.17567
# 109/109 [==============================] - 95s 871ms/step - loss: 0.1375 - accuracy: 0.9558 - val_loss: 0.1884 - val_accuracy: 0.9461
# Epoch 97/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9561
# Epoch 97: val_loss improved from 0.17567 to 0.16440, saving model to model.save
# 109/109 [==============================] - 98s 900ms/step - loss: 0.1363 - accuracy: 0.9561 - val_loss: 0.1644 - val_accuracy: 0.9506
# Epoch 98/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9567
# Epoch 98: val_loss improved from 0.16440 to 0.15178, saving model to model.save
# 109/109 [==============================] - 98s 895ms/step - loss: 0.1342 - accuracy: 0.9567 - val_loss: 0.1518 - val_accuracy: 0.9501
# Epoch 99/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1318 - accuracy: 0.9574
# Epoch 99: val_loss did not improve from 0.15178
# 109/109 [==============================] - 95s 868ms/step - loss: 0.1318 - accuracy: 0.9574 - val_loss: 0.1608 - val_accuracy: 0.9495
# Epoch 100/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9560
# Epoch 100: val_loss did not improve from 0.15178
# 109/109 [==============================] - 95s 866ms/step - loss: 0.1332 - accuracy: 0.9560 - val_loss: 0.1578 - val_accuracy: 0.9492
# Epoch 101/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9568
# Epoch 101: val_loss did not improve from 0.15178
# 109/109 [==============================] - 95s 868ms/step - loss: 0.1275 - accuracy: 0.9568 - val_loss: 0.1695 - val_accuracy: 0.9476
# Epoch 102/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1296 - accuracy: 0.9561
# Epoch 102: val_loss did not improve from 0.15178
# 109/109 [==============================] - 96s 875ms/step - loss: 0.1296 - accuracy: 0.9561 - val_loss: 0.3070 - val_accuracy: 0.9189
# Epoch 103/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9573
# Epoch 103: val_loss did not improve from 0.15178
# 109/109 [==============================] - 96s 877ms/step - loss: 0.1272 - accuracy: 0.9573 - val_loss: 0.1557 - val_accuracy: 0.9501
# Epoch 104/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1277 - accuracy: 0.9565
# Epoch 104: val_loss did not improve from 0.15178
# 109/109 [==============================] - 95s 870ms/step - loss: 0.1277 - accuracy: 0.9565 - val_loss: 0.1563 - val_accuracy: 0.9487
# Epoch 105/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9563
# Epoch 105: val_loss did not improve from 0.15178
# 109/109 [==============================] - 94s 862ms/step - loss: 0.1263 - accuracy: 0.9563 - val_loss: 0.1569 - val_accuracy: 0.9503
# Epoch 106/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9570
# Epoch 106: val_loss did not improve from 0.15178
# 109/109 [==============================] - 95s 866ms/step - loss: 0.1231 - accuracy: 0.9570 - val_loss: 0.1678 - val_accuracy: 0.9466
# Epoch 107/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9569
# Epoch 107: val_loss did not improve from 0.15178
# 109/109 [==============================] - 94s 864ms/step - loss: 0.1206 - accuracy: 0.9569 - val_loss: 0.2131 - val_accuracy: 0.9357
# Epoch 108/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1196 - accuracy: 0.9570
# Epoch 108: val_loss improved from 0.15178 to 0.14245, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 0.1196 - accuracy: 0.9570 - val_loss: 0.1424 - val_accuracy: 0.9501
# Epoch 109/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9570
# Epoch 109: val_loss did not improve from 0.14245
# 109/109 [==============================] - 95s 867ms/step - loss: 0.1188 - accuracy: 0.9570 - val_loss: 0.1432 - val_accuracy: 0.9490
# Epoch 110/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9576
# Epoch 110: val_loss improved from 0.14245 to 0.13823, saving model to model.save
# 109/109 [==============================] - 98s 895ms/step - loss: 0.1207 - accuracy: 0.9576 - val_loss: 0.1382 - val_accuracy: 0.9525
# Epoch 111/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9562
# Epoch 111: val_loss did not improve from 0.13823
# 109/109 [==============================] - 95s 868ms/step - loss: 0.1207 - accuracy: 0.9562 - val_loss: 0.2050 - val_accuracy: 0.9326
# Epoch 112/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.9555
# Epoch 112: val_loss did not improve from 0.13823
# 109/109 [==============================] - 95s 865ms/step - loss: 0.1201 - accuracy: 0.9555 - val_loss: 0.1423 - val_accuracy: 0.9509
# Epoch 113/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9564
# Epoch 113: val_loss did not improve from 0.13823
# 109/109 [==============================] - 95s 870ms/step - loss: 0.1160 - accuracy: 0.9564 - val_loss: 0.1421 - val_accuracy: 0.9515
# Epoch 114/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9576
# Epoch 114: val_loss improved from 0.13823 to 0.13194, saving model to model.save
# 109/109 [==============================] - 99s 903ms/step - loss: 0.1156 - accuracy: 0.9576 - val_loss: 0.1319 - val_accuracy: 0.9515
# Epoch 115/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9558
# Epoch 115: val_loss did not improve from 0.13194
# 109/109 [==============================] - 95s 874ms/step - loss: 0.1172 - accuracy: 0.9558 - val_loss: 0.1458 - val_accuracy: 0.9494
# Epoch 116/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9569
# Epoch 116: val_loss did not improve from 0.13194
# 109/109 [==============================] - 95s 871ms/step - loss: 0.1156 - accuracy: 0.9569 - val_loss: 0.1519 - val_accuracy: 0.9430
# Epoch 117/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9569
# Epoch 117: val_loss did not improve from 0.13194
# 109/109 [==============================] - 95s 867ms/step - loss: 0.1141 - accuracy: 0.9569 - val_loss: 0.1735 - val_accuracy: 0.9448
# Epoch 118/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1139 - accuracy: 0.9569
# Epoch 118: val_loss did not improve from 0.13194
# 109/109 [==============================] - 95s 867ms/step - loss: 0.1139 - accuracy: 0.9569 - val_loss: 0.1451 - val_accuracy: 0.9485
# Epoch 119/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9572
# Epoch 119: val_loss did not improve from 0.13194
# 109/109 [==============================] - 95s 871ms/step - loss: 0.1137 - accuracy: 0.9572 - val_loss: 0.1453 - val_accuracy: 0.9475
# Epoch 120/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9572
# Epoch 120: val_loss did not improve from 0.13194
# 109/109 [==============================] - 95s 866ms/step - loss: 0.1128 - accuracy: 0.9572 - val_loss: 0.1480 - val_accuracy: 0.9468
# Epoch 121/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1120 - accuracy: 0.9566
# Epoch 121: val_loss did not improve from 0.13194
# 109/109 [==============================] - 96s 875ms/step - loss: 0.1120 - accuracy: 0.9566 - val_loss: 0.1327 - val_accuracy: 0.9510
# Epoch 122/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9577
# Epoch 122: val_loss improved from 0.13194 to 0.12695, saving model to model.save
# 109/109 [==============================] - 99s 907ms/step - loss: 0.1085 - accuracy: 0.9577 - val_loss: 0.1269 - val_accuracy: 0.9502
# Epoch 123/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9573
# Epoch 123: val_loss did not improve from 0.12695
# 109/109 [==============================] - 95s 870ms/step - loss: 0.1090 - accuracy: 0.9573 - val_loss: 0.1461 - val_accuracy: 0.9494
# Epoch 124/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9572
# Epoch 124: val_loss did not improve from 0.12695
# 109/109 [==============================] - 95s 869ms/step - loss: 0.1102 - accuracy: 0.9572 - val_loss: 0.1512 - val_accuracy: 0.9481
# Epoch 125/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9576
# Epoch 125: val_loss did not improve from 0.12695
# 109/109 [==============================] - 95s 870ms/step - loss: 0.1083 - accuracy: 0.9576 - val_loss: 0.1292 - val_accuracy: 0.9459
# Epoch 126/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9569
# Epoch 126: val_loss did not improve from 0.12695
# 109/109 [==============================] - 95s 873ms/step - loss: 0.1088 - accuracy: 0.9569 - val_loss: 0.1451 - val_accuracy: 0.9491
# Epoch 127/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9576
# Epoch 127: val_loss did not improve from 0.12695
# 109/109 [==============================] - 96s 877ms/step - loss: 0.1082 - accuracy: 0.9576 - val_loss: 0.1468 - val_accuracy: 0.9479
# Epoch 128/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9564
# Epoch 128: val_loss did not improve from 0.12695
# 109/109 [==============================] - 95s 868ms/step - loss: 0.1085 - accuracy: 0.9564 - val_loss: 0.1691 - val_accuracy: 0.9393
# Epoch 129/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9550
# Epoch 129: val_loss did not improve from 0.12695
# 109/109 [==============================] - 95s 868ms/step - loss: 0.1116 - accuracy: 0.9550 - val_loss: 0.2483 - val_accuracy: 0.9226
# Epoch 130/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9549
# Epoch 130: val_loss did not improve from 0.12695
# 109/109 [==============================] - 95s 866ms/step - loss: 0.1148 - accuracy: 0.9549 - val_loss: 0.1714 - val_accuracy: 0.9410
# Epoch 131/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9561
# Epoch 131: val_loss did not improve from 0.12695
# 109/109 [==============================] - 95s 871ms/step - loss: 0.1141 - accuracy: 0.9561 - val_loss: 0.1661 - val_accuracy: 0.9432
# Epoch 132/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1136 - accuracy: 0.9552
# Epoch 132: val_loss did not improve from 0.12695
# Restoring model weights from the end of the best epoch: 122.
# 109/109 [==============================] - 95s 867ms/step - loss: 0.1136 - accuracy: 0.9552 - val_loss: 0.1643 - val_accuracy: 0.9423
# Epoch 132: early stopping
# 47/47 [==============================] - 25s 531ms/step
# Classification Report:
#                                    precision    recall  f1-score   support
#
# age-related macular degeneration       0.16      0.15      0.15      1725
#                         cataract       0.15      0.15      0.15      1684
#                         diabetic       0.15      0.17      0.16      1697
#                         glaucoma       0.14      0.15      0.14      1728
#                     hypertensive       0.14      0.13      0.13      1694
#                           myopia       0.15      0.15      0.15      1687
#                           normal       0.15      0.14      0.14      1720
#
#                         accuracy                           0.15     11935
#                        macro avg       0.15      0.15      0.15     11935
#                     weighted avg       0.15      0.15      0.15     11935
#
# Class: age-related macular degeneration
#   Accuracy: 0.15
#   Precision: 0.16
#   Recall: 0.15
#   F1-Score: 0.15
# Class: cataract
#   Accuracy: 0.15
#   Precision: 0.15
#   Recall: 0.15
#   F1-Score: 0.15
# Class: diabetic
#   Accuracy: 0.15
#   Precision: 0.15
#   Recall: 0.17
#   F1-Score: 0.16
# Class: glaucoma
#   Accuracy: 0.15
#   Precision: 0.14
#   Recall: 0.15
#   F1-Score: 0.14
# Class: hypertensive
#   Accuracy: 0.15
#   Precision: 0.14
#   Recall: 0.13
#   F1-Score: 0.13
# Class: myopia
#   Accuracy: 0.15
#   Precision: 0.15
#   Recall: 0.15
#   F1-Score: 0.15
# Class: normal
#   Accuracy: 0.15
#   Precision: 0.15
#   Recall: 0.14
#   F1-Score: 0.14

# %%
# # Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
# model = load_model('model.save')

# # Evaluasi model pada data uji
# y_true = test_generator.classes
# y_pred_probs = model.predict(test_generator)
# y_pred = np.argmax(y_pred_probs, axis=1)

# # Confusion Matrix
# conf_matrix = confusion_matrix(y_true, y_pred)
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
# plt.title('Confusion Matrix')
# plt.xlabel('Predicted')
# plt.ylabel('True')
# plt.show()
# plt.savefig("Confusion_Matrix.png")

# # Classification Report
# class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
# print("Classification Report:\n", class_report)

# # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
# accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
# precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
# recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
# f1_score = 2 * (precision * recall) / (precision + recall)

# # Print the values
# for i, class_name in enumerate(test_generator.class_indices.keys()):
#     print(f'Class: {class_name}')
#     print(f'  Accuracy: {accuracy:.2f}')
#     print(f'  Precision: {precision[i]:.2f}')
#     print(f'  Recall: {recall[i]:.2f}')
#     print(f'  F1-Score: {f1_score[i]:.2f}')

# # ROC Curve and AUC
# fpr = dict()
# tpr = dict()
# roc_auc = dict()

# for i in range(num_classes):
#     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
#     roc_auc[i] = auc(fpr[i], tpr[i])

# # Plot ROC Curve
# plt.figure(figsize=(10, 8))
# for i in range(num_classes):
#     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# plt.plot([0, 1], [0, 1], 'k--', label='Random')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve')
# plt.legend()
# plt.show()
# plt.savefig("ROC_Curve.png")

# %%
# import zipfile
# import os
# from IPython.display import FileLink

# def zip_dir(directory = os.curdir, file_name = 'directory.zip'):
#     os.chdir(directory)
#     zip_ref = zipfile.ZipFile(file_name, mode='w')
#     for folder, _, files in os.walk(directory):
#         for file in files:
#             if file_name in file:
#                 pass
#             else:
#                 zip_ref.write(os.path.join(folder, file))

#     return FileLink(file_name)

# zip_dir()
