# %%
import cv2
import datetime
import os
import pandas as pd
import numpy as np
import shutil
import seaborn as sns
import random
import math
import tensorflow as tf
import sys
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from matplotlib import pyplot as plt
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from keras import applications
from keras.applications.vgg19 import VGG19
from keras.applications.mobilenet import MobileNet
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, LearningRateScheduler
from keras.models import Model, Sequential, load_model
from keras.layers import Conv2D, Dense, Flatten, MaxPooling2D, GlobalAveragePooling2D, Dropout, Activation, BatchNormalization
from keras.optimizers import Adam, RMSprop, SGD
from keras.initializers import he_normal
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from tqdm import tqdm
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Import image description data
df_data = pd.read_csv("/kaggle/input/ocular-disease-recognition-odir5k/full_df.csv")

df_data2 = df_data.iloc[:, 1:7]

# "myopia", "hypertensive", "diabetic", "age-related macular degeneration", "glaucoma",

# Daftar kata kunci yang ingin dicari
keywords = ["cataract", "normal", "myopia", "hypertensive", "diabetic", "age-related macular degeneration", "glaucoma"]  # Ganti dengan kata kunci yang diinginkan

# Fungsi untuk mencari kata kunci dalam DataFrame
def search_keywords(data_frame, keyword):
    left_diagnosis = data_frame[data_frame['Left-Diagnostic Keywords'].str.contains(keyword)]
    right_diagnosis = data_frame[data_frame['Right-Diagnostic Keywords'].str.contains(keyword)]
    combined = pd.concat((left_diagnosis['Left-Fundus'], right_diagnosis['Right-Fundus']))

    df_result = pd.DataFrame(combined, columns=['fundus'])
    df_result['class'] = keyword
    return df_result

# Mencari semua kata kunci dalam satu langkah
dfs = []
for keyword in keywords:
    df_keyword = search_keywords(df_data2, keyword)
    dfs.append(df_keyword)

# Menggabungkan hasil pencarian kata kunci
result_df = pd.concat(dfs)

# Menyimpan DataFrame dalam file XLSX
result_df.to_excel('merge.xlsx', index=False)

# Convert DataFrame ke bentuk JSON
data_list = result_df.to_dict(orient='records')


def resize_image(img, target_size):
    # Mendapatkan dimensi gambar asli
    original_height, original_width = img.shape[:2]

    # Mendapatkan dimensi target
    target_width, target_height = target_size

    # Menghitung rasio skala lebar dan tinggi
    width_ratio = target_width / original_width
    height_ratio = target_height / original_height

    # Menentukan rasio skala yang akan digunakan untuk resizing
    scale_ratio = min(width_ratio, height_ratio)

    # Menghitung ukuran baru setelah penskalaan
    new_width = int(original_width * scale_ratio)
    new_height = int(original_height * scale_ratio)

    # Melakukan resizing gambar dengan opsi interporasi yang baik
    resized_img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_AREA)

    # Membuat latar belakang gambar dengan ukuran target
    background = (0, 0, 0)  # Hitam

    # Membuat gambar dengan ukuran target yang tepat
    top_padding = (target_height - new_height) // 2
    bottom_padding = target_height - new_height - top_padding
    left_padding = (target_width - new_width) // 2
    right_padding = target_width - new_width - left_padding

    # Menggunakan padding untuk membuat latar belakang dengan ukuran target
    background_img = cv2.copyMakeBorder(resized_img, top_padding, bottom_padding, left_padding, right_padding, cv2.BORDER_CONSTANT, value=background)

    return background_img

## Read image and preprocessing
def process_images(input_folder, output_folder):
    # Membuat folder output jika belum ada
    os.makedirs(output_folder, exist_ok=True)

    # Loop melalui semua file dalam folder
    for filename in os.listdir(output_folder):

        os.remove(os.path.join(output_folder, filename))

    print("Isi file dalam folder output telah dihapus.")

    # Mendapatkan daftar file gambar di dalam folder input
    image_files = [file for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

    # Loop melalui daftar file gambar
    for image_file in tqdm(image_files, desc="Processing images"):
        # Membaca gambar
        image_path = os.path.join(input_folder, image_file)
        image = cv2.imread(image_path)

        # Ubah ukuran gambar
        target_size = (224, 224)  # Ubah ukuran sesuai kebutuhan Anda
        # resized_image = cv2.resize(image, target_size)
        resized_image = resize_image(image, target_size)
        # cropped_image = crop_padding(resized_image)

        # Ubah format warna gambar
        colored_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

        # Simpan gambar ke folder output dengan nama yang sama
        output_path = os.path.join(output_folder, image_file)
        cv2.imwrite(output_path, colored_image)

    print("Proses selesai. Gambar-gambar telah disimpan di folder output.")

# Preprocessing gambar
input_folder = "/kaggle/input/ocular-disease-recognition-odir5k/ODIR-5K/ODIR-5K/Training Images"
output_folder = "/kaggle/working/output_preprocessing/"

process_images(input_folder, output_folder)
# Out:
# Isi file dalam folder output telah dihapus.
# Processing images: 100%|██████████| 7000/7000 [08:53<00:00, 13.13it/s]
# Proses selesai. Gambar-gambar telah disimpan di folder output.

# %%
# Folder untuk menyimpan gambar-gambar hasil konversi
output_folder_oversampled = "/kaggle/working/output_oversample/"
output_folder_undersampled = "/kaggle/working/output_undersample/"

# Membuat folder output jika belum ada
os.makedirs(output_folder_oversampled, exist_ok=True)
os.makedirs(output_folder_undersampled, exist_ok=True)

def oversample_images_generator(images, labels):
    oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
    oversampled_images, oversampled_labels = oversampler.fit_resample(images.reshape(len(images), -1), labels)
    for oversampled_image, oversampled_label in zip(oversampled_images, oversampled_labels):
        yield oversampled_image.reshape(images.shape[1:]), oversampled_label

def undersample_images_generator(images, labels):
    undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
    undersampled_images, undersampled_labels = undersampler.fit_resample(images.reshape(len(images), -1), labels)
    for undersampled_image, undersampled_label in zip(undersampled_images, undersampled_labels):
        yield undersampled_image.reshape(images.shape[1:]), undersampled_label

tracked_images = []
for df in tqdm(data_list, desc="Tracking image label"):
    fundus = df['fundus']
    file_path = os.path.join(output_folder, fundus)
    image = cv2.imread(file_path)
    if image is not None:
        label = df['class']
        tracked_images.append((image, label))

# Memisahkan gambar dan label menjadi dua array terpisah
tracked_images_array = np.array([x[0] for x in tracked_images])
labels_array = np.array([x[1] for x in tracked_images])

unique_classes = np.unique(labels_array)
num_classes = len(unique_classes)
print("Jumlah kelas: ", num_classes)

# Melakukan oversampling
oversampled_images = np.array([oversampled_image for oversampled_image, _ in oversample_images_generator(tracked_images_array, labels_array)])
oversampled_labels = np.array([oversampled_label for _, oversampled_label in oversample_images_generator(tracked_images_array, labels_array)])
print("Proses selesai. Gambar telah di oversample.")

# Melakukan undersampling
undersampled_images = np.array([undersampled_image for undersampled_image, _ in undersample_images_generator(tracked_images_array, labels_array)])
undersampled_labels = np.array([undersampled_label for _, undersampled_label in undersample_images_generator(tracked_images_array, labels_array)])
print("Proses selesai. Gambar telah di undersample.")

# Fungsi untuk menyimpan gambar ke dalam folder
def save_images(images, labels, output_folder):
    for i, (image, label) in enumerate(zip(images, labels)):
        fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
        file_path = os.path.join(output_folder, fundus)
        cv2.imwrite(file_path, image)

# Menyimpan hasil oversampling
save_images(oversampled_images, oversampled_labels, output_folder_oversampled)

# Menyimpan hasil undersampling
save_images(undersampled_images, undersampled_labels, output_folder_undersampled)

# Fungsi untuk melakukan histogram equalization pada gambar
def histogram_equalization(image):
    # Ubah gambar ke skala keabuan jika belum
    if len(image.shape) > 2:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image

    # Lakukan histogram equalization
    equalized = cv2.equalizeHist(gray)

    equalized = cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

    return equalized

# Fungsi untuk melakukan histogram equalization pada gambar
def clahe(image):
    # Ubah gambar ke skala keabuan jika belum
    if len(image.shape) > 2:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image

    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    enhanced_image = clahe.apply(gray)

    enhanced_image = cv2.cvtColor(enhanced_image, cv2.COLOR_GRAY2BGR)

    return enhanced_image

# Folder untuk menyimpan gambar-gambar hasil konversi
output_folder_equalized = "/kaggle/working/output_equalized/"
output_folder_clahe = "/kaggle/working/output_clahe/"
# output_folder_stretched = "output_stretched/"

# Membuat folder output jika belum ada
os.makedirs(output_folder_equalized, exist_ok=True)
os.makedirs(output_folder_clahe, exist_ok=True)

# Fungsi untuk menyimpan gambar ke dalam folder
def save_images(images, labels, output_folder):
    for i, (image, label) in enumerate(zip(images, labels)):
        fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
        file_path = os.path.join(output_folder, fundus)
        cv2.imwrite(file_path, image)

# Melakukan histogram equalization pada gambar-gambar hasil oversampling
for i in tqdm(range(len(oversampled_images)), desc="CLAHE-ing Images"):
    oversampled_images[i] = clahe(oversampled_images[i])

# Menyimpan hasil histogram equalization
save_images(oversampled_images, oversampled_labels, output_folder_clahe)

# Melakukan histogram equalization pada gambar-gambar hasil oversampling
for i in tqdm(range(len(oversampled_images)), desc="Equalizing Images"):
    oversampled_images[i] = histogram_equalization(oversampled_images[i])

# Menyimpan hasil contrast stretching
save_images(oversampled_images, oversampled_labels, output_folder_equalized)
# Out:
# Tracking image label: 100%|██████████| 8470/8470 [00:03<00:00, 2200.57it/s]
# Jumlah kelas:  7
# Proses selesai. Gambar telah di oversample.
# Proses selesai. Gambar telah di undersample.
# CLAHE-ing Images: 100%|██████████| 39781/39781 [00:13<00:00, 2998.28it/s]
# Equalizing Images: 100%|██████████| 39781/39781 [00:05<00:00, 6675.06it/s]

# %%
def split_data(input_folder, output_folder, train_ratio, keywords):
    # Membuat folder output jika belum ada
    os.makedirs(output_folder, exist_ok=True)

    # Hapus konten folder output jika ada
    for filename in os.listdir(output_folder):
        file_path = os.path.join(output_folder, filename)
        if os.path.isfile(file_path):
            os.remove(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)

    # Daftar semua file gambar dalam folder input
    image_files = [file for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

    # Acak urutan file gambar
    random.shuffle(image_files)

    # Tentukan jumlah data training dan testing berdasarkan rasio yang diberikan
    num_train = int(len(image_files) * train_ratio)

    # Bagi data ke dalam folder training dan testing
    train_output_folder = os.path.join(output_folder, 'train')
    test_output_folder = os.path.join(output_folder, 'test')
    os.makedirs(train_output_folder, exist_ok=True)
    os.makedirs(test_output_folder, exist_ok=True)

    # Salin data training dan testing berdasarkan keyword
    for filename in tqdm(image_files[:num_train], desc="Splitting for training data"):
        src_path = os.path.join(input_folder, filename)
        for keyword in keywords:
            if keyword in filename:
                class_name = keyword
                break
        else:
            class_name = "other"

        dst_path = os.path.join(train_output_folder, class_name, filename)
        os.makedirs(os.path.join(train_output_folder, class_name), exist_ok=True)
        shutil.copy(src_path, dst_path)

    for filename in tqdm(image_files[num_train:], desc="Splitting for testing data"):
        src_path = os.path.join(input_folder, filename)
        for keyword in keywords:
            if keyword in filename:
                class_name = keyword
                break
        else:
            class_name = "other"

        dst_path = os.path.join(test_output_folder, class_name, filename)
        os.makedirs(os.path.join(test_output_folder, class_name), exist_ok=True)
        shutil.copy(src_path, dst_path)

    print("Proses split data selesai.")

# Splitting gambar
input_folder = "/kaggle/working/output_clahe/"
output_folder = "/kaggle/working/output_splitting/"
train_ratio = 0.7  # Rasio data training (0.7 = 70% training, 30% testing)

split_data(input_folder, output_folder, train_ratio, keywords)
# Out:
# Splitting for training data: 100%|██████████| 27846/27846 [00:03<00:00, 7663.70it/s]
# Splitting for testing data: 100%|██████████| 11935/11935 [00:01<00:00, 7596.61it/s]
# Proses split data selesai.

# %%
# Definisikan path folder data training dan testing
train_data_dir = '/kaggle/working/output_splitting/train/'
test_data_dir = '/kaggle/working/output_splitting/test/'

# Definisikan parameter untuk pelatihan model
input_shape = (224, 224, 3)
batch_size = 256
epochs = 200
num_classes = 7

# test_datagen = ImageDataGenerator(rescale=1.0/255)

# Buat generator data pelatihan dan pengujian tanpa augmentasi
train_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=input_shape[:2],  # Sesuaikan dengan input_shape
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=input_shape[:2],  # Sesuaikan dengan input_shape
    batch_size=batch_size,
    class_mode='categorical'
)

# Create a VGG19 model
vgg = VGG19(input_shape=input_shape , weights='imagenet', include_top=False)

# This sets the base that the layers are not trainable. If we'd want to train the layers with custom data, these two lines can be ommitted. 
for layer in vgg.layers:
  layer.trainable = False

# # Menggunakan beberapa lapisan convolutional terakhir
# for layer in vgg.layers[:-4]:
#     layer.trainable = True

# Stacking a new simple convolutional network on top of it    
x = Flatten()(vgg.output)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(num_classes, activation='softmax')(x)

#Creating model object 
model = Model(inputs=vgg.input, outputs=x)

model.summary()

# Define learning rate schedule function
def lr_schedule(epoch):
    initial_lr = 0.01
    drop = 0.5
    epochs_drop = 10.0
    lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lr

# Define callbacks
checkpoint_vgg = ModelCheckpoint('model.save', monitor='val_loss', save_best_only=True, verbose=1)
early_stopping_vgg = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
lr_scheduler = LearningRateScheduler(lr_schedule)  # Learning Rate Scheduler callback

callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback, lr_scheduler]

#Compile the model 
sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd_optimizer, metrics=['accuracy'])
# adam_optimizer = Adam(learning_rate=0.0001)
history = model.fit(train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)

# Evaluasi model pada data pelatihan
y_train_true = train_generator.classes
y_train_pred_probs = model.predict(train_generator)
y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# Confusion Matrix pada data pelatihan
conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_train, annot=True, fmt='g', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
plt.title('Confusion Matrix (Training)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
plt.savefig("Confusion_Matrix_Train.png")

# Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix (Training)
accuracy_train = np.trace(conf_matrix_train) / np.sum(conf_matrix_train)
precision_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=0)
recall_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=1)
f1_score_train = 2 * (precision_train * recall_train) / (precision_train + recall_train)

# Print the values (Training)
for i, class_name in enumerate(train_generator.class_indices.keys()):
    print(f'Class: {class_name}')
    print(f'  Accuracy (Train): {accuracy_train:.2f}')
    print(f'  Precision (Train): {precision_train[i]:.2f}')
    print(f'  Recall (Train): {recall_train[i]:.2f}')
    print(f'  F1-Score (Train): {f1_score_train[i]:.2f}')

# ROC Curve and AUC pada data pelatihan
fpr_train = dict()
tpr_train = dict()
roc_auc_train = dict()

for i in range(num_classes):
    fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
    roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])

# Plot ROC Curve pada data pelatihan
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (Training)')
plt.legend()
plt.show()
plt.savefig("ROC_Curve_Train.png")

# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig("LossVal_loss.png")

# accuracies
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig("AccVal_acc.png")

# Evaluasi model pada data pelatihan
y_train_true = train_generator.classes
y_train_pred_probs = model.predict(train_generator)
y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# Confusion Matrix pada data pelatihan
conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_train, annot=True, fmt='g', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
plt.title('Confusion Matrix (Training)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
plt.savefig("Confusion_Matrix_Train.png")

# Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix (Training)
accuracy_train = np.trace(conf_matrix_train) / np.sum(conf_matrix_train)
precision_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=0)
recall_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=1)
f1_score_train = 2 * (precision_train * recall_train) / (precision_train + recall_train)

# Print the values (Training)
for i, class_name in enumerate(train_generator.class_indices.keys()):
    print(f'Class: {class_name}')
    print(f'  Accuracy (Train): {accuracy_train:.2f}')
    print(f'  Precision (Train): {precision_train[i]:.2f}')
    print(f'  Recall (Train): {recall_train[i]:.2f}')
    print(f'  F1-Score (Train): {f1_score_train[i]:.2f}')

# ROC Curve and AUC pada data pelatihan
fpr_train = dict()
tpr_train = dict()
roc_auc_train = dict()

for i in range(num_classes):
    fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
    roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])

# Plot ROC Curve pada data pelatihan
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (Training)')
plt.legend()
plt.show()
plt.savefig("ROC_Curve_Train.png")

# Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
model = load_model('model.save')

# Evaluasi model pada data uji
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
plt.savefig("Confusion_Matrix.png")

# Classification Report
class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
print("Classification Report:\n", class_report)

# Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
f1_score = 2 * (precision * recall) / (precision + recall)

# Print the values
for i, class_name in enumerate(test_generator.class_indices.keys()):
    print(f'Class: {class_name}')
    print(f'  Accuracy: {accuracy:.2f}')
    print(f'  Precision: {precision[i]:.2f}')
    print(f'  Recall: {recall[i]:.2f}')
    print(f'  F1-Score: {f1_score[i]:.2f}')

# ROC Curve and AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curve
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
plt.savefig("ROC_Curve.png")
# Out:
# Found 27846 images belonging to 7 classes.
# Found 11935 images belonging to 7 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  batch_normalization (Batch  (None, 25088)             100352
#  Normalization)
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  batch_normalization_1 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 45827143 (174.82 MB)
# Trainable params: 25750535 (98.23 MB)
# Non-trainable params: 20076608 (76.59 MB)
# _________________________________________________________________
# Epoch 1/200
# 109/109 [==============================] - ETA: 0s - loss: 2.9138 - accuracy: 0.6872
# Epoch 1: val_loss improved from inf to 2.75187, saving model to model.save
# 109/109 [==============================] - 130s 1s/step - loss: 2.9138 - accuracy: 0.6872 - val_loss: 2.7519 - val_accuracy: 0.7059 - lr: 0.0100
# Epoch 2/200
# 109/109 [==============================] - ETA: 0s - loss: 2.4216 - accuracy: 0.8245
# Epoch 2: val_loss improved from 2.75187 to 2.37976, saving model to model.save
# 109/109 [==============================] - 93s 856ms/step - loss: 2.4216 - accuracy: 0.8245 - val_loss: 2.3798 - val_accuracy: 0.8464 - lr: 0.0100
# Epoch 3/200
# 109/109 [==============================] - ETA: 0s - loss: 2.2601 - accuracy: 0.8554
# Epoch 3: val_loss improved from 2.37976 to 2.16970, saving model to model.save
# 109/109 [==============================] - 93s 854ms/step - loss: 2.2601 - accuracy: 0.8554 - val_loss: 2.1697 - val_accuracy: 0.8827 - lr: 0.0100
# Epoch 4/200
# 109/109 [==============================] - ETA: 0s - loss: 2.1524 - accuracy: 0.8700
# Epoch 4: val_loss improved from 2.16970 to 2.03475, saving model to model.save
# 109/109 [==============================] - 96s 875ms/step - loss: 2.1524 - accuracy: 0.8700 - val_loss: 2.0347 - val_accuracy: 0.9109 - lr: 0.0100
# Epoch 5/200
# 109/109 [==============================] - ETA: 0s - loss: 2.0654 - accuracy: 0.8789
# Epoch 5: val_loss improved from 2.03475 to 1.93461, saving model to model.save
# 109/109 [==============================] - 93s 853ms/step - loss: 2.0654 - accuracy: 0.8789 - val_loss: 1.9346 - val_accuracy: 0.9213 - lr: 0.0100
# Epoch 6/200
# 109/109 [==============================] - ETA: 0s - loss: 1.9711 - accuracy: 0.8915
# Epoch 6: val_loss improved from 1.93461 to 1.83706, saving model to model.save
# 109/109 [==============================] - 94s 860ms/step - loss: 1.9711 - accuracy: 0.8915 - val_loss: 1.8371 - val_accuracy: 0.9295 - lr: 0.0100
# Epoch 7/200
# 109/109 [==============================] - ETA: 0s - loss: 1.8931 - accuracy: 0.8984
# Epoch 7: val_loss improved from 1.83706 to 1.77784, saving model to model.save
# 109/109 [==============================] - 93s 850ms/step - loss: 1.8931 - accuracy: 0.8984 - val_loss: 1.7778 - val_accuracy: 0.9277 - lr: 0.0100
# Epoch 8/200
# 109/109 [==============================] - ETA: 0s - loss: 1.8322 - accuracy: 0.8961
# Epoch 8: val_loss improved from 1.77784 to 1.70418, saving model to model.save
# 109/109 [==============================] - 93s 853ms/step - loss: 1.8322 - accuracy: 0.8961 - val_loss: 1.7042 - val_accuracy: 0.9325 - lr: 0.0100
# Epoch 9/200
# 109/109 [==============================] - ETA: 0s - loss: 1.7600 - accuracy: 0.9022
# Epoch 9: val_loss improved from 1.70418 to 1.66001, saving model to model.save
# 109/109 [==============================] - 94s 859ms/step - loss: 1.7600 - accuracy: 0.9022 - val_loss: 1.6600 - val_accuracy: 0.9326 - lr: 0.0100
# Epoch 10/200
# 109/109 [==============================] - ETA: 0s - loss: 1.6912 - accuracy: 0.9108
# Epoch 10: val_loss improved from 1.66001 to 1.59663, saving model to model.save
# 109/109 [==============================] - 93s 855ms/step - loss: 1.6912 - accuracy: 0.9108 - val_loss: 1.5966 - val_accuracy: 0.9345 - lr: 0.0050
# Epoch 11/200
# 109/109 [==============================] - ETA: 0s - loss: 1.6395 - accuracy: 0.9158
# Epoch 11: val_loss improved from 1.59663 to 1.55667, saving model to model.save
# 109/109 [==============================] - 94s 860ms/step - loss: 1.6395 - accuracy: 0.9158 - val_loss: 1.5567 - val_accuracy: 0.9414 - lr: 0.0050
# Epoch 12/200
# 109/109 [==============================] - ETA: 0s - loss: 1.5986 - accuracy: 0.9200
# Epoch 12: val_loss improved from 1.55667 to 1.52117, saving model to model.save
# 109/109 [==============================] - 93s 856ms/step - loss: 1.5986 - accuracy: 0.9200 - val_loss: 1.5212 - val_accuracy: 0.9403 - lr: 0.0050
# Epoch 13/200
# 109/109 [==============================] - ETA: 0s - loss: 1.5617 - accuracy: 0.9220
# Epoch 13: val_loss improved from 1.52117 to 1.49831, saving model to model.save
# 109/109 [==============================] - 94s 860ms/step - loss: 1.5617 - accuracy: 0.9220 - val_loss: 1.4983 - val_accuracy: 0.9419 - lr: 0.0050
# Epoch 14/200
# 109/109 [==============================] - ETA: 0s - loss: 1.5329 - accuracy: 0.9219
# Epoch 14: val_loss improved from 1.49831 to 1.47383, saving model to model.save
# 109/109 [==============================] - 93s 854ms/step - loss: 1.5329 - accuracy: 0.9219 - val_loss: 1.4738 - val_accuracy: 0.9424 - lr: 0.0050
# Epoch 15/200
# 109/109 [==============================] - ETA: 0s - loss: 1.4988 - accuracy: 0.9244
# Epoch 15: val_loss improved from 1.47383 to 1.43622, saving model to model.save
# 109/109 [==============================] - 94s 857ms/step - loss: 1.4988 - accuracy: 0.9244 - val_loss: 1.4362 - val_accuracy: 0.9421 - lr: 0.0050
# Epoch 16/200
# 109/109 [==============================] - ETA: 0s - loss: 1.4751 - accuracy: 0.9247
# Epoch 16: val_loss improved from 1.43622 to 1.42419, saving model to model.save
# 109/109 [==============================] - 93s 854ms/step - loss: 1.4751 - accuracy: 0.9247 - val_loss: 1.4242 - val_accuracy: 0.9390 - lr: 0.0050
# Epoch 17/200
# 109/109 [==============================] - ETA: 0s - loss: 1.4464 - accuracy: 0.9244
# Epoch 17: val_loss improved from 1.42419 to 1.39958, saving model to model.save
# 109/109 [==============================] - 94s 858ms/step - loss: 1.4464 - accuracy: 0.9244 - val_loss: 1.3996 - val_accuracy: 0.9406 - lr: 0.0050
# Epoch 18/200
# 109/109 [==============================] - ETA: 0s - loss: 1.4147 - accuracy: 0.9266
# Epoch 18: val_loss improved from 1.39958 to 1.36308, saving model to model.save
# 109/109 [==============================] - 94s 858ms/step - loss: 1.4147 - accuracy: 0.9266 - val_loss: 1.3631 - val_accuracy: 0.9417 - lr: 0.0050
# Epoch 19/200
# 109/109 [==============================] - ETA: 0s - loss: 1.3906 - accuracy: 0.9270
# Epoch 19: val_loss improved from 1.36308 to 1.32524, saving model to model.save
# 109/109 [==============================] - 93s 852ms/step - loss: 1.3906 - accuracy: 0.9270 - val_loss: 1.3252 - val_accuracy: 0.9435 - lr: 0.0050
# Epoch 20/200
# 109/109 [==============================] - ETA: 0s - loss: 1.3578 - accuracy: 0.9290
# Epoch 20: val_loss improved from 1.32524 to 1.31759, saving model to model.save
# 109/109 [==============================] - 93s 854ms/step - loss: 1.3578 - accuracy: 0.9290 - val_loss: 1.3176 - val_accuracy: 0.9428 - lr: 0.0025
# Epoch 21/200
# 109/109 [==============================] - ETA: 0s - loss: 1.3398 - accuracy: 0.9309
# Epoch 21: val_loss improved from 1.31759 to 1.30464, saving model to model.save
# 109/109 [==============================] - 93s 856ms/step - loss: 1.3398 - accuracy: 0.9309 - val_loss: 1.3046 - val_accuracy: 0.9415 - lr: 0.0025
# Epoch 22/200
# 109/109 [==============================] - ETA: 0s - loss: 1.3231 - accuracy: 0.9329
# Epoch 22: val_loss improved from 1.30464 to 1.28928, saving model to model.save
# 109/109 [==============================] - 93s 855ms/step - loss: 1.3231 - accuracy: 0.9329 - val_loss: 1.2893 - val_accuracy: 0.9423 - lr: 0.0025
# Epoch 23/200
# 109/109 [==============================] - ETA: 0s - loss: 1.3072 - accuracy: 0.9338
# Epoch 23: val_loss improved from 1.28928 to 1.27681, saving model to model.save
# 109/109 [==============================] - 94s 859ms/step - loss: 1.3072 - accuracy: 0.9338 - val_loss: 1.2768 - val_accuracy: 0.9431 - lr: 0.0025
# Epoch 24/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2985 - accuracy: 0.9324
# Epoch 24: val_loss improved from 1.27681 to 1.26126, saving model to model.save
# 109/109 [==============================] - 93s 856ms/step - loss: 1.2985 - accuracy: 0.9324 - val_loss: 1.2613 - val_accuracy: 0.9429 - lr: 0.0025
# Epoch 25/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2850 - accuracy: 0.9341
# Epoch 25: val_loss improved from 1.26126 to 1.25305, saving model to model.save
# 109/109 [==============================] - 94s 858ms/step - loss: 1.2850 - accuracy: 0.9341 - val_loss: 1.2530 - val_accuracy: 0.9464 - lr: 0.0025
# Epoch 26/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2678 - accuracy: 0.9343
# Epoch 26: val_loss improved from 1.25305 to 1.23493, saving model to model.save
# 109/109 [==============================] - 93s 855ms/step - loss: 1.2678 - accuracy: 0.9343 - val_loss: 1.2349 - val_accuracy: 0.9452 - lr: 0.0025
# Epoch 27/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2574 - accuracy: 0.9334
# Epoch 27: val_loss improved from 1.23493 to 1.21798, saving model to model.save
# 109/109 [==============================] - 94s 859ms/step - loss: 1.2574 - accuracy: 0.9334 - val_loss: 1.2180 - val_accuracy: 0.9459 - lr: 0.0025
# Epoch 28/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2407 - accuracy: 0.9362
# Epoch 28: val_loss improved from 1.21798 to 1.20714, saving model to model.save
# 109/109 [==============================] - 93s 855ms/step - loss: 1.2407 - accuracy: 0.9362 - val_loss: 1.2071 - val_accuracy: 0.9469 - lr: 0.0025
# Epoch 29/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2317 - accuracy: 0.9359
# Epoch 29: val_loss improved from 1.20714 to 1.20713, saving model to model.save
# 109/109 [==============================] - 94s 860ms/step - loss: 1.2317 - accuracy: 0.9359 - val_loss: 1.2071 - val_accuracy: 0.9450 - lr: 0.0025
# Epoch 30/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2226 - accuracy: 0.9346
# Epoch 30: val_loss improved from 1.20713 to 1.19080, saving model to model.save
# 109/109 [==============================] - 94s 857ms/step - loss: 1.2226 - accuracy: 0.9346 - val_loss: 1.1908 - val_accuracy: 0.9455 - lr: 0.0012
# Epoch 31/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2088 - accuracy: 0.9371
# Epoch 31: val_loss improved from 1.19080 to 1.18399, saving model to model.save
# 109/109 [==============================] - 94s 857ms/step - loss: 1.2088 - accuracy: 0.9371 - val_loss: 1.1840 - val_accuracy: 0.9466 - lr: 0.0012
# Epoch 32/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2055 - accuracy: 0.9365
# Epoch 32: val_loss improved from 1.18399 to 1.17986, saving model to model.save
# 109/109 [==============================] - 94s 863ms/step - loss: 1.2055 - accuracy: 0.9365 - val_loss: 1.1799 - val_accuracy: 0.9468 - lr: 0.0012
# Epoch 33/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1956 - accuracy: 0.9377
# Epoch 33: val_loss improved from 1.17986 to 1.17603, saving model to model.save
# 109/109 [==============================] - 93s 856ms/step - loss: 1.1956 - accuracy: 0.9377 - val_loss: 1.1760 - val_accuracy: 0.9443 - lr: 0.0012
# Epoch 34/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1876 - accuracy: 0.9388
# Epoch 34: val_loss improved from 1.17603 to 1.16706, saving model to model.save
# 109/109 [==============================] - 94s 858ms/step - loss: 1.1876 - accuracy: 0.9388 - val_loss: 1.1671 - val_accuracy: 0.9468 - lr: 0.0012
# Epoch 35/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1823 - accuracy: 0.9394
# Epoch 35: val_loss improved from 1.16706 to 1.16369, saving model to model.save
# 109/109 [==============================] - 94s 864ms/step - loss: 1.1823 - accuracy: 0.9394 - val_loss: 1.1637 - val_accuracy: 0.9455 - lr: 0.0012
# Epoch 36/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1759 - accuracy: 0.9385
# Epoch 36: val_loss improved from 1.16369 to 1.15447, saving model to model.save
# 109/109 [==============================] - 94s 858ms/step - loss: 1.1759 - accuracy: 0.9385 - val_loss: 1.1545 - val_accuracy: 0.9444 - lr: 0.0012
# Epoch 37/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1666 - accuracy: 0.9403
# Epoch 37: val_loss improved from 1.15447 to 1.15048, saving model to model.save
# 109/109 [==============================] - 94s 861ms/step - loss: 1.1666 - accuracy: 0.9403 - val_loss: 1.1505 - val_accuracy: 0.9450 - lr: 0.0012
# Epoch 38/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1626 - accuracy: 0.9397
# Epoch 38: val_loss improved from 1.15048 to 1.14842, saving model to model.save
# 109/109 [==============================] - 93s 853ms/step - loss: 1.1626 - accuracy: 0.9397 - val_loss: 1.1484 - val_accuracy: 0.9449 - lr: 0.0012
# Epoch 39/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1554 - accuracy: 0.9388
# Epoch 39: val_loss improved from 1.14842 to 1.13767, saving model to model.save
# 109/109 [==============================] - 94s 857ms/step - loss: 1.1554 - accuracy: 0.9388 - val_loss: 1.1377 - val_accuracy: 0.9467 - lr: 0.0012
# Epoch 40/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1488 - accuracy: 0.9407
# Epoch 40: val_loss did not improve from 1.13767
# 109/109 [==============================] - 90s 823ms/step - loss: 1.1488 - accuracy: 0.9407 - val_loss: 1.1403 - val_accuracy: 0.9468 - lr: 6.2500e-04
# Epoch 41/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1447 - accuracy: 0.9421
# Epoch 41: val_loss improved from 1.13767 to 1.13563, saving model to model.save
# 109/109 [==============================] - 93s 854ms/step - loss: 1.1447 - accuracy: 0.9421 - val_loss: 1.1356 - val_accuracy: 0.9470 - lr: 6.2500e-04
# Epoch 42/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1435 - accuracy: 0.9400
# Epoch 42: val_loss improved from 1.13563 to 1.12918, saving model to model.save
# 109/109 [==============================] - 94s 865ms/step - loss: 1.1435 - accuracy: 0.9400 - val_loss: 1.1292 - val_accuracy: 0.9477 - lr: 6.2500e-04
# Epoch 43/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1443 - accuracy: 0.9384
# Epoch 43: val_loss improved from 1.12918 to 1.12628, saving model to model.save
# 109/109 [==============================] - 94s 856ms/step - loss: 1.1443 - accuracy: 0.9384 - val_loss: 1.1263 - val_accuracy: 0.9481 - lr: 6.2500e-04
# Epoch 44/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1439 - accuracy: 0.9385
# Epoch 44: val_loss improved from 1.12628 to 1.12103, saving model to model.save
# 109/109 [==============================] - 94s 860ms/step - loss: 1.1439 - accuracy: 0.9385 - val_loss: 1.1210 - val_accuracy: 0.9483 - lr: 6.2500e-04
# Epoch 45/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1344 - accuracy: 0.9407
# Epoch 45: val_loss improved from 1.12103 to 1.11846, saving model to model.save
# 109/109 [==============================] - 94s 863ms/step - loss: 1.1344 - accuracy: 0.9407 - val_loss: 1.1185 - val_accuracy: 0.9473 - lr: 6.2500e-04
# Epoch 46/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1290 - accuracy: 0.9419
# Epoch 46: val_loss improved from 1.11846 to 1.11792, saving model to model.save
# 109/109 [==============================] - 93s 855ms/step - loss: 1.1290 - accuracy: 0.9419 - val_loss: 1.1179 - val_accuracy: 0.9475 - lr: 6.2500e-04
# Epoch 47/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1302 - accuracy: 0.9404
# Epoch 47: val_loss improved from 1.11792 to 1.11652, saving model to model.save
# 109/109 [==============================] - 93s 855ms/step - loss: 1.1302 - accuracy: 0.9404 - val_loss: 1.1165 - val_accuracy: 0.9453 - lr: 6.2500e-04
# Epoch 48/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1273 - accuracy: 0.9398
# Epoch 48: val_loss improved from 1.11652 to 1.10787, saving model to model.save
# 109/109 [==============================] - 94s 860ms/step - loss: 1.1273 - accuracy: 0.9398 - val_loss: 1.1079 - val_accuracy: 0.9462 - lr: 6.2500e-04
# Epoch 49/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1242 - accuracy: 0.9406
# Epoch 49: val_loss improved from 1.10787 to 1.10507, saving model to model.save
# 109/109 [==============================] - 94s 856ms/step - loss: 1.1242 - accuracy: 0.9406 - val_loss: 1.1051 - val_accuracy: 0.9478 - lr: 6.2500e-04
# Epoch 50/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1207 - accuracy: 0.9415
# Epoch 50: val_loss did not improve from 1.10507
# 109/109 [==============================] - 90s 828ms/step - loss: 1.1207 - accuracy: 0.9415 - val_loss: 1.1072 - val_accuracy: 0.9466 - lr: 3.1250e-04
# Epoch 51/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1177 - accuracy: 0.9419
# Epoch 51: val_loss improved from 1.10507 to 1.10320, saving model to model.save
# 109/109 [==============================] - 94s 860ms/step - loss: 1.1177 - accuracy: 0.9419 - val_loss: 1.1032 - val_accuracy: 0.9471 - lr: 3.1250e-04
# Epoch 52/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1164 - accuracy: 0.9418
# Epoch 52: val_loss did not improve from 1.10320
# 109/109 [==============================] - 90s 826ms/step - loss: 1.1164 - accuracy: 0.9418 - val_loss: 1.1076 - val_accuracy: 0.9458 - lr: 3.1250e-04
# Epoch 53/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1109 - accuracy: 0.9440
# Epoch 53: val_loss improved from 1.10320 to 1.09824, saving model to model.save
# 109/109 [==============================] - 93s 852ms/step - loss: 1.1109 - accuracy: 0.9440 - val_loss: 1.0982 - val_accuracy: 0.9474 - lr: 3.1250e-04
# Epoch 54/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1166 - accuracy: 0.9420
# Epoch 54: val_loss did not improve from 1.09824
# 109/109 [==============================] - 91s 830ms/step - loss: 1.1166 - accuracy: 0.9420 - val_loss: 1.0987 - val_accuracy: 0.9473 - lr: 3.1250e-04
# Epoch 55/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1141 - accuracy: 0.9404
# Epoch 55: val_loss did not improve from 1.09824
# 109/109 [==============================] - 90s 827ms/step - loss: 1.1141 - accuracy: 0.9404 - val_loss: 1.1015 - val_accuracy: 0.9465 - lr: 3.1250e-04
# Epoch 56/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1102 - accuracy: 0.9409
# Epoch 56: val_loss did not improve from 1.09824
# 109/109 [==============================] - 90s 828ms/step - loss: 1.1102 - accuracy: 0.9409 - val_loss: 1.0983 - val_accuracy: 0.9466 - lr: 3.1250e-04
# Epoch 57/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1099 - accuracy: 0.9418
# Epoch 57: val_loss improved from 1.09824 to 1.09176, saving model to model.save
# 109/109 [==============================] - 94s 857ms/step - loss: 1.1099 - accuracy: 0.9418 - val_loss: 1.0918 - val_accuracy: 0.9479 - lr: 3.1250e-04
# Epoch 58/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1090 - accuracy: 0.9421
# Epoch 58: val_loss did not improve from 1.09176
# 109/109 [==============================] - 91s 828ms/step - loss: 1.1090 - accuracy: 0.9421 - val_loss: 1.0957 - val_accuracy: 0.9481 - lr: 3.1250e-04
# Epoch 59/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1065 - accuracy: 0.9419
# Epoch 59: val_loss did not improve from 1.09176
# 109/109 [==============================] - 90s 825ms/step - loss: 1.1065 - accuracy: 0.9419 - val_loss: 1.0919 - val_accuracy: 0.9482 - lr: 3.1250e-04
# Epoch 60/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1049 - accuracy: 0.9418
# Epoch 60: val_loss improved from 1.09176 to 1.09051, saving model to model.save
# 109/109 [==============================] - 95s 865ms/step - loss: 1.1049 - accuracy: 0.9418 - val_loss: 1.0905 - val_accuracy: 0.9489 - lr: 1.5625e-04
# Epoch 61/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1033 - accuracy: 0.9437
# Epoch 61: val_loss did not improve from 1.09051
# 109/109 [==============================] - 90s 827ms/step - loss: 1.1033 - accuracy: 0.9437 - val_loss: 1.0960 - val_accuracy: 0.9474 - lr: 1.5625e-04
# Epoch 62/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1034 - accuracy: 0.9420
# Epoch 62: val_loss did not improve from 1.09051
# 109/109 [==============================] - 91s 830ms/step - loss: 1.1034 - accuracy: 0.9420 - val_loss: 1.0940 - val_accuracy: 0.9474 - lr: 1.5625e-04
# Epoch 63/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0993 - accuracy: 0.9434
# Epoch 63: val_loss improved from 1.09051 to 1.08952, saving model to model.save
# 109/109 [==============================] - 94s 862ms/step - loss: 1.0993 - accuracy: 0.9434 - val_loss: 1.0895 - val_accuracy: 0.9486 - lr: 1.5625e-04
# Epoch 64/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0953 - accuracy: 0.9439
# Epoch 64: val_loss did not improve from 1.08952
# 109/109 [==============================] - 90s 828ms/step - loss: 1.0953 - accuracy: 0.9439 - val_loss: 1.0907 - val_accuracy: 0.9483 - lr: 1.5625e-04
# Epoch 65/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1015 - accuracy: 0.9414
# Epoch 65: val_loss did not improve from 1.08952
# 109/109 [==============================] - 90s 828ms/step - loss: 1.1015 - accuracy: 0.9414 - val_loss: 1.0923 - val_accuracy: 0.9475 - lr: 1.5625e-04
# Epoch 66/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0996 - accuracy: 0.9418
# Epoch 66: val_loss did not improve from 1.08952
# 109/109 [==============================] - 91s 830ms/step - loss: 1.0996 - accuracy: 0.9418 - val_loss: 1.0924 - val_accuracy: 0.9482 - lr: 1.5625e-04
# Epoch 67/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.9427
# Epoch 67: val_loss did not improve from 1.08952
# 109/109 [==============================] - 90s 826ms/step - loss: 1.0986 - accuracy: 0.9427 - val_loss: 1.0932 - val_accuracy: 0.9474 - lr: 1.5625e-04
# Epoch 68/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0950 - accuracy: 0.9437
# Epoch 68: val_loss did not improve from 1.08952
# 109/109 [==============================] - 90s 828ms/step - loss: 1.0950 - accuracy: 0.9437 - val_loss: 1.0904 - val_accuracy: 0.9464 - lr: 1.5625e-04
# Epoch 69/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0969 - accuracy: 0.9426
# Epoch 69: val_loss improved from 1.08952 to 1.08190, saving model to model.save
# 109/109 [==============================] - 93s 854ms/step - loss: 1.0969 - accuracy: 0.9426 - val_loss: 1.0819 - val_accuracy: 0.9494 - lr: 1.5625e-04
# Epoch 70/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0958 - accuracy: 0.9422
# Epoch 70: val_loss did not improve from 1.08190
# 109/109 [==============================] - 91s 836ms/step - loss: 1.0958 - accuracy: 0.9422 - val_loss: 1.0861 - val_accuracy: 0.9479 - lr: 7.8125e-05
# Epoch 71/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0979 - accuracy: 0.9417
# Epoch 71: val_loss did not improve from 1.08190
# 109/109 [==============================] - 90s 826ms/step - loss: 1.0979 - accuracy: 0.9417 - val_loss: 1.0860 - val_accuracy: 0.9481 - lr: 7.8125e-05
# Epoch 72/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0929 - accuracy: 0.9434
# Epoch 72: val_loss did not improve from 1.08190
# 109/109 [==============================] - 90s 827ms/step - loss: 1.0929 - accuracy: 0.9434 - val_loss: 1.0876 - val_accuracy: 0.9478 - lr: 7.8125e-05
# Epoch 73/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0957 - accuracy: 0.9433
# Epoch 73: val_loss did not improve from 1.08190
# 109/109 [==============================] - 90s 824ms/step - loss: 1.0957 - accuracy: 0.9433 - val_loss: 1.0854 - val_accuracy: 0.9480 - lr: 7.8125e-05
# Epoch 74/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0962 - accuracy: 0.9428
# Epoch 74: val_loss did not improve from 1.08190
# 109/109 [==============================] - 91s 831ms/step - loss: 1.0962 - accuracy: 0.9428 - val_loss: 1.0911 - val_accuracy: 0.9469 - lr: 7.8125e-05
# Epoch 75/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0945 - accuracy: 0.9424
# Epoch 75: val_loss did not improve from 1.08190
# 109/109 [==============================] - 90s 824ms/step - loss: 1.0945 - accuracy: 0.9424 - val_loss: 1.0840 - val_accuracy: 0.9481 - lr: 7.8125e-05
# Epoch 76/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0926 - accuracy: 0.9424
# Epoch 76: val_loss did not improve from 1.08190
# 109/109 [==============================] - 90s 826ms/step - loss: 1.0926 - accuracy: 0.9424 - val_loss: 1.0890 - val_accuracy: 0.9475 - lr: 7.8125e-05
# Epoch 77/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0929 - accuracy: 0.9438
# Epoch 77: val_loss did not improve from 1.08190
# 109/109 [==============================] - 90s 824ms/step - loss: 1.0929 - accuracy: 0.9438 - val_loss: 1.0846 - val_accuracy: 0.9475 - lr: 7.8125e-05
# Epoch 78/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0928 - accuracy: 0.9428
# Epoch 78: val_loss did not improve from 1.08190
# 109/109 [==============================] - 90s 827ms/step - loss: 1.0928 - accuracy: 0.9428 - val_loss: 1.0907 - val_accuracy: 0.9456 - lr: 7.8125e-05
# Epoch 79/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0923 - accuracy: 0.9436
# Epoch 79: val_loss did not improve from 1.08190
# Restoring model weights from the end of the best epoch: 69.
# 109/109 [==============================] - 90s 827ms/step - loss: 1.0923 - accuracy: 0.9436 - val_loss: 1.0840 - val_accuracy: 0.9485 - lr: 7.8125e-05
# Epoch 79: early stopping
# 109/109 [==============================] - 57s 524ms/step
# Class: age-related macular degeneration
#   Accuracy (Train): 0.14
#   Precision (Train): 0.14
#   Recall (Train): 0.14
#   F1-Score (Train): 0.14
# Class: cataract
#   Accuracy (Train): 0.14
#   Precision (Train): 0.15
#   Recall (Train): 0.15
#   F1-Score (Train): 0.15
# Class: diabetic
#   Accuracy (Train): 0.14
#   Precision (Train): 0.14
#   Recall (Train): 0.17
#   F1-Score (Train): 0.15
# Class: glaucoma
#   Accuracy (Train): 0.14
#   Precision (Train): 0.15
#   Recall (Train): 0.14
#   F1-Score (Train): 0.14
# Class: hypertensive
#   Accuracy (Train): 0.14
#   Precision (Train): 0.14
#   Recall (Train): 0.14
#   F1-Score (Train): 0.14
# Class: myopia
#   Accuracy (Train): 0.14
#   Precision (Train): 0.14
#   Recall (Train): 0.14
#   F1-Score (Train): 0.14
# Class: normal
#   Accuracy (Train): 0.14
#   Precision (Train): 0.13
#   Recall (Train): 0.13
#   F1-Score (Train): 0.13
# 109/109 [==============================] - 57s 526ms/step
# Class: age-related macular degeneration
#   Accuracy (Train): 0.14
#   Precision (Train): 0.15
#   Recall (Train): 0.14
#   F1-Score (Train): 0.14
# Class: cataract
#   Accuracy (Train): 0.14
#   Precision (Train): 0.14
#   Recall (Train): 0.14
#   F1-Score (Train): 0.14
# Class: diabetic
#   Accuracy (Train): 0.14
#   Precision (Train): 0.14
#   Recall (Train): 0.17
#   F1-Score (Train): 0.15
# Class: glaucoma
#   Accuracy (Train): 0.14
#   Precision (Train): 0.14
#   Recall (Train): 0.13
#   F1-Score (Train): 0.14
# Class: hypertensive
#   Accuracy (Train): 0.14
#   Precision (Train): 0.13
#   Recall (Train): 0.13
#   F1-Score (Train): 0.13
# Class: myopia
#   Accuracy (Train): 0.14
#   Precision (Train): 0.13
#   Recall (Train): 0.14
#   F1-Score (Train): 0.14
# Class: normal
#   Accuracy (Train): 0.14
#   Precision (Train): 0.14
#   Recall (Train): 0.14
#   F1-Score (Train): 0.14
# 47/47 [==============================] - 25s 525ms/step
# Classification Report:
#                                    precision    recall  f1-score   support
#
# age-related macular degeneration       0.14      0.14      0.14      1670
#                         cataract       0.15      0.15      0.15      1690
#                         diabetic       0.15      0.17      0.16      1720
#                         glaucoma       0.13      0.13      0.13      1662
#                     hypertensive       0.14      0.14      0.14      1741
#                           myopia       0.14      0.14      0.14      1717
#                           normal       0.13      0.13      0.13      1735
#
#                         accuracy                           0.14     11935
#                        macro avg       0.14      0.14      0.14     11935
#                     weighted avg       0.14      0.14      0.14     11935
#
# Class: age-related macular degeneration
#   Accuracy: 0.14
#   Precision: 0.14
#   Recall: 0.14
#   F1-Score: 0.14
# Class: cataract
#   Accuracy: 0.14
#   Precision: 0.15
#   Recall: 0.15
#   F1-Score: 0.15
# Class: diabetic
#   Accuracy: 0.14
#   Precision: 0.15
#   Recall: 0.17
#   F1-Score: 0.16
# Class: glaucoma
#   Accuracy: 0.14
#   Precision: 0.13
#   Recall: 0.13
#   F1-Score: 0.13
# Class: hypertensive
#   Accuracy: 0.14
#   Precision: 0.14
#   Recall: 0.14
#   F1-Score: 0.14
# Class: myopia
#   Accuracy: 0.14
#   Precision: 0.14
#   Recall: 0.14
#   F1-Score: 0.14
# Class: normal
#   Accuracy: 0.14
#   Precision: 0.13
#   Recall: 0.13
#   F1-Score: 0.13

# %%
# # Path ke gambar yang akan diuji
# test_image_path = 'path/to/your/test/image.jpg'  # Ganti dengan path gambar yang ingin diuji

# # Praproses gambar agar sesuai dengan format input model
# img = image.load_img(test_image_path, target_size=input_shape[:2])
# img_array = image.img_to_array(img)
# img_array = np.expand_dims(img_array, axis=0)
# img_array /= 255.0

# # Load model yang sudah disimpan
# saved_model_path = 'path/to/your/saved/model.h5'  # Ganti dengan path model yang sudah disimpan
# model = load_model(saved_model_path)

# # Lakukan prediksi menggunakan model
# prediction_probs = model.predict(img_array)
# predicted_class = np.argmax(prediction_probs)

# # Tampilkan hasil prediksi
# class_labels = list(test_generator.class_indices.keys())
# predicted_class_label = class_labels[predicted_class]
# prediction_accuracy = prediction_probs[0, predicted_class] * 100

# print(f'Predicted Class: {predicted_class_label}')
# print(f'Prediction Accuracy: {prediction_accuracy:.2f}%')

# %%
# tensorboard --logdir /kaggle/working/logs/fit

# %%
# from tensorboard import notebook

# # Load the TensorBoard notebook extension
# notebook.display(port=6006, height=1000)

# %load_ext tensorboard
# %tensorboard --logdir=/kaggle/working/logs/fit

# %%
import zipfile
import os
from IPython.display import FileLink

def zip_dir(directory = os.curdir, file_name = 'directory.zip'):
    os.chdir(directory)
    zip_ref = zipfile.ZipFile(file_name, mode='w')
    for folder, _, files in os.walk(directory):
        for file in files:
            if file_name in file:
                pass
            else:
                zip_ref.write(os.path.join(folder, file))

    return FileLink(file_name)

zip_dir()
# Out:
# /kaggle/working/directory.zip
