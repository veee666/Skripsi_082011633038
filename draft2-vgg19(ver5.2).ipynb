# %%
import cv2
import datetime
import os
import pandas as pd
import numpy as np
import shutil
import seaborn as sns
import random
import math
import tensorflow as tf
import sys
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from matplotlib import pyplot as plt
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from keras import applications, regularizers
from keras.applications.vgg19 import VGG19
from keras.applications.mobilenet import MobileNet
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, LearningRateScheduler
from keras.models import Model, Sequential, load_model
from keras.layers import Conv2D, Dense, Flatten, MaxPooling2D, Dropout, Activation, BatchNormalization
from keras.optimizers import Adam, RMSprop, SGD
from keras.initializers import he_normal
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from tqdm import tqdm
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Import image description data
df_data = pd.read_csv("/kaggle/input/ocular-disease-recognition-odir5k/full_df.csv")

df_data2 = df_data.iloc[:, 1:7]

# "myopia", "hypertensive", "diabetic", "age-related macular degeneration", "glaucoma",

# Daftar kata kunci yang ingin dicari
keywords = ["cataract", "normal", "myopia", "hypertensive", "diabetic", "age-related macular degeneration", "glaucoma"]  # Ganti dengan kata kunci yang diinginkan

# Fungsi untuk mencari kata kunci dalam DataFrame
def search_keywords(data_frame, keyword):
    left_diagnosis = data_frame[data_frame['Left-Diagnostic Keywords'].str.contains(keyword)]
    right_diagnosis = data_frame[data_frame['Right-Diagnostic Keywords'].str.contains(keyword)]
    combined = pd.concat((left_diagnosis['Left-Fundus'], right_diagnosis['Right-Fundus']))

    df_result = pd.DataFrame(combined, columns=['fundus'])
    df_result['class'] = keyword
    return df_result

# Mencari semua kata kunci dalam satu langkah
dfs = []
for keyword in keywords:
    df_keyword = search_keywords(df_data2, keyword)
    dfs.append(df_keyword)

# Menggabungkan hasil pencarian kata kunci
result_df = pd.concat(dfs)

# Menyimpan DataFrame dalam file XLSX
result_df.to_excel('merge.xlsx', index=False)

# Convert DataFrame ke bentuk JSON
data_list = result_df.to_dict(orient='records')


def resize_image(img, target_size):
    # Mendapatkan dimensi gambar asli
    original_height, original_width = img.shape[:2]

    # Mendapatkan dimensi target
    target_width, target_height = target_size

    # Menghitung rasio skala lebar dan tinggi
    width_ratio = target_width / original_width
    height_ratio = target_height / original_height

    # Menentukan rasio skala yang akan digunakan untuk resizing
    scale_ratio = min(width_ratio, height_ratio)

    # Menghitung ukuran baru setelah penskalaan
    new_width = int(original_width * scale_ratio)
    new_height = int(original_height * scale_ratio)

    # Melakukan resizing gambar dengan opsi interporasi yang baik
    resized_img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_AREA)

    # Membuat latar belakang gambar dengan ukuran target
    background = (0, 0, 0)  # Hitam

    # Membuat gambar dengan ukuran target yang tepat
    top_padding = (target_height - new_height) // 2
    bottom_padding = target_height - new_height - top_padding
    left_padding = (target_width - new_width) // 2
    right_padding = target_width - new_width - left_padding

    # Menggunakan padding untuk membuat latar belakang dengan ukuran target
    background_img = cv2.copyMakeBorder(resized_img, top_padding, bottom_padding, left_padding, right_padding, cv2.BORDER_CONSTANT, value=background)

    return background_img

## Read image and preprocessing
def process_images(input_folder, output_folder):
    # Membuat folder output jika belum ada
    os.makedirs(output_folder, exist_ok=True)

    # Loop melalui semua file dalam folder
    for filename in os.listdir(output_folder):

        os.remove(os.path.join(output_folder, filename))

    print("Isi file dalam folder output telah dihapus.")

    # Mendapatkan daftar file gambar di dalam folder input
    image_files = [file for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

    # Loop melalui daftar file gambar
    for image_file in tqdm(image_files, desc="Processing images"):
        # Membaca gambar
        image_path = os.path.join(input_folder, image_file)
        image = cv2.imread(image_path)

        # Ubah ukuran gambar
        target_size = (224, 224)  # Ubah ukuran sesuai kebutuhan Anda
        # resized_image = cv2.resize(image, target_size)
        resized_image = resize_image(image, target_size)
        # cropped_image = crop_padding(resized_image)

        # Ubah format warna gambar
        colored_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

        # Simpan gambar ke folder output dengan nama yang sama
        output_path = os.path.join(output_folder, image_file)
        cv2.imwrite(output_path, colored_image)

    print("Proses selesai. Gambar-gambar telah disimpan di folder output.")

# Preprocessing gambar
input_folder = "/kaggle/input/ocular-disease-recognition-odir5k/ODIR-5K/ODIR-5K/Training Images"
output_folder = "/kaggle/working/output_preprocessing/"

process_images(input_folder, output_folder)
# Out:
# Isi file dalam folder output telah dihapus.
# Processing images: 100%|██████████| 7000/7000 [09:16<00:00, 12.58it/s]
# Proses selesai. Gambar-gambar telah disimpan di folder output.

# %%
# Folder untuk menyimpan gambar-gambar hasil konversi
output_folder_oversampled = "/kaggle/working/output_oversample/"
output_folder_undersampled = "/kaggle/working/output_undersample/"

# Membuat folder output jika belum ada
os.makedirs(output_folder_oversampled, exist_ok=True)
os.makedirs(output_folder_undersampled, exist_ok=True)

def oversample_images_generator(images, labels):
    oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
    oversampled_images, oversampled_labels = oversampler.fit_resample(images.reshape(len(images), -1), labels)
    for oversampled_image, oversampled_label in zip(oversampled_images, oversampled_labels):
        yield oversampled_image.reshape(images.shape[1:]), oversampled_label

def undersample_images_generator(images, labels):
    undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
    undersampled_images, undersampled_labels = undersampler.fit_resample(images.reshape(len(images), -1), labels)
    for undersampled_image, undersampled_label in zip(undersampled_images, undersampled_labels):
        yield undersampled_image.reshape(images.shape[1:]), undersampled_label

tracked_images = []
for df in tqdm(data_list, desc="Tracking image label"):
    fundus = df['fundus']
    file_path = os.path.join(output_folder, fundus)
    image = cv2.imread(file_path)
    if image is not None:
        label = df['class']
        tracked_images.append((image, label))

# Memisahkan gambar dan label menjadi dua array terpisah
tracked_images_array = np.array([x[0] for x in tracked_images])
labels_array = np.array([x[1] for x in tracked_images])

unique_classes = np.unique(labels_array)
num_classes = len(unique_classes)
print("Jumlah kelas: ", num_classes)

# Melakukan oversampling
oversampled_images = np.array([oversampled_image for oversampled_image, _ in oversample_images_generator(tracked_images_array, labels_array)])
oversampled_labels = np.array([oversampled_label for _, oversampled_label in oversample_images_generator(tracked_images_array, labels_array)])
print("Proses selesai. Gambar telah di oversample.")

# Melakukan undersampling
undersampled_images = np.array([undersampled_image for undersampled_image, _ in undersample_images_generator(tracked_images_array, labels_array)])
undersampled_labels = np.array([undersampled_label for _, undersampled_label in undersample_images_generator(tracked_images_array, labels_array)])
print("Proses selesai. Gambar telah di undersample.")

# Fungsi untuk menyimpan gambar ke dalam folder
def save_images(images, labels, output_folder):
    for i, (image, label) in enumerate(zip(images, labels)):
        fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
        file_path = os.path.join(output_folder, fundus)
        cv2.imwrite(file_path, image)

# Menyimpan hasil oversampling
save_images(oversampled_images, oversampled_labels, output_folder_oversampled)

# Menyimpan hasil undersampling
save_images(undersampled_images, undersampled_labels, output_folder_undersampled)

# Fungsi untuk melakukan histogram equalization pada gambar
def histogram_equalization(image):
    # Ubah gambar ke skala keabuan jika belum
    if len(image.shape) > 2:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image

    # Lakukan histogram equalization
    equalized = cv2.equalizeHist(gray)

    equalized = cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

    return equalized

# Fungsi untuk melakukan histogram equalization pada gambar
def clahe(image):
    clahe = cv2.createCLAHE(clipLimit=10, tileGridSize=(8,8))
    lab = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # convert from BGR to LAB color space
#     l, a, b = cv2.split(lab)  # split on 3 different channels
    l2 = clahe.apply(lab)  # apply CLAHE to the L-channel
#     lab = cv2.merge((l2,a,b))  # merge channels
#     image = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)  # convert from LAB to BGR
    image = cv2.cvtColor(l2, cv2.COLOR_GRAY2BGR)
    return image

# Folder untuk menyimpan gambar-gambar hasil konversi
output_folder_equalized = "/kaggle/working/output_equalized/"
output_folder_clahe = "/kaggle/working/output_clahe/"

# Membuat folder output jika belum ada
os.makedirs(output_folder_equalized, exist_ok=True)
os.makedirs(output_folder_clahe, exist_ok=True)

# Fungsi untuk menyimpan gambar ke dalam folder
def save_images(images, labels, output_folder):
    for i, (image, label) in enumerate(zip(images, labels)):
        fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
        file_path = os.path.join(output_folder, fundus)
        cv2.imwrite(file_path, image)

# Melakukan histogram equalization pada gambar-gambar hasil oversampling
for i in tqdm(range(len(oversampled_images)), desc="CLAHE-ing Images"):
    oversampled_images[i] = clahe(oversampled_images[i])

# Menyimpan hasil histogram equalization
save_images(oversampled_images, oversampled_labels, output_folder_clahe)

# Melakukan histogram equalization pada gambar-gambar hasil oversampling
for i in tqdm(range(len(oversampled_images)), desc="Equalizing Images"):
    oversampled_images[i] = histogram_equalization(oversampled_images[i])

# Menyimpan hasil contrast stretching
save_images(oversampled_images, oversampled_labels, output_folder_equalized)
# Out:
# Tracking image label: 100%|██████████| 8470/8470 [00:03<00:00, 2121.40it/s]
# Jumlah kelas:  7
# Proses selesai. Gambar telah di oversample.
# Proses selesai. Gambar telah di undersample.
# CLAHE-ing Images: 100%|██████████| 39781/39781 [00:14<00:00, 2774.42it/s]
# Equalizing Images: 100%|██████████| 39781/39781 [00:06<00:00, 6387.53it/s]

# %%
def split_data(input_folder, output_folder, train_ratio, keywords):
    # Membuat folder output jika belum ada
    os.makedirs(output_folder, exist_ok=True)

    # Hapus konten folder output jika ada
    for filename in os.listdir(output_folder):
        file_path = os.path.join(output_folder, filename)
        if os.path.isfile(file_path):
            os.remove(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)

    # Daftar semua file gambar dalam folder input
    image_files = [file for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

    # Acak urutan file gambar
    random.shuffle(image_files)

    # Tentukan jumlah data training dan testing berdasarkan rasio yang diberikan
    num_train = int(len(image_files) * train_ratio)

    # Bagi data ke dalam folder training dan testing
    train_output_folder = os.path.join(output_folder, 'train')
    test_output_folder = os.path.join(output_folder, 'test')
    os.makedirs(train_output_folder, exist_ok=True)
    os.makedirs(test_output_folder, exist_ok=True)

    # Salin data training dan testing berdasarkan keyword
    for filename in tqdm(image_files[:num_train], desc="Splitting for training data"):
        src_path = os.path.join(input_folder, filename)
        for keyword in keywords:
            if keyword in filename:
                class_name = keyword
                break
        else:
            class_name = "other"

        dst_path = os.path.join(train_output_folder, class_name, filename)
        os.makedirs(os.path.join(train_output_folder, class_name), exist_ok=True)
        shutil.copy(src_path, dst_path)

    for filename in tqdm(image_files[num_train:], desc="Splitting for testing data"):
        src_path = os.path.join(input_folder, filename)
        for keyword in keywords:
            if keyword in filename:
                class_name = keyword
                break
        else:
            class_name = "other"

        dst_path = os.path.join(test_output_folder, class_name, filename)
        os.makedirs(os.path.join(test_output_folder, class_name), exist_ok=True)
        shutil.copy(src_path, dst_path)

    print("Proses split data selesai.")

# Splitting gambar
input_folder = "/kaggle/working/output_clahe/"
output_folder = "/kaggle/working/output_splitting/"
train_ratio = 0.7  # Rasio data training (0.7 = 70% training, 20% testing)

split_data(input_folder, output_folder, train_ratio, keywords)
# Out:
# Splitting for training data: 100%|██████████| 27846/27846 [00:03<00:00, 7119.20it/s]
# Splitting for testing data: 100%|██████████| 11935/11935 [00:01<00:00, 7303.27it/s]
# Proses split data selesai.

# %%
# # Definisikan path folder data training dan testing
# train_data_dir = '/kaggle/working/output_splitting/train/'
# test_data_dir = '/kaggle/working/output_splitting/test/'

# # Definisikan parameter untuk pelatihan model
# input_shape = (224, 224, 3)
# batch_size = 256
# epochs = 200
# num_classes = 7

# # test_datagen = ImageDataGenerator(rescale=1.0/255)

# # Buat generator data pelatihan dan pengujian tanpa augmentasi
# train_datagen = ImageDataGenerator(rescale=1.0/255)
# test_datagen = ImageDataGenerator(rescale=1.0/255)

# train_generator = train_datagen.flow_from_directory(
#     train_data_dir,
#     target_size=input_shape[:2],  # Sesuaikan dengan input_shape
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# test_generator = test_datagen.flow_from_directory(
#     test_data_dir,
#     target_size=input_shape[:2],  # Sesuaikan dengan input_shape
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# # Create a VGG19 model
# vgg = VGG19(input_shape=input_shape , weights='imagenet', include_top=False)

# # # This sets the base that the layers are not trainable. If we'd want to train the layers with custom data, these two lines can be ommitted. 
# # for layer in vgg.layers:
# #   layer.trainable = False

# # Unfreeze the last three blocks (15th to 17th blocks)
# for layer in vgg.layers[:-3]:
#     layer.trainable = False

# # Create a new model on top of VGG19
# model = Sequential()
# model.add(vgg)

# # Additional Convolutional Layers
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=(2, 2)))

# # Flatten and Fully Connected Layers
# model.add(Flatten())
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
# model.add(Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
# model.add(Dense(num_classes, activation='softmax'))

# model.summary()

# # Define callbacks
# checkpoint_vgg = ModelCheckpoint('model.save', monitor='val_loss', save_best_only=True, verbose=1)
# early_stopping_vgg = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)
# log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
# # lr_scheduler = LearningRateScheduler(lr_schedule)  # Learning Rate Scheduler callback

# callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback]
# # callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback, lr_scheduler]

# #Compile the model 
# # sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
# adam_optimizer = Adam(learning_rate=0.01)
# model.compile(loss='categorical_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
# history = model.fit(train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)

# # loss
# plt.plot(history.history['loss'], label='train loss')
# plt.plot(history.history['val_loss'], label='val loss')
# plt.legend()
# plt.show()
# plt.savefig("LossVal_loss.png")

# # accuracies
# plt.plot(history.history['accuracy'], label='train acc')
# plt.plot(history.history['val_accuracy'], label='val acc')
# plt.legend()
# plt.show()
# plt.savefig("AccVal_acc.png")

# # Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
# model = load_model('model.save')

# # Confusion Matrix and Classification Report
# Y_pred = model.predict(test_generator)
# y_pred = np.argmax(Y_pred, axis=1)
# print('Confusion Matrix')
# print(confusion_matrix(test_generator.classes, y_pred))
# print('Classification Report')
# print(classification_report(test_generator.classes, y_pred, target_names=train_generator.class_indices))

# # AUC-ROC Curve
# def plot_auc_roc_curve(model, test_generator):
#     y_true = test_generator.classes
#     y_score = model.predict(test_generator)
    
#     fpr, tpr, thresholds = roc_curve(y_true, y_score, pos_label=None)
#     auc = roc_auc_score(y_true, y_score, multi_class='ovr')
    
#     plt.figure(figsize=(8, 8))
#     plt.plot(fpr, tpr, color='darkorange', lw=2, label='AUC = {:.2f}'.format(auc))
#     plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.title('Receiver Operating Characteristic (ROC) Curve')
#     plt.legend(loc='lower right')
#     plt.show()

# plot_auc_roc_curve(model, test_generator)

# # Loss
# plt.plot(history.history['loss'], label='train loss')
# plt.plot(history.history['val_loss'], label='val loss')
# plt.legend()
# plt.show()
# plt.savefig("LossVal_loss.png")

# # Accuracies
# plt.plot(history.history['accuracy'], label='train acc')
# plt.plot(history.history['val_accuracy'], label='val acc')
# plt.legend()
# plt.show()
# plt.savefig("AccVal_acc.png")

# # # Evaluasi model pada data pelatihan
# # y_train_true = train_generator.classes
# # y_train_pred_probs = model.predict(train_generator)
# # y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# # # Confusion Matrix pada data pelatihan
# # conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)
# # plt.figure(figsize=(8, 6))
# # sns.heatmap(conf_matrix_train, annot=True, fmt='g', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
# # plt.title('Confusion Matrix (Training)')
# # plt.xlabel('Predicted')
# # plt.ylabel('True')
# # plt.show()
# # plt.savefig("Confusion_Matrix_Train.png")

# # # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix (Training)
# # accuracy_train = np.trace(conf_matrix_train) / np.sum(conf_matrix_train)
# # precision_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=0)
# # recall_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=1)
# # f1_score_train = 2 * (precision_train * recall_train) / (precision_train + recall_train)

# # # Calculate overall metrics
# # overall_precision_train = np.mean(precision_train)
# # overall_recall_train = np.mean(recall_train)
# # overall_f1_score_train = np.mean(f1_score_train)

# # # Calculate micro-average ROC-AUC
# # fpr_micro, tpr_micro, _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes).ravel(), y_train_pred_probs.ravel())
# # roc_auc_micro = auc(fpr_micro, tpr_micro)

# # # Print the overall values (Testing) including AUC-ROC
# # print('Overall Metrics (Testing):')
# # print(f'  Accuracy: {accuracy_train:.2f}')
# # print(f'  Precision: {overall_precision:.2f}')
# # print(f'  Recall: {overall_recall:.2f}')
# # print(f'  F1-Score: {overall_f1_score:.2f}')
# # print(f'  AUC-ROC: {roc_auc_micro:.2f}')

# # # AUC ROC pada data pelatihan
# # roc_auc_train_macro = roc_auc_score(to_categorical(y_train_true, num_classes=num_classes), y_train_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))

# # # Plot AUC for the macro average
# # fpr_train_macro, tpr_train_macro, _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes).ravel(), y_train_pred_probs.ravel())
# # roc_auc_train_macro = auc(fpr_train_macro, tpr_train_macro)
# # plt.plot(fpr_train_macro, tpr_train_macro, label=f'Macro (AUC = {roc_auc_train_macro:.2f})')

# # # Plot AUC for each class
# # fpr_train = dict()
# # tpr_train = dict()
# # roc_auc_train = dict()
# # for i in range(num_classes):
# #     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
# #     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])
# #     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Training)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Train.png")

# # # Print the values (Training)
# # for i, class_name in enumerate(train_generator.class_indices.keys()):
# #     print(f'Class: {class_name}')
# #     print(f'  Accuracy (Train): {accuracy_train:.2f}')
# #     print(f'  Precision (Train): {precision_train[i]:.2f}')
# #     print(f'  Recall (Train): {recall_train[i]:.2f}')
# #     print(f'  F1-Score (Train): {f1_score_train[i]:.2f}')

# # # ROC Curve and AUC pada data pelatihan
# # fpr_train = dict()
# # tpr_train = dict()
# # roc_auc_train = dict()

# # # AUC ROC pada data pelatihan
# # roc_auc_train_macro = roc_auc_score(to_categorical(y_train_true, num_classes=num_classes), y_train_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # plt.plot(fpr_train, tpr_train, label=f'Macro (AUC = {roc_auc_train_macro:.2f})')

# # for i in range(num_classes):
# #     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
# #     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # for i in range(num_classes):
# #     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Training)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Train.png")

# # # Evaluasi model pada data uji
# # y_true = test_generator.classes
# # y_pred_probs = model.predict(test_generator)
# # y_pred = np.argmax(y_pred_probs, axis=1)

# # # Confusion Matrix
# # conf_matrix = confusion_matrix(y_true, y_pred)
# # plt.figure(figsize=(8, 6))
# # sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
# # plt.title('Confusion Matrix')
# # plt.xlabel('Predicted')
# # plt.ylabel('True')
# # plt.show()
# # plt.savefig("Confusion_Matrix.png")

# # # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
# # accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
# # precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
# # recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
# # f1_score = 2 * (precision * recall) / (precision + recall)

# # # Calculate overall metrics
# # overall_precision = np.mean(precision)
# # overall_recall = np.mean(recall)
# # overall_f1_score = np.mean(f1_score)

# # # AUC-ROC
# # fpr = dict()
# # tpr = dict()
# # roc_auc = dict()

# # for i in range(num_classes):
# #     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
# #     roc_auc[i] = auc(fpr[i], tpr[i])

# # # Print the overall values (Testing) including AUC-ROC
# # print('Overall Metrics:')
# # print(f'  Accuracy: {accuracy:.2f}')
# # print(f'  Precision: {overall_precision:.2f}')
# # print(f'  Recall: {overall_recall:.2f}')
# # print(f'  F1-Score: {overall_f1_score:.2f}')
# # print(f'  AUC-ROC: {roc_auc:.2f}')

# # # Plot ROC Curve
# # plt.figure(figsize=(10, 8))
# # for i in range(num_classes):
# #     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve')
# # plt.legend()
# # plt.show()

# # # Classification Report
# # class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
# # print("Classification Report:\n", class_report)

# # # Print the values
# # for i, class_name in enumerate(test_generator.class_indices.keys()):
# #     print(f'Class: {class_name}')
# #     print(f'  Accuracy: {accuracy:.2f}')
# #     print(f'  Precision: {precision[i]:.2f}')
# #     print(f'  Recall: {recall[i]:.2f}')
# #     print(f'  F1-Score: {f1_score[i]:.2f}')

# # # ROC Curve and AUC
# # fpr = dict()
# # tpr = dict()
# # roc_auc = dict()

# # # AUC ROC pada data pelatihan
# # roc_auc_test_macro = roc_auc_score(to_categorical(y_true, num_classes=num_classes), y_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # plt.plot(fpr, tpr, label=f'Macro (AUC = {roc_auc_test_macro:.2f})')

# # # for i in range(num_classes):
# # #     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
# # #     roc_auc[i] = auc(fpr[i], tpr[i])

# # # # Plot ROC Curve
# # # plt.figure(figsize=(10, 8))
# # # for i in range(num_classes):
# # #     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Testing)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Test.png")

# %%
# # Evaluasi model pada data pelatihan
# y_train_true = train_generator.classes
# y_train_pred_probs = model.predict(train_generator)
# y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# # Confusion Matrix pada data pelatihan
# conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix_train, annot=True, fmt='g', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
# plt.title('Confusion Matrix (Training)')
# plt.xlabel('Predicted')
# plt.ylabel('True')
# plt.show()
# plt.savefig("Confusion_Matrix_Train.png")

# # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix (Training)
# accuracy_train = np.trace(conf_matrix_train) / np.sum(conf_matrix_train)
# precision_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=0)
# recall_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=1)
# f1_score_train = 2 * (precision_train * recall_train) / (precision_train + recall_train)

# # Print the values (Training)
# for i, class_name in enumerate(train_generator.class_indices.keys()):
#     print(f'Class: {class_name}')
#     print(f'  Accuracy (Train): {accuracy_train:.2f}')
#     print(f'  Precision (Train): {precision_train[i]:.2f}')
#     print(f'  Recall (Train): {recall_train[i]:.2f}')
#     print(f'  F1-Score (Train): {f1_score_train[i]:.2f}')

# # ROC Curve and AUC pada data pelatihan
# fpr_train = dict()
# tpr_train = dict()
# roc_auc_train = dict()

# for i in range(num_classes):
#     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
#     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])

# # Plot ROC Curve pada data pelatihan
# plt.figure(figsize=(10, 8))
# for i in range(num_classes):
#     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# plt.plot([0, 1], [0, 1], 'k--', label='Random')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve (Training)')
# plt.legend()
# plt.show()
# plt.savefig("ROC_Curve_Train.png")

# %%
# Definisikan path folder data training dan testing
train_data_dir = '/kaggle/working/output_splitting/train/'
test_data_dir = '/kaggle/working/output_splitting/test/'

# Definisikan parameter untuk pelatihan model
input_shape = (224, 224, 3)
batch_size = 256
epochs = 200
num_classes = 7

# test_datagen = ImageDataGenerator(rescale=1.0/255)

# Buat generator data pelatihan dan pengujian tanpa augmentasi
train_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=input_shape[:2],  # Sesuaikan dengan input_shape
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=input_shape[:2],  # Sesuaikan dengan input_shape
    batch_size=batch_size,
    class_mode='categorical'
)

# Create a VGG19 model
vgg = VGG19(input_shape=input_shape , weights='imagenet', include_top=False)

# Unfreeze the last three blocks (15th to 17th blocks)
for layer in vgg.layers[:-3]:
    layer.trainable = False

# Stacking a new simple convolutional network on top of it    
x = Flatten()(vgg.output)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(num_classes, activation='softmax')(x)

#Creating model object 
model = Model(inputs=vgg.input, outputs=x)

model.summary()

# Define callbacks
checkpoint_vgg = ModelCheckpoint('model.save', monitor='val_loss', save_best_only=True, verbose=1)
early_stopping_vgg = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
# lr_scheduler = LearningRateScheduler(lr_schedule)  # Learning Rate Scheduler callback

callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback]

#Compile the model 
sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd_optimizer, metrics=['accuracy'])
# adam_optimizer = Adam(learning_rate=0.0001)
history = model.fit(train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)

# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig("LossVal_loss.png")

# accuracies
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig("AccVal_acc.png")

# Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
model = load_model('model.save')

# Evaluasi model pada data uji
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
plt.savefig("Confusion_Matrix.png")

# Classification Report
class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
print("Classification Report:\n", class_report)

# Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
f1_score = 2 * (precision * recall) / (precision + recall)

# Print the values
for i, class_name in enumerate(test_generator.class_indices.keys()):
    print(f'Class: {class_name}')
    print(f'  Accuracy: {accuracy:.2f}')
    print(f'  Precision: {precision[i]:.2f}')
    print(f'  Recall: {recall[i]:.2f}')
    print(f'  F1-Score: {f1_score[i]:.2f}')

# ROC Curve and AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curve
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
plt.savefig("ROC_Curve.png")
# Out:
# Found 27846 images belonging to 7 classes.
# Found 11935 images belonging to 7 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 4s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  batch_normalization (Batch  (None, 25088)             100352
#  Normalization)
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  batch_normalization_1 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 45827143 (174.82 MB)
# Trainable params: 30470151 (116.23 MB)
# Non-trainable params: 15356992 (58.58 MB)
# _________________________________________________________________
# Epoch 1/200
# 109/109 [==============================] - ETA: 0s - loss: 3.0553 - accuracy: 0.6282
# Epoch 1: val_loss improved from inf to 4.83634, saving model to model.save
# 109/109 [==============================] - 139s 1s/step - loss: 3.0553 - accuracy: 0.6282 - val_loss: 4.8363 - val_accuracy: 0.4558
# Epoch 2/200
# 109/109 [==============================] - ETA: 0s - loss: 2.4298 - accuracy: 0.8082
# Epoch 2: val_loss improved from 4.83634 to 3.17024, saving model to model.save
# 109/109 [==============================] - 100s 914ms/step - loss: 2.4298 - accuracy: 0.8082 - val_loss: 3.1702 - val_accuracy: 0.6032
# Epoch 3/200
# 109/109 [==============================] - ETA: 0s - loss: 2.1910 - accuracy: 0.8707
# Epoch 3: val_loss did not improve from 3.17024
# 109/109 [==============================] - 96s 880ms/step - loss: 2.1910 - accuracy: 0.8707 - val_loss: 3.4281 - val_accuracy: 0.5514
# Epoch 4/200
# 109/109 [==============================] - ETA: 0s - loss: 2.0460 - accuracy: 0.8969
# Epoch 4: val_loss improved from 3.17024 to 2.61373, saving model to model.save
# 109/109 [==============================] - 99s 904ms/step - loss: 2.0460 - accuracy: 0.8969 - val_loss: 2.6137 - val_accuracy: 0.7292
# Epoch 5/200
# 109/109 [==============================] - ETA: 0s - loss: 1.9295 - accuracy: 0.9119
# Epoch 5: val_loss improved from 2.61373 to 2.19592, saving model to model.save
# 109/109 [==============================] - 100s 913ms/step - loss: 1.9295 - accuracy: 0.9119 - val_loss: 2.1959 - val_accuracy: 0.8159
# Epoch 6/200
# 109/109 [==============================] - ETA: 0s - loss: 1.8190 - accuracy: 0.9258
# Epoch 6: val_loss improved from 2.19592 to 2.09387, saving model to model.save
# 109/109 [==============================] - 99s 906ms/step - loss: 1.8190 - accuracy: 0.9258 - val_loss: 2.0939 - val_accuracy: 0.8497
# Epoch 7/200
# 109/109 [==============================] - ETA: 0s - loss: 1.7341 - accuracy: 0.9319
# Epoch 7: val_loss improved from 2.09387 to 1.86792, saving model to model.save
# 109/109 [==============================] - 99s 906ms/step - loss: 1.7341 - accuracy: 0.9319 - val_loss: 1.8679 - val_accuracy: 0.8830
# Epoch 8/200
# 109/109 [==============================] - ETA: 0s - loss: 1.6567 - accuracy: 0.9347
# Epoch 8: val_loss improved from 1.86792 to 1.74744, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 1.6567 - accuracy: 0.9347 - val_loss: 1.7474 - val_accuracy: 0.9084
# Epoch 9/200
# 109/109 [==============================] - ETA: 0s - loss: 1.5793 - accuracy: 0.9393
# Epoch 9: val_loss improved from 1.74744 to 1.58039, saving model to model.save
# 109/109 [==============================] - 99s 907ms/step - loss: 1.5793 - accuracy: 0.9393 - val_loss: 1.5804 - val_accuracy: 0.9377
# Epoch 10/200
# 109/109 [==============================] - ETA: 0s - loss: 1.5081 - accuracy: 0.9436
# Epoch 10: val_loss improved from 1.58039 to 1.56007, saving model to model.save
# 109/109 [==============================] - 99s 904ms/step - loss: 1.5081 - accuracy: 0.9436 - val_loss: 1.5601 - val_accuracy: 0.9288
# Epoch 11/200
# 109/109 [==============================] - ETA: 0s - loss: 1.4556 - accuracy: 0.9422
# Epoch 11: val_loss improved from 1.56007 to 1.43317, saving model to model.save
# 109/109 [==============================] - 99s 907ms/step - loss: 1.4556 - accuracy: 0.9422 - val_loss: 1.4332 - val_accuracy: 0.9375
# Epoch 12/200
# 109/109 [==============================] - ETA: 0s - loss: 1.3892 - accuracy: 0.9446
# Epoch 12: val_loss did not improve from 1.43317
# 109/109 [==============================] - 96s 880ms/step - loss: 1.3892 - accuracy: 0.9446 - val_loss: 1.4473 - val_accuracy: 0.9101
# Epoch 13/200
# 109/109 [==============================] - ETA: 0s - loss: 1.3232 - accuracy: 0.9482
# Epoch 13: val_loss improved from 1.43317 to 1.42084, saving model to model.save
# 109/109 [==============================] - 99s 907ms/step - loss: 1.3232 - accuracy: 0.9482 - val_loss: 1.4208 - val_accuracy: 0.9195
# Epoch 14/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2746 - accuracy: 0.9482
# Epoch 14: val_loss did not improve from 1.42084
# 109/109 [==============================] - 95s 870ms/step - loss: 1.2746 - accuracy: 0.9482 - val_loss: 1.4748 - val_accuracy: 0.8881
# Epoch 15/200
# 109/109 [==============================] - ETA: 0s - loss: 1.2179 - accuracy: 0.9516
# Epoch 15: val_loss improved from 1.42084 to 1.34104, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 1.2179 - accuracy: 0.9516 - val_loss: 1.3410 - val_accuracy: 0.9052
# Epoch 16/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1708 - accuracy: 0.9505
# Epoch 16: val_loss improved from 1.34104 to 1.19074, saving model to model.save
# 109/109 [==============================] - 98s 902ms/step - loss: 1.1708 - accuracy: 0.9505 - val_loss: 1.1907 - val_accuracy: 0.9320
# Epoch 17/200
# 109/109 [==============================] - ETA: 0s - loss: 1.1262 - accuracy: 0.9502
# Epoch 17: val_loss improved from 1.19074 to 1.15115, saving model to model.save
# 109/109 [==============================] - 98s 898ms/step - loss: 1.1262 - accuracy: 0.9502 - val_loss: 1.1511 - val_accuracy: 0.9405
# Epoch 18/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0810 - accuracy: 0.9510
# Epoch 18: val_loss improved from 1.15115 to 1.09084, saving model to model.save
# 109/109 [==============================] - 99s 905ms/step - loss: 1.0810 - accuracy: 0.9510 - val_loss: 1.0908 - val_accuracy: 0.9459
# Epoch 19/200
# 109/109 [==============================] - ETA: 0s - loss: 1.0383 - accuracy: 0.9518
# Epoch 19: val_loss improved from 1.09084 to 1.06441, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 1.0383 - accuracy: 0.9518 - val_loss: 1.0644 - val_accuracy: 0.9420
# Epoch 20/200
# 109/109 [==============================] - ETA: 0s - loss: 0.9969 - accuracy: 0.9523
# Epoch 20: val_loss improved from 1.06441 to 1.04645, saving model to model.save
# 109/109 [==============================] - 98s 895ms/step - loss: 0.9969 - accuracy: 0.9523 - val_loss: 1.0464 - val_accuracy: 0.9327
# Epoch 21/200
# 109/109 [==============================] - ETA: 0s - loss: 0.9648 - accuracy: 0.9508
# Epoch 21: val_loss improved from 1.04645 to 0.98227, saving model to model.save
# 109/109 [==============================] - 98s 894ms/step - loss: 0.9648 - accuracy: 0.9508 - val_loss: 0.9823 - val_accuracy: 0.9399
# Epoch 22/200
# 109/109 [==============================] - ETA: 0s - loss: 0.9244 - accuracy: 0.9521
# Epoch 22: val_loss improved from 0.98227 to 0.96859, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 0.9244 - accuracy: 0.9521 - val_loss: 0.9686 - val_accuracy: 0.9422
# Epoch 23/200
# 109/109 [==============================] - ETA: 0s - loss: 0.8878 - accuracy: 0.9524
# Epoch 23: val_loss improved from 0.96859 to 0.95569, saving model to model.save
# 109/109 [==============================] - 99s 907ms/step - loss: 0.8878 - accuracy: 0.9524 - val_loss: 0.9557 - val_accuracy: 0.9337
# Epoch 24/200
# 109/109 [==============================] - ETA: 0s - loss: 0.8519 - accuracy: 0.9537
# Epoch 24: val_loss improved from 0.95569 to 0.87467, saving model to model.save
# 109/109 [==============================] - 98s 898ms/step - loss: 0.8519 - accuracy: 0.9537 - val_loss: 0.8747 - val_accuracy: 0.9400
# Epoch 25/200
# 109/109 [==============================] - ETA: 0s - loss: 0.8197 - accuracy: 0.9542
# Epoch 25: val_loss improved from 0.87467 to 0.85145, saving model to model.save
# 109/109 [==============================] - 99s 904ms/step - loss: 0.8197 - accuracy: 0.9542 - val_loss: 0.8514 - val_accuracy: 0.9445
# Epoch 26/200
# 109/109 [==============================] - ETA: 0s - loss: 0.7902 - accuracy: 0.9540
# Epoch 26: val_loss improved from 0.85145 to 0.79723, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 0.7902 - accuracy: 0.9540 - val_loss: 0.7972 - val_accuracy: 0.9509
# Epoch 27/200
# 109/109 [==============================] - ETA: 0s - loss: 0.7614 - accuracy: 0.9528
# Epoch 27: val_loss did not improve from 0.79723
# 109/109 [==============================] - 95s 868ms/step - loss: 0.7614 - accuracy: 0.9528 - val_loss: 0.8085 - val_accuracy: 0.9412
# Epoch 28/200
# 109/109 [==============================] - ETA: 0s - loss: 0.7308 - accuracy: 0.9548
# Epoch 28: val_loss did not improve from 0.79723
# 109/109 [==============================] - 95s 872ms/step - loss: 0.7308 - accuracy: 0.9548 - val_loss: 0.8083 - val_accuracy: 0.9234
# Epoch 29/200
# 109/109 [==============================] - ETA: 0s - loss: 0.7103 - accuracy: 0.9526
# Epoch 29: val_loss improved from 0.79723 to 0.73374, saving model to model.save
# 109/109 [==============================] - 99s 906ms/step - loss: 0.7103 - accuracy: 0.9526 - val_loss: 0.7337 - val_accuracy: 0.9455
# Epoch 30/200
# 109/109 [==============================] - ETA: 0s - loss: 0.6862 - accuracy: 0.9523
# Epoch 30: val_loss improved from 0.73374 to 0.71544, saving model to model.save
# 109/109 [==============================] - 98s 898ms/step - loss: 0.6862 - accuracy: 0.9523 - val_loss: 0.7154 - val_accuracy: 0.9439
# Epoch 31/200
# 109/109 [==============================] - ETA: 0s - loss: 0.6601 - accuracy: 0.9536
# Epoch 31: val_loss improved from 0.71544 to 0.70944, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 0.6601 - accuracy: 0.9536 - val_loss: 0.7094 - val_accuracy: 0.9355
# Epoch 32/200
# 109/109 [==============================] - ETA: 0s - loss: 0.6356 - accuracy: 0.9524
# Epoch 32: val_loss improved from 0.70944 to 0.67368, saving model to model.save
# 109/109 [==============================] - 99s 905ms/step - loss: 0.6356 - accuracy: 0.9524 - val_loss: 0.6737 - val_accuracy: 0.9404
# Epoch 33/200
# 109/109 [==============================] - ETA: 0s - loss: 0.6180 - accuracy: 0.9524
# Epoch 33: val_loss improved from 0.67368 to 0.64480, saving model to model.save
# 109/109 [==============================] - 100s 912ms/step - loss: 0.6180 - accuracy: 0.9524 - val_loss: 0.6448 - val_accuracy: 0.9469
# Epoch 34/200
# 109/109 [==============================] - ETA: 0s - loss: 0.5926 - accuracy: 0.9546
# Epoch 34: val_loss improved from 0.64480 to 0.62279, saving model to model.save
# 109/109 [==============================] - 100s 914ms/step - loss: 0.5926 - accuracy: 0.9546 - val_loss: 0.6228 - val_accuracy: 0.9431
# Epoch 35/200
# 109/109 [==============================] - ETA: 0s - loss: 0.5678 - accuracy: 0.9547
# Epoch 35: val_loss improved from 0.62279 to 0.59148, saving model to model.save
# 109/109 [==============================] - 99s 902ms/step - loss: 0.5678 - accuracy: 0.9547 - val_loss: 0.5915 - val_accuracy: 0.9461
# Epoch 36/200
# 109/109 [==============================] - ETA: 0s - loss: 0.5504 - accuracy: 0.9537
# Epoch 36: val_loss improved from 0.59148 to 0.58057, saving model to model.save
# 109/109 [==============================] - 99s 905ms/step - loss: 0.5504 - accuracy: 0.9537 - val_loss: 0.5806 - val_accuracy: 0.9489
# Epoch 37/200
# 109/109 [==============================] - ETA: 0s - loss: 0.5334 - accuracy: 0.9524
# Epoch 37: val_loss improved from 0.58057 to 0.56743, saving model to model.save
# 109/109 [==============================] - 99s 904ms/step - loss: 0.5334 - accuracy: 0.9524 - val_loss: 0.5674 - val_accuracy: 0.9455
# Epoch 38/200
# 109/109 [==============================] - ETA: 0s - loss: 0.5085 - accuracy: 0.9551
# Epoch 38: val_loss did not improve from 0.56743
# 109/109 [==============================] - 95s 874ms/step - loss: 0.5085 - accuracy: 0.9551 - val_loss: 0.5896 - val_accuracy: 0.9388
# Epoch 39/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4937 - accuracy: 0.9547
# Epoch 39: val_loss improved from 0.56743 to 0.54979, saving model to model.save
# 109/109 [==============================] - 99s 904ms/step - loss: 0.4937 - accuracy: 0.9547 - val_loss: 0.5498 - val_accuracy: 0.9404
# Epoch 40/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4776 - accuracy: 0.9545
# Epoch 40: val_loss improved from 0.54979 to 0.51428, saving model to model.save
# 109/109 [==============================] - 99s 910ms/step - loss: 0.4776 - accuracy: 0.9545 - val_loss: 0.5143 - val_accuracy: 0.9442
# Epoch 41/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4608 - accuracy: 0.9553
# Epoch 41: val_loss improved from 0.51428 to 0.49687, saving model to model.save
# 109/109 [==============================] - 99s 909ms/step - loss: 0.4608 - accuracy: 0.9553 - val_loss: 0.4969 - val_accuracy: 0.9393
# Epoch 42/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4523 - accuracy: 0.9535
# Epoch 42: val_loss improved from 0.49687 to 0.48738, saving model to model.save
# 109/109 [==============================] - 99s 906ms/step - loss: 0.4523 - accuracy: 0.9535 - val_loss: 0.4874 - val_accuracy: 0.9428
# Epoch 43/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4325 - accuracy: 0.9557
# Epoch 43: val_loss improved from 0.48738 to 0.44725, saving model to model.save
# 109/109 [==============================] - 99s 907ms/step - loss: 0.4325 - accuracy: 0.9557 - val_loss: 0.4472 - val_accuracy: 0.9476
# Epoch 44/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4163 - accuracy: 0.9557
# Epoch 44: val_loss did not improve from 0.44725
# 109/109 [==============================] - 95s 870ms/step - loss: 0.4163 - accuracy: 0.9557 - val_loss: 0.4682 - val_accuracy: 0.9379
# Epoch 45/200
# 109/109 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.9540
# Epoch 45: val_loss improved from 0.44725 to 0.43104, saving model to model.save
# 109/109 [==============================] - 99s 907ms/step - loss: 0.4090 - accuracy: 0.9540 - val_loss: 0.4310 - val_accuracy: 0.9463
# Epoch 46/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3895 - accuracy: 0.9563
# Epoch 46: val_loss improved from 0.43104 to 0.41590, saving model to model.save
# 109/109 [==============================] - 99s 905ms/step - loss: 0.3895 - accuracy: 0.9563 - val_loss: 0.4159 - val_accuracy: 0.9439
# Epoch 47/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3778 - accuracy: 0.9548
# Epoch 47: val_loss improved from 0.41590 to 0.39642, saving model to model.save
# 109/109 [==============================] - 98s 897ms/step - loss: 0.3778 - accuracy: 0.9548 - val_loss: 0.3964 - val_accuracy: 0.9479
# Epoch 48/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3676 - accuracy: 0.9537
# Epoch 48: val_loss improved from 0.39642 to 0.38747, saving model to model.save
# 109/109 [==============================] - 98s 897ms/step - loss: 0.3676 - accuracy: 0.9537 - val_loss: 0.3875 - val_accuracy: 0.9488
# Epoch 49/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3544 - accuracy: 0.9549
# Epoch 49: val_loss did not improve from 0.38747
# 109/109 [==============================] - 96s 875ms/step - loss: 0.3544 - accuracy: 0.9549 - val_loss: 0.3939 - val_accuracy: 0.9454
# Epoch 50/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3441 - accuracy: 0.9562
# Epoch 50: val_loss improved from 0.38747 to 0.37329, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 0.3441 - accuracy: 0.9562 - val_loss: 0.3733 - val_accuracy: 0.9470
# Epoch 51/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.9560
# Epoch 51: val_loss improved from 0.37329 to 0.36806, saving model to model.save
# 109/109 [==============================] - 99s 903ms/step - loss: 0.3316 - accuracy: 0.9560 - val_loss: 0.3681 - val_accuracy: 0.9503
# Epoch 52/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.9558
# Epoch 52: val_loss did not improve from 0.36806
# 109/109 [==============================] - 95s 870ms/step - loss: 0.3221 - accuracy: 0.9558 - val_loss: 0.3752 - val_accuracy: 0.9330
# Epoch 53/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.9542
# Epoch 53: val_loss improved from 0.36806 to 0.33430, saving model to model.save
# 109/109 [==============================] - 99s 905ms/step - loss: 0.3152 - accuracy: 0.9542 - val_loss: 0.3343 - val_accuracy: 0.9497
# Epoch 54/200
# 109/109 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.9554
# Epoch 54: val_loss did not improve from 0.33430
# 109/109 [==============================] - 95s 871ms/step - loss: 0.3053 - accuracy: 0.9554 - val_loss: 0.3564 - val_accuracy: 0.9419
# Epoch 55/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2956 - accuracy: 0.9549
# Epoch 55: val_loss did not improve from 0.33430
# 109/109 [==============================] - 95s 869ms/step - loss: 0.2956 - accuracy: 0.9549 - val_loss: 0.3853 - val_accuracy: 0.9244
# Epoch 56/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 0.9555
# Epoch 56: val_loss improved from 0.33430 to 0.32140, saving model to model.save
# 109/109 [==============================] - 98s 900ms/step - loss: 0.2882 - accuracy: 0.9555 - val_loss: 0.3214 - val_accuracy: 0.9473
# Epoch 57/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.9551
# Epoch 57: val_loss improved from 0.32140 to 0.31710, saving model to model.save
# 109/109 [==============================] - 98s 900ms/step - loss: 0.2822 - accuracy: 0.9551 - val_loss: 0.3171 - val_accuracy: 0.9470
# Epoch 58/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2724 - accuracy: 0.9559
# Epoch 58: val_loss did not improve from 0.31710
# 109/109 [==============================] - 95s 871ms/step - loss: 0.2724 - accuracy: 0.9559 - val_loss: 0.3223 - val_accuracy: 0.9436
# Epoch 59/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.9536
# Epoch 59: val_loss improved from 0.31710 to 0.30232, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 0.2681 - accuracy: 0.9536 - val_loss: 0.3023 - val_accuracy: 0.9458
# Epoch 60/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2620 - accuracy: 0.9546
# Epoch 60: val_loss improved from 0.30232 to 0.28255, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 0.2620 - accuracy: 0.9546 - val_loss: 0.2825 - val_accuracy: 0.9487
# Epoch 61/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2574 - accuracy: 0.9540
# Epoch 61: val_loss improved from 0.28255 to 0.27736, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 0.2574 - accuracy: 0.9540 - val_loss: 0.2774 - val_accuracy: 0.9499
# Epoch 62/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.9563
# Epoch 62: val_loss did not improve from 0.27736
# 109/109 [==============================] - 95s 869ms/step - loss: 0.2469 - accuracy: 0.9563 - val_loss: 0.2807 - val_accuracy: 0.9475
# Epoch 63/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.9562
# Epoch 63: val_loss did not improve from 0.27736
# 109/109 [==============================] - 95s 870ms/step - loss: 0.2443 - accuracy: 0.9562 - val_loss: 0.2854 - val_accuracy: 0.9460
# Epoch 64/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9563
# Epoch 64: val_loss did not improve from 0.27736
# 109/109 [==============================] - 96s 875ms/step - loss: 0.2360 - accuracy: 0.9563 - val_loss: 0.2879 - val_accuracy: 0.9455
# Epoch 65/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2297 - accuracy: 0.9560
# Epoch 65: val_loss improved from 0.27736 to 0.25660, saving model to model.save
# 109/109 [==============================] - 99s 910ms/step - loss: 0.2297 - accuracy: 0.9560 - val_loss: 0.2566 - val_accuracy: 0.9506
# Epoch 66/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2239 - accuracy: 0.9560
# Epoch 66: val_loss improved from 0.25660 to 0.24444, saving model to model.save
# 109/109 [==============================] - 98s 897ms/step - loss: 0.2239 - accuracy: 0.9560 - val_loss: 0.2444 - val_accuracy: 0.9499
# Epoch 67/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2191 - accuracy: 0.9561
# Epoch 67: val_loss improved from 0.24444 to 0.24378, saving model to model.save
# 109/109 [==============================] - 114s 1s/step - loss: 0.2191 - accuracy: 0.9561 - val_loss: 0.2438 - val_accuracy: 0.9481
# Epoch 68/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9566
# Epoch 68: val_loss did not improve from 0.24378
# 109/109 [==============================] - 95s 866ms/step - loss: 0.2137 - accuracy: 0.9566 - val_loss: 0.3146 - val_accuracy: 0.9320
# Epoch 69/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2107 - accuracy: 0.9548
# Epoch 69: val_loss improved from 0.24378 to 0.23658, saving model to model.save
# 109/109 [==============================] - 98s 897ms/step - loss: 0.2107 - accuracy: 0.9548 - val_loss: 0.2366 - val_accuracy: 0.9500
# Epoch 70/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2063 - accuracy: 0.9554
# Epoch 70: val_loss improved from 0.23658 to 0.23441, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 0.2063 - accuracy: 0.9554 - val_loss: 0.2344 - val_accuracy: 0.9487
# Epoch 71/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2023 - accuracy: 0.9564
# Epoch 71: val_loss improved from 0.23441 to 0.22885, saving model to model.save
# 109/109 [==============================] - 98s 901ms/step - loss: 0.2023 - accuracy: 0.9564 - val_loss: 0.2288 - val_accuracy: 0.9479
# Epoch 72/200
# 109/109 [==============================] - ETA: 0s - loss: 0.2018 - accuracy: 0.9531
# Epoch 72: val_loss improved from 0.22885 to 0.22193, saving model to model.save
# 109/109 [==============================] - 98s 897ms/step - loss: 0.2018 - accuracy: 0.9531 - val_loss: 0.2219 - val_accuracy: 0.9505
# Epoch 73/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9546
# Epoch 73: val_loss did not improve from 0.22193
# 109/109 [==============================] - 95s 872ms/step - loss: 0.1983 - accuracy: 0.9546 - val_loss: 0.2531 - val_accuracy: 0.9418
# Epoch 74/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1949 - accuracy: 0.9551
# Epoch 74: val_loss improved from 0.22193 to 0.22180, saving model to model.save
# 109/109 [==============================] - 98s 902ms/step - loss: 0.1949 - accuracy: 0.9551 - val_loss: 0.2218 - val_accuracy: 0.9443
# Epoch 75/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1879 - accuracy: 0.9551
# Epoch 75: val_loss improved from 0.22180 to 0.21113, saving model to model.save
# 109/109 [==============================] - 98s 894ms/step - loss: 0.1879 - accuracy: 0.9551 - val_loss: 0.2111 - val_accuracy: 0.9499
# Epoch 76/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9558
# Epoch 76: val_loss did not improve from 0.21113
# 109/109 [==============================] - 95s 871ms/step - loss: 0.1872 - accuracy: 0.9558 - val_loss: 0.2124 - val_accuracy: 0.9424
# Epoch 77/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1814 - accuracy: 0.9550
# Epoch 77: val_loss improved from 0.21113 to 0.20916, saving model to model.save
# 109/109 [==============================] - 99s 902ms/step - loss: 0.1814 - accuracy: 0.9550 - val_loss: 0.2092 - val_accuracy: 0.9492
# Epoch 78/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9566
# Epoch 78: val_loss improved from 0.20916 to 0.20407, saving model to model.save
# 109/109 [==============================] - 98s 900ms/step - loss: 0.1748 - accuracy: 0.9566 - val_loss: 0.2041 - val_accuracy: 0.9482
# Epoch 79/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9573
# Epoch 79: val_loss improved from 0.20407 to 0.19179, saving model to model.save
# 109/109 [==============================] - 98s 895ms/step - loss: 0.1724 - accuracy: 0.9573 - val_loss: 0.1918 - val_accuracy: 0.9514
# Epoch 80/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9550
# Epoch 80: val_loss did not improve from 0.19179
# 109/109 [==============================] - 95s 871ms/step - loss: 0.1717 - accuracy: 0.9550 - val_loss: 0.2224 - val_accuracy: 0.9386
# Epoch 81/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1709 - accuracy: 0.9545
# Epoch 81: val_loss did not improve from 0.19179
# 109/109 [==============================] - 96s 877ms/step - loss: 0.1709 - accuracy: 0.9545 - val_loss: 0.2332 - val_accuracy: 0.9389
# Epoch 82/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1730 - accuracy: 0.9544
# Epoch 82: val_loss did not improve from 0.19179
# 109/109 [==============================] - 95s 872ms/step - loss: 0.1730 - accuracy: 0.9544 - val_loss: 0.1977 - val_accuracy: 0.9489
# Epoch 83/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9555
# Epoch 83: val_loss improved from 0.19179 to 0.18460, saving model to model.save
# 109/109 [==============================] - 99s 905ms/step - loss: 0.1639 - accuracy: 0.9555 - val_loss: 0.1846 - val_accuracy: 0.9481
# Epoch 84/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1663 - accuracy: 0.9538
# Epoch 84: val_loss did not improve from 0.18460
# 109/109 [==============================] - 95s 869ms/step - loss: 0.1663 - accuracy: 0.9538 - val_loss: 0.2207 - val_accuracy: 0.9430
# Epoch 85/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9562
# Epoch 85: val_loss improved from 0.18460 to 0.18289, saving model to model.save
# 109/109 [==============================] - 98s 896ms/step - loss: 0.1611 - accuracy: 0.9562 - val_loss: 0.1829 - val_accuracy: 0.9458
# Epoch 86/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9558
# Epoch 86: val_loss did not improve from 0.18289
# 109/109 [==============================] - 95s 869ms/step - loss: 0.1563 - accuracy: 0.9558 - val_loss: 0.1908 - val_accuracy: 0.9502
# Epoch 87/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9568
# Epoch 87: val_loss did not improve from 0.18289
# 109/109 [==============================] - 94s 861ms/step - loss: 0.1528 - accuracy: 0.9568 - val_loss: 0.1853 - val_accuracy: 0.9513
# Epoch 88/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9565
# Epoch 88: val_loss did not improve from 0.18289
# 109/109 [==============================] - 95s 871ms/step - loss: 0.1502 - accuracy: 0.9565 - val_loss: 0.1940 - val_accuracy: 0.9439
# Epoch 89/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9566
# Epoch 89: val_loss did not improve from 0.18289
# 109/109 [==============================] - 94s 865ms/step - loss: 0.1485 - accuracy: 0.9566 - val_loss: 0.1948 - val_accuracy: 0.9445
# Epoch 90/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1487 - accuracy: 0.9559
# Epoch 90: val_loss improved from 0.18289 to 0.17584, saving model to model.save
# 109/109 [==============================] - 99s 905ms/step - loss: 0.1487 - accuracy: 0.9559 - val_loss: 0.1758 - val_accuracy: 0.9467
# Epoch 91/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9560
# Epoch 91: val_loss improved from 0.17584 to 0.17087, saving model to model.save
# 109/109 [==============================] - 98s 899ms/step - loss: 0.1443 - accuracy: 0.9560 - val_loss: 0.1709 - val_accuracy: 0.9476
# Epoch 92/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9561
# Epoch 92: val_loss did not improve from 0.17087
# 109/109 [==============================] - 95s 868ms/step - loss: 0.1407 - accuracy: 0.9561 - val_loss: 0.1811 - val_accuracy: 0.9485
# Epoch 93/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9553
# Epoch 93: val_loss did not improve from 0.17087
# 109/109 [==============================] - 94s 861ms/step - loss: 0.1426 - accuracy: 0.9553 - val_loss: 0.1726 - val_accuracy: 0.9486
# Epoch 94/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9572
# Epoch 94: val_loss improved from 0.17087 to 0.16749, saving model to model.save
# 109/109 [==============================] - 99s 906ms/step - loss: 0.1378 - accuracy: 0.9572 - val_loss: 0.1675 - val_accuracy: 0.9493
# Epoch 95/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9577
# Epoch 95: val_loss did not improve from 0.16749
# 109/109 [==============================] - 95s 872ms/step - loss: 0.1360 - accuracy: 0.9577 - val_loss: 0.1970 - val_accuracy: 0.9386
# Epoch 96/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1355 - accuracy: 0.9556
# Epoch 96: val_loss did not improve from 0.16749
# 109/109 [==============================] - 96s 881ms/step - loss: 0.1355 - accuracy: 0.9556 - val_loss: 0.1775 - val_accuracy: 0.9502
# Epoch 97/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1359 - accuracy: 0.9555
# Epoch 97: val_loss did not improve from 0.16749
# 109/109 [==============================] - 96s 877ms/step - loss: 0.1359 - accuracy: 0.9555 - val_loss: 0.1823 - val_accuracy: 0.9432
# Epoch 98/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1339 - accuracy: 0.9562
# Epoch 98: val_loss improved from 0.16749 to 0.16011, saving model to model.save
# 109/109 [==============================] - 99s 910ms/step - loss: 0.1339 - accuracy: 0.9562 - val_loss: 0.1601 - val_accuracy: 0.9508
# Epoch 99/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9573
# Epoch 99: val_loss did not improve from 0.16011
# 109/109 [==============================] - 97s 884ms/step - loss: 0.1302 - accuracy: 0.9573 - val_loss: 0.1611 - val_accuracy: 0.9507
# Epoch 100/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9567
# Epoch 100: val_loss did not improve from 0.16011
# 109/109 [==============================] - 97s 884ms/step - loss: 0.1298 - accuracy: 0.9567 - val_loss: 0.1675 - val_accuracy: 0.9471
# Epoch 101/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9574
# Epoch 101: val_loss did not improve from 0.16011
# 109/109 [==============================] - 97s 890ms/step - loss: 0.1275 - accuracy: 0.9574 - val_loss: 0.1693 - val_accuracy: 0.9474
# Epoch 102/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1277 - accuracy: 0.9573
# Epoch 102: val_loss did not improve from 0.16011
# 109/109 [==============================] - 97s 884ms/step - loss: 0.1277 - accuracy: 0.9573 - val_loss: 0.1631 - val_accuracy: 0.9479
# Epoch 103/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9568
# Epoch 103: val_loss improved from 0.16011 to 0.13894, saving model to model.save
# 109/109 [==============================] - 99s 906ms/step - loss: 0.1265 - accuracy: 0.9568 - val_loss: 0.1389 - val_accuracy: 0.9517
# Epoch 104/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9571
# Epoch 104: val_loss did not improve from 0.13894
# 109/109 [==============================] - 95s 873ms/step - loss: 0.1233 - accuracy: 0.9571 - val_loss: 0.1530 - val_accuracy: 0.9515
# Epoch 105/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9570
# Epoch 105: val_loss did not improve from 0.13894
# 109/109 [==============================] - 95s 873ms/step - loss: 0.1250 - accuracy: 0.9570 - val_loss: 0.2016 - val_accuracy: 0.9320
# Epoch 106/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1223 - accuracy: 0.9581
# Epoch 106: val_loss did not improve from 0.13894
# 109/109 [==============================] - 96s 875ms/step - loss: 0.1223 - accuracy: 0.9581 - val_loss: 0.1521 - val_accuracy: 0.9484
# Epoch 107/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1223 - accuracy: 0.9578
# Epoch 107: val_loss did not improve from 0.13894
# 109/109 [==============================] - 95s 871ms/step - loss: 0.1223 - accuracy: 0.9578 - val_loss: 0.1617 - val_accuracy: 0.9463
# Epoch 108/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.9563
# Epoch 108: val_loss did not improve from 0.13894
# 109/109 [==============================] - 95s 865ms/step - loss: 0.1209 - accuracy: 0.9563 - val_loss: 0.1452 - val_accuracy: 0.9451
# Epoch 109/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9569
# Epoch 109: val_loss did not improve from 0.13894
# 109/109 [==============================] - 95s 867ms/step - loss: 0.1200 - accuracy: 0.9569 - val_loss: 0.1555 - val_accuracy: 0.9481
# Epoch 110/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1180 - accuracy: 0.9586
# Epoch 110: val_loss did not improve from 0.13894
# 109/109 [==============================] - 95s 868ms/step - loss: 0.1180 - accuracy: 0.9586 - val_loss: 0.1486 - val_accuracy: 0.9501
# Epoch 111/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1177 - accuracy: 0.9574
# Epoch 111: val_loss did not improve from 0.13894
# 109/109 [==============================] - 95s 866ms/step - loss: 0.1177 - accuracy: 0.9574 - val_loss: 0.1425 - val_accuracy: 0.9524
# Epoch 112/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9575
# Epoch 112: val_loss did not improve from 0.13894
# 109/109 [==============================] - 96s 875ms/step - loss: 0.1162 - accuracy: 0.9575 - val_loss: 0.1608 - val_accuracy: 0.9469
# Epoch 113/200
# 109/109 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9569
# Epoch 113: val_loss did not improve from 0.13894
# Restoring model weights from the end of the best epoch: 103.
# 109/109 [==============================] - 95s 872ms/step - loss: 0.1162 - accuracy: 0.9569 - val_loss: 0.1450 - val_accuracy: 0.9496
# Epoch 113: early stopping
# 47/47 [==============================] - 25s 525ms/step
# Classification Report:
#                                    precision    recall  f1-score   support
#
# age-related macular degeneration       0.14      0.13      0.13      1669
#                         cataract       0.16      0.16      0.16      1717
#                         diabetic       0.14      0.16      0.15      1739
#                         glaucoma       0.15      0.15      0.15      1746
#                     hypertensive       0.15      0.15      0.15      1671
#                           myopia       0.14      0.14      0.14      1688
#                           normal       0.14      0.14      0.14      1705
#
#                         accuracy                           0.15     11935
#                        macro avg       0.15      0.15      0.15     11935
#                     weighted avg       0.15      0.15      0.15     11935
#
# Class: age-related macular degeneration
#   Accuracy: 0.15
#   Precision: 0.14
#   Recall: 0.13
#   F1-Score: 0.13
# Class: cataract
#   Accuracy: 0.15
#   Precision: 0.16
#   Recall: 0.16
#   F1-Score: 0.16
# Class: diabetic
#   Accuracy: 0.15
#   Precision: 0.14
#   Recall: 0.16
#   F1-Score: 0.15
# Class: glaucoma
#   Accuracy: 0.15
#   Precision: 0.15
#   Recall: 0.15
#   F1-Score: 0.15
# Class: hypertensive
#   Accuracy: 0.15
#   Precision: 0.15
#   Recall: 0.15
#   F1-Score: 0.15
# Class: myopia
#   Accuracy: 0.15
#   Precision: 0.14
#   Recall: 0.14
#   F1-Score: 0.14
# Class: normal
#   Accuracy: 0.15
#   Precision: 0.14
#   Recall: 0.14
#   F1-Score: 0.14

# %%
# # Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
# model = load_model('model.save')

# # Evaluasi model pada data uji
# y_true = test_generator.classes
# y_pred_probs = model.predict(test_generator)
# y_pred = np.argmax(y_pred_probs, axis=1)

# # Confusion Matrix
# conf_matrix = confusion_matrix(y_true, y_pred)
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
# plt.title('Confusion Matrix')
# plt.xlabel('Predicted')
# plt.ylabel('True')
# plt.show()
# plt.savefig("Confusion_Matrix.png")

# # Classification Report
# class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
# print("Classification Report:\n", class_report)

# # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
# accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
# precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
# recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
# f1_score = 2 * (precision * recall) / (precision + recall)

# # Print the values
# for i, class_name in enumerate(test_generator.class_indices.keys()):
#     print(f'Class: {class_name}')
#     print(f'  Accuracy: {accuracy:.2f}')
#     print(f'  Precision: {precision[i]:.2f}')
#     print(f'  Recall: {recall[i]:.2f}')
#     print(f'  F1-Score: {f1_score[i]:.2f}')

# # ROC Curve and AUC
# fpr = dict()
# tpr = dict()
# roc_auc = dict()

# for i in range(num_classes):
#     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
#     roc_auc[i] = auc(fpr[i], tpr[i])

# # Plot ROC Curve
# plt.figure(figsize=(10, 8))
# for i in range(num_classes):
#     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# plt.plot([0, 1], [0, 1], 'k--', label='Random')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve')
# plt.legend()
# plt.show()
# plt.savefig("ROC_Curve.png")

# %%
# import zipfile
# import os
# from IPython.display import FileLink

# def zip_dir(directory = os.curdir, file_name = 'directory.zip'):
#     os.chdir(directory)
#     zip_ref = zipfile.ZipFile(file_name, mode='w')
#     for folder, _, files in os.walk(directory):
#         for file in files:
#             if file_name in file:
#                 pass
#             else:
#                 zip_ref.write(os.path.join(folder, file))

#     return FileLink(file_name)

# zip_dir()
