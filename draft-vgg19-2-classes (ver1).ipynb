# %%
import cv2
import datetime
import os
import pandas as pd
import numpy as np
import shutil
import seaborn as sns
import random
import math
import tensorflow as tf
import sys
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from matplotlib import pyplot as plt
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from keras import applications, regularizers
from keras.applications.vgg19 import VGG19
from keras.applications.mobilenet import MobileNet
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, LearningRateScheduler
from keras.models import Model, Sequential, load_model
from keras.layers import Conv2D, Dense, Flatten, MaxPooling2D, Dropout, Activation, BatchNormalization
from keras.optimizers import Adam, RMSprop, SGD
from keras.initializers import he_normal
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from tqdm import tqdm
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Import image description data
df_data = pd.read_csv("/kaggle/input/ocular-disease-recognition-odir5k/full_df.csv")

df_data2 = df_data.iloc[:, 1:7]

# "myopia", "hypertensive", "diabetic", "age-related macular degeneration", "glaucoma",

# Daftar kata kunci yang ingin dicari
keywords = ["cataract", "normal"]  # Ganti dengan kata kunci yang diinginkan

# Fungsi untuk mencari kata kunci dalam DataFrame
def search_keywords(data_frame, keyword):
    left_diagnosis = data_frame[data_frame['Left-Diagnostic Keywords'].str.contains(keyword)]
    right_diagnosis = data_frame[data_frame['Right-Diagnostic Keywords'].str.contains(keyword)]
    combined = pd.concat((left_diagnosis['Left-Fundus'], right_diagnosis['Right-Fundus']))

    df_result = pd.DataFrame(combined, columns=['fundus'])
    df_result['class'] = keyword
    return df_result

# Mencari semua kata kunci dalam satu langkah
dfs = []
for keyword in keywords:
    df_keyword = search_keywords(df_data2, keyword)
    dfs.append(df_keyword)

# Menggabungkan hasil pencarian kata kunci
result_df = pd.concat(dfs)

# Menyimpan DataFrame dalam file XLSX
result_df.to_excel('merge.xlsx', index=False)

# Convert DataFrame ke bentuk JSON
data_list = result_df.to_dict(orient='records')


def resize_image(img, target_size):
    # Mendapatkan dimensi gambar asli
    original_height, original_width = img.shape[:2]

    # Mendapatkan dimensi target
    target_width, target_height = target_size

    # Menghitung rasio skala lebar dan tinggi
    width_ratio = target_width / original_width
    height_ratio = target_height / original_height

    # Menentukan rasio skala yang akan digunakan untuk resizing
    scale_ratio = min(width_ratio, height_ratio)

    # Menghitung ukuran baru setelah penskalaan
    new_width = int(original_width * scale_ratio)
    new_height = int(original_height * scale_ratio)

    # Melakukan resizing gambar dengan opsi interporasi yang baik
    resized_img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_AREA)

    # Membuat latar belakang gambar dengan ukuran target
    background = (0, 0, 0)  # Hitam

    # Membuat gambar dengan ukuran target yang tepat
    top_padding = (target_height - new_height) // 2
    bottom_padding = target_height - new_height - top_padding
    left_padding = (target_width - new_width) // 2
    right_padding = target_width - new_width - left_padding

    # Menggunakan padding untuk membuat latar belakang dengan ukuran target
    background_img = cv2.copyMakeBorder(resized_img, top_padding, bottom_padding, left_padding, right_padding, cv2.BORDER_CONSTANT, value=background)

    return background_img

## Read image and preprocessing
def process_images(input_folder, output_folder):
    # Membuat folder output jika belum ada
    os.makedirs(output_folder, exist_ok=True)

    # Loop melalui semua file dalam folder
    for filename in os.listdir(output_folder):

        os.remove(os.path.join(output_folder, filename))

    print("Isi file dalam folder output telah dihapus.")

    # Mendapatkan daftar file gambar di dalam folder input
    image_files = [file for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

    # Loop melalui daftar file gambar
    for image_file in tqdm(image_files, desc="Processing images"):
        # Membaca gambar
        image_path = os.path.join(input_folder, image_file)
        image = cv2.imread(image_path)

        # Ubah ukuran gambar
        target_size = (224, 224)  # Ubah ukuran sesuai kebutuhan Anda
        resized_image = cv2.resize(image, target_size)
#         resized_image = resize_image(image, target_size)
        # cropped_image = crop_padding(resized_image)

        # Ubah format warna gambar
        colored_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

        # Simpan gambar ke folder output dengan nama yang sama
        output_path = os.path.join(output_folder, image_file)
        cv2.imwrite(output_path, colored_image)

    print("Proses selesai. Gambar-gambar telah disimpan di folder output.")

# Preprocessing gambar
input_folder = "/kaggle/input/ocular-disease-recognition-odir5k/ODIR-5K/ODIR-5K/Training Images"
output_folder = "/kaggle/working/output_preprocessing/"

process_images(input_folder, output_folder)
# Out:
# Isi file dalam folder output telah dihapus.
# Processing images: 100%|██████████| 7000/7000 [06:20<00:00, 18.39it/s]
# Proses selesai. Gambar-gambar telah disimpan di folder output.

# %%
# tracked_images = []
# for df in tqdm(data_list, desc="Tracking image label"):
#     fundus = df['fundus']
#     file_path = os.path.join(output_folder, fundus)
#     image = cv2.imread(file_path)
#     if image is not None:
#         label = df['class']
#         tracked_images.append((image, label))

# # Memisahkan gambar dan label menjadi dua array terpisah
# tracked_images_array = np.array([x[0] for x in tracked_images])
# labels_array = np.array([x[1] for x in tracked_images])

# # Fungsi untuk menyimpan gambar ke dalam folder
# def save_images(images, labels, output_folder):
#     for i, (image, label) in enumerate(zip(images, labels)):
#         fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
#         file_path = os.path.join(output_folder, fundus)
#         cv2.imwrite(file_path, image)

# # Fungsi untuk melakukan histogram equalization pada gambar
# def histogram_equalization(image):
#     # Ubah gambar ke skala keabuan jika belum
#     if len(image.shape) > 2:
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     else:
#         gray = image

#     # Lakukan histogram equalization
#     equalized = cv2.equalizeHist(gray)

#     equalized = cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

#     return equalized

# # Fungsi untuk melakukan histogram equalization pada gambar
# def clahe(image):
#     # Ubah gambar ke skala keabuan jika belum
#     if len(image.shape) > 2:
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     else:
#         gray = image

#     clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
#     enhanced_image = clahe.apply(gray)

#     enhanced_image = cv2.cvtColor(enhanced_image, cv2.COLOR_GRAY2BGR)
#     return image

# # Folder untuk menyimpan gambar-gambar hasil konversi
# output_folder_equalized = "/kaggle/working/output_equalized/"
# output_folder_clahe = "/kaggle/working/output_clahe/"

# # Membuat folder output jika belum ada
# os.makedirs(output_folder_equalized, exist_ok=True)
# os.makedirs(output_folder_clahe, exist_ok=True)

# # Melakukan histogram equalization pada gambar-gambar hasil tracking
# for i in tqdm(range(len(tracked_images_array)), desc="Equalizing Images"):
#     tracked_images_array[i] = histogram_equalization(tracked_images_array[i])

# # Menyimpan hasil histogram equalization
# save_images(tracked_images_array, labels_array, output_folder_equalized)

# # Melakukan CLAHE pada gambar-gambar hasil tracking
# for i in tqdm(range(len(tracked_images_array)), desc="CLAHE-ing Images"):
#     tracked_images_array[i] = clahe(tracked_images_array[i])
    
# # Menyimpan hasil CLAHE
# save_images(tracked_images_array, labels_array, output_folder_clahe)

# %%
# Folder untuk menyimpan gambar-gambar hasil konversi
output_folder_oversampled = "/kaggle/working/output_oversample/"
output_folder_undersampled = "/kaggle/working/output_undersample/"

# Membuat folder output jika belum ada
os.makedirs(output_folder_oversampled, exist_ok=True)
os.makedirs(output_folder_undersampled, exist_ok=True)

def oversample_images_generator(images, labels):
    oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
    oversampled_images, oversampled_labels = oversampler.fit_resample(images.reshape(len(images), -1), labels)
    for i in range(len(oversampled_images)):
        yield oversampled_images[i].reshape(images.shape[1:]), oversampled_labels[i]

def undersample_images_generator(images, labels):
    undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
    undersampled_images, undersampled_labels = undersampler.fit_resample(images.reshape(len(images), -1), labels)
    for i in range(len(undersampled_images)):
        yield undersampled_images[i].reshape(images.shape[1:]), undersampled_labels[i]

tracked_images = []
for df in tqdm(data_list, desc="Tracking image label"):
    fundus = df['fundus']
    file_path = os.path.join(output_folder, fundus)
    image = cv2.imread(file_path)
    if image is not None:
        label = df['class']
        tracked_images.append((image, label))

# Memisahkan gambar dan label menjadi dua list terpisah
tracked_images_list = [(x[0], x[1]) for x in tracked_images]
images_list, labels_list = zip(*tracked_images_list)

unique_classes = np.unique(labels_list)
num_classes = len(unique_classes)
print("Jumlah kelas: ", num_classes)

# Melakukan oversampling
oversampled_images_gen = oversample_images_generator(np.array(images_list), np.array(labels_list))
oversampled_images, oversampled_labels = zip(*oversampled_images_gen)
oversampled_images = list(oversampled_images)
oversampled_labels = list(oversampled_labels)
print("Proses selesai. Gambar telah di oversample.")

# Melakukan undersampling
undersampled_images_gen = undersample_images_generator(np.array(images_list), np.array(labels_list))
undersampled_images, undersampled_labels = zip(*undersampled_images_gen)
undersampled_images = list(undersampled_images)
undersampled_labels = list(undersampled_labels)
print("Proses selesai. Gambar telah di undersample.")

# Fungsi untuk menyimpan gambar ke dalam folder
def save_images(images, labels, output_folder):
    for i, (image, label) in enumerate(zip(images, labels)):
        fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
        file_path = os.path.join(output_folder, fundus)
        cv2.imwrite(file_path, image)

# Menyimpan hasil oversampling
save_images(oversampled_images, oversampled_labels, output_folder_oversampled)

# Menyimpan hasil undersampling
save_images(undersampled_images, undersampled_labels, output_folder_undersampled)

# Fungsi untuk melakukan histogram equalization pada gambar
def histogram_equalization(image):
    # Ubah gambar ke skala keabuan jika belum
    if len(image.shape) > 2:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image

    # Lakukan histogram equalization
    equalized = cv2.equalizeHist(gray)

    equalized = cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

    return equalized

# Fungsi untuk melakukan histogram equalization pada gambar
def clahe(image):
    # Ubah gambar ke skala keabuan jika belum
    if len(image.shape) > 2:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image

    clahe = cv2.createCLAHE(clipLimit=2, tileGridSize=(8,8))
    enhanced_image = clahe.apply(gray)

    enhanced_image = cv2.cvtColor(enhanced_image, cv2.COLOR_GRAY2BGR)
    return image

# Folder untuk menyimpan gambar-gambar hasil konversi
output_folder_equalized = "/kaggle/working/output_equalized/"
output_folder_clahe = "/kaggle/working/output_clahe/"

# Membuat folder output jika belum ada
os.makedirs(output_folder_equalized, exist_ok=True)
os.makedirs(output_folder_clahe, exist_ok=True)

# Melakukan histogram equalization pada gambar-gambar hasil oversampling
oversampled_images_copy = list(oversampled_images)  # Buat salinan agar asli tidak berubah
for i in tqdm(range(len(oversampled_images_copy)), desc="CLAHE-ing Images"):
    oversampled_images_copy[i] = clahe(oversampled_images_copy[i])

# Menyimpan hasil histogram equalization
save_images(oversampled_images_copy, oversampled_labels, output_folder_clahe)

# Melakukan histogram equalization pada gambar-gambar hasil oversampling
oversampled_images_copy = list(oversampled_images)  # Buat salinan agar asli tidak berubah
for i in tqdm(range(len(oversampled_images_copy)), desc="Equalizing Images"):
    oversampled_images_copy[i] = histogram_equalization(oversampled_images_copy[i])

# Menyimpan hasil contrast stretching
save_images(oversampled_images_copy, oversampled_labels, output_folder_equalized)
# Out:
# Tracking image label: 100%|██████████| 6277/6277 [00:03<00:00, 1901.15it/s]
# Jumlah kelas:  2
# Proses selesai. Gambar telah di oversample.
# Proses selesai. Gambar telah di undersample.
# CLAHE-ing Images: 100%|██████████| 11366/11366 [00:03<00:00, 3057.67it/s]
# Equalizing Images: 100%|██████████| 11366/11366 [00:02<00:00, 4067.05it/s]

# %%
# # Folder untuk menyimpan gambar-gambar hasil konversi
# output_folder_oversampled = "/kaggle/working/output_oversample/"
# output_folder_undersampled = "/kaggle/working/output_undersample/"

# # Membuat folder output jika belum ada
# os.makedirs(output_folder_oversampled, exist_ok=True)
# os.makedirs(output_folder_undersampled, exist_ok=True)

# def oversample_images_generator(images, labels):
#     oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
#     oversampled_images, oversampled_labels = oversampler.fit_resample(images.reshape(len(images), -1), labels)
#     for oversampled_image, oversampled_label in zip(oversampled_images, oversampled_labels):
#         yield oversampled_image.reshape(images.shape[1:]), oversampled_label

# def undersample_images_generator(images, labels):
#     undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
#     undersampled_images, undersampled_labels = undersampler.fit_resample(images.reshape(len(images), -1), labels)
#     for undersampled_image, undersampled_label in zip(undersampled_images, undersampled_labels):
#         yield undersampled_image.reshape(images.shape[1:]), undersampled_label

# tracked_images = []
# for df in tqdm(data_list, desc="Tracking image label"):
#     fundus = df['fundus']
#     file_path = os.path.join(output_folder, fundus)
#     image = cv2.imread(file_path)
#     if image is not None:
#         label = df['class']
#         tracked_images.append((image, label))

# # Memisahkan gambar dan label menjadi dua array terpisah
# tracked_images_array = np.array([x[0] for x in tracked_images])
# labels_array = np.array([x[1] for x in tracked_images])

# unique_classes = np.unique(labels_array)
# num_classes = len(unique_classes)
# print("Jumlah kelas: ", num_classes)

# # Melakukan oversampling
# oversampled_images = np.array([oversampled_image for oversampled_image, _ in oversample_images_generator(tracked_images_array, labels_array)])
# oversampled_labels = np.array([oversampled_label for _, oversampled_label in oversample_images_generator(tracked_images_array, labels_array)])
# print("Proses selesai. Gambar telah di oversample.")

# # Melakukan undersampling
# undersampled_images = np.array([undersampled_image for undersampled_image, _ in undersample_images_generator(tracked_images_array, labels_array)])
# undersampled_labels = np.array([undersampled_label for _, undersampled_label in undersample_images_generator(tracked_images_array, labels_array)])
# print("Proses selesai. Gambar telah di undersample.")

# # Fungsi untuk menyimpan gambar ke dalam folder
# def save_images(images, labels, output_folder):
#     for i, (image, label) in enumerate(zip(images, labels)):
#         fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
#         file_path = os.path.join(output_folder, fundus)
#         cv2.imwrite(file_path, image)

# # Menyimpan hasil oversampling
# save_images(oversampled_images, oversampled_labels, output_folder_oversampled)

# # Menyimpan hasil undersampling
# save_images(undersampled_images, undersampled_labels, output_folder_undersampled)

# # Fungsi untuk melakukan histogram equalization pada gambar
# def histogram_equalization(image):
#     # Ubah gambar ke skala keabuan jika belum
#     if len(image.shape) > 2:
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     else:
#         gray = image

#     # Lakukan histogram equalization
#     equalized = cv2.equalizeHist(gray)

#     equalized = cv2.cvtColor(equalized, cv2.COLOR_GRAY2BGR)

#     return equalized

# # Fungsi untuk melakukan histogram equalization pada gambar
# def clahe(image):
#     # Ubah gambar ke skala keabuan jika belum
#     if len(image.shape) > 2:
#         gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     else:
#         gray = image

#     clahe = cv2.createCLAHE(clipLimit=20, tileGridSize=(8,8))
#     enhanced_image = clahe.apply(gray)

#     enhanced_image = cv2.cvtColor(enhanced_image, cv2.COLOR_GRAY2BGR)
#     return image

# # Folder untuk menyimpan gambar-gambar hasil konversi
# output_folder_equalized = "/kaggle/working/output_equalized/"
# output_folder_clahe = "/kaggle/working/output_clahe/"

# # Membuat folder output jika belum ada
# os.makedirs(output_folder_equalized, exist_ok=True)
# os.makedirs(output_folder_clahe, exist_ok=True)

# # Fungsi untuk menyimpan gambar ke dalam folder
# def save_images(images, labels, output_folder):
#     for i, (image, label) in enumerate(zip(images, labels)):
#         fundus = f"{label}_{i}.jpg"  # Nama file menggunakan label dan indeks
#         file_path = os.path.join(output_folder, fundus)
#         cv2.imwrite(file_path, image)

# # Melakukan histogram equalization pada gambar-gambar hasil oversampling
# for i in tqdm(range(len(oversampled_images)), desc="CLAHE-ing Images"):
#     oversampled_images[i] = clahe(oversampled_images[i])

# # Menyimpan hasil histogram equalization
# save_images(oversampled_images, oversampled_labels, output_folder_clahe)

# # Melakukan histogram equalization pada gambar-gambar hasil oversampling
# for i in tqdm(range(len(oversampled_images)), desc="Equalizing Images"):
#     oversampled_images[i] = histogram_equalization(oversampled_images[i])

# # Menyimpan hasil contrast stretching
# save_images(oversampled_images, oversampled_labels, output_folder_equalized)

# %%
def split_data(input_folder, output_folder, train_ratio, keywords):
    # Membuat folder output jika belum ada
    os.makedirs(output_folder, exist_ok=True)

    # Hapus konten folder output jika ada
    for filename in os.listdir(output_folder):
        file_path = os.path.join(output_folder, filename)
        if os.path.isfile(file_path):
            os.remove(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)

    # Daftar semua file gambar dalam folder input
    image_files = [file for file in os.listdir(input_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

    # Acak urutan file gambar
    random.shuffle(image_files)

    # Tentukan jumlah data training dan testing berdasarkan rasio yang diberikan
    num_train = int(len(image_files) * train_ratio)

    # Bagi data ke dalam folder training dan testing
    train_output_folder = os.path.join(output_folder, 'train')
    test_output_folder = os.path.join(output_folder, 'test')
    os.makedirs(train_output_folder, exist_ok=True)
    os.makedirs(test_output_folder, exist_ok=True)

    # Salin data training dan testing berdasarkan keyword
    for filename in tqdm(image_files[:num_train], desc="Splitting for training data"):
        src_path = os.path.join(input_folder, filename)
        for keyword in keywords:
            if keyword in filename:
                class_name = keyword
                break
        else:
            class_name = "other"

        dst_path = os.path.join(train_output_folder, class_name, filename)
        os.makedirs(os.path.join(train_output_folder, class_name), exist_ok=True)
        shutil.copy(src_path, dst_path)

    for filename in tqdm(image_files[num_train:], desc="Splitting for testing data"):
        src_path = os.path.join(input_folder, filename)
        for keyword in keywords:
            if keyword in filename:
                class_name = keyword
                break
        else:
            class_name = "other"

        dst_path = os.path.join(test_output_folder, class_name, filename)
        os.makedirs(os.path.join(test_output_folder, class_name), exist_ok=True)
        shutil.copy(src_path, dst_path)

    print("Proses split data selesai.")

# Splitting gambar
input_folder = "/kaggle/working/output_clahe/"
output_folder = "/kaggle/working/output_splitting/"
train_ratio = 0.7  # Rasio data training (0.7 = 70% training, 30% testing)

split_data(input_folder, output_folder, train_ratio, keywords)
# Out:
# Splitting for training data: 100%|██████████| 7956/7956 [00:01<00:00, 7710.10it/s]
# Splitting for testing data: 100%|██████████| 3410/3410 [00:00<00:00, 7767.04it/s]
# Proses split data selesai.

# %%
# # Definisikan path folder data training dan testing
# train_data_dir = '/kaggle/working/output_splitting/train/'
# test_data_dir = '/kaggle/working/output_splitting/test/'

# # Definisikan parameter untuk pelatihan model
# input_shape = (224, 224, 3)
# batch_size = 256
# epochs = 200
# num_classes = 7

# # test_datagen = ImageDataGenerator(rescale=1.0/255)

# # Buat generator data pelatihan dan pengujian tanpa augmentasi
# train_datagen = ImageDataGenerator(rescale=1.0/255)
# test_datagen = ImageDataGenerator(rescale=1.0/255)

# train_generator = train_datagen.flow_from_directory(
#     train_data_dir,
#     target_size=input_shape[:2],  # Sesuaikan dengan input_shape
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# test_generator = test_datagen.flow_from_directory(
#     test_data_dir,
#     target_size=input_shape[:2],  # Sesuaikan dengan input_shape
#     batch_size=batch_size,
#     class_mode='categorical'
# )

# # Create a VGG19 model
# vgg = VGG19(input_shape=input_shape , weights='imagenet', include_top=False)

# # # This sets the base that the layers are not trainable. If we'd want to train the layers with custom data, these two lines can be ommitted. 
# # for layer in vgg.layers:
# #   layer.trainable = False

# # Unfreeze the last three blocks (15th to 17th blocks)
# for layer in vgg.layers[:-3]:
#     layer.trainable = False

# # Create a new model on top of VGG19
# model = Sequential()
# model.add(vgg)

# # Additional Convolutional Layers
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=(2, 2)))

# # Flatten and Fully Connected Layers
# model.add(Flatten())
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
# model.add(Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# model.add(BatchNormalization())
# model.add(Dropout(0.3))
# model.add(Dense(num_classes, activation='softmax'))

# model.summary()

# # Define callbacks
# checkpoint_vgg = ModelCheckpoint('model.save', monitor='val_loss', save_best_only=True, verbose=1)
# early_stopping_vgg = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)
# log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
# # lr_scheduler = LearningRateScheduler(lr_schedule)  # Learning Rate Scheduler callback

# callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback]
# # callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback, lr_scheduler]

# #Compile the model 
# # sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
# adam_optimizer = Adam(learning_rate=0.01)
# model.compile(loss='categorical_crossentropy', optimizer=adam_optimizer, metrics=['accuracy'])
# history = model.fit(train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)

# # loss
# plt.plot(history.history['loss'], label='train loss')
# plt.plot(history.history['val_loss'], label='val loss')
# plt.legend()
# plt.show()
# plt.savefig("LossVal_loss.png")

# # accuracies
# plt.plot(history.history['accuracy'], label='train acc')
# plt.plot(history.history['val_accuracy'], label='val acc')
# plt.legend()
# plt.show()
# plt.savefig("AccVal_acc.png")

# # Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
# model = load_model('model.save')

# # Confusion Matrix and Classification Report
# Y_pred = model.predict(test_generator)
# y_pred = np.argmax(Y_pred, axis=1)
# print('Confusion Matrix')
# print(confusion_matrix(test_generator.classes, y_pred))
# print('Classification Report')
# print(classification_report(test_generator.classes, y_pred, target_names=train_generator.class_indices))

# # AUC-ROC Curve
# def plot_auc_roc_curve(model, test_generator):
#     y_true = test_generator.classes
#     y_score = model.predict(test_generator)
    
#     fpr, tpr, thresholds = roc_curve(y_true, y_score, pos_label=None)
#     auc = roc_auc_score(y_true, y_score, multi_class='ovr')
    
#     plt.figure(figsize=(8, 8))
#     plt.plot(fpr, tpr, color='darkorange', lw=2, label='AUC = {:.2f}'.format(auc))
#     plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.title('Receiver Operating Characteristic (ROC) Curve')
#     plt.legend(loc='lower right')
#     plt.show()

# plot_auc_roc_curve(model, test_generator)

# # Loss
# plt.plot(history.history['loss'], label='train loss')
# plt.plot(history.history['val_loss'], label='val loss')
# plt.legend()
# plt.show()
# plt.savefig("LossVal_loss.png")

# # Accuracies
# plt.plot(history.history['accuracy'], label='train acc')
# plt.plot(history.history['val_accuracy'], label='val acc')
# plt.legend()
# plt.show()
# plt.savefig("AccVal_acc.png")

# # # Evaluasi model pada data pelatihan
# # y_train_true = train_generator.classes
# # y_train_pred_probs = model.predict(train_generator)
# # y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# # # Confusion Matrix pada data pelatihan
# # conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)
# # plt.figure(figsize=(8, 6))
# # sns.heatmap(conf_matrix_train, annot=True, fmt='g', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
# # plt.title('Confusion Matrix (Training)')
# # plt.xlabel('Predicted')
# # plt.ylabel('True')
# # plt.show()
# # plt.savefig("Confusion_Matrix_Train.png")

# # # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix (Training)
# # accuracy_train = np.trace(conf_matrix_train) / np.sum(conf_matrix_train)
# # precision_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=0)
# # recall_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=1)
# # f1_score_train = 2 * (precision_train * recall_train) / (precision_train + recall_train)

# # # Calculate overall metrics
# # overall_precision_train = np.mean(precision_train)
# # overall_recall_train = np.mean(recall_train)
# # overall_f1_score_train = np.mean(f1_score_train)

# # # Calculate micro-average ROC-AUC
# # fpr_micro, tpr_micro, _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes).ravel(), y_train_pred_probs.ravel())
# # roc_auc_micro = auc(fpr_micro, tpr_micro)

# # # Print the overall values (Testing) including AUC-ROC
# # print('Overall Metrics (Testing):')
# # print(f'  Accuracy: {accuracy_train:.2f}')
# # print(f'  Precision: {overall_precision:.2f}')
# # print(f'  Recall: {overall_recall:.2f}')
# # print(f'  F1-Score: {overall_f1_score:.2f}')
# # print(f'  AUC-ROC: {roc_auc_micro:.2f}')

# # # AUC ROC pada data pelatihan
# # roc_auc_train_macro = roc_auc_score(to_categorical(y_train_true, num_classes=num_classes), y_train_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))

# # # Plot AUC for the macro average
# # fpr_train_macro, tpr_train_macro, _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes).ravel(), y_train_pred_probs.ravel())
# # roc_auc_train_macro = auc(fpr_train_macro, tpr_train_macro)
# # plt.plot(fpr_train_macro, tpr_train_macro, label=f'Macro (AUC = {roc_auc_train_macro:.2f})')

# # # Plot AUC for each class
# # fpr_train = dict()
# # tpr_train = dict()
# # roc_auc_train = dict()
# # for i in range(num_classes):
# #     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
# #     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])
# #     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Training)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Train.png")

# # # Print the values (Training)
# # for i, class_name in enumerate(train_generator.class_indices.keys()):
# #     print(f'Class: {class_name}')
# #     print(f'  Accuracy (Train): {accuracy_train:.2f}')
# #     print(f'  Precision (Train): {precision_train[i]:.2f}')
# #     print(f'  Recall (Train): {recall_train[i]:.2f}')
# #     print(f'  F1-Score (Train): {f1_score_train[i]:.2f}')

# # # ROC Curve and AUC pada data pelatihan
# # fpr_train = dict()
# # tpr_train = dict()
# # roc_auc_train = dict()

# # # AUC ROC pada data pelatihan
# # roc_auc_train_macro = roc_auc_score(to_categorical(y_train_true, num_classes=num_classes), y_train_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # plt.plot(fpr_train, tpr_train, label=f'Macro (AUC = {roc_auc_train_macro:.2f})')

# # for i in range(num_classes):
# #     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
# #     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # for i in range(num_classes):
# #     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Training)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Train.png")

# # # Evaluasi model pada data uji
# # y_true = test_generator.classes
# # y_pred_probs = model.predict(test_generator)
# # y_pred = np.argmax(y_pred_probs, axis=1)

# # # Confusion Matrix
# # conf_matrix = confusion_matrix(y_true, y_pred)
# # plt.figure(figsize=(8, 6))
# # sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
# # plt.title('Confusion Matrix')
# # plt.xlabel('Predicted')
# # plt.ylabel('True')
# # plt.show()
# # plt.savefig("Confusion_Matrix.png")

# # # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
# # accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
# # precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
# # recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
# # f1_score = 2 * (precision * recall) / (precision + recall)

# # # Calculate overall metrics
# # overall_precision = np.mean(precision)
# # overall_recall = np.mean(recall)
# # overall_f1_score = np.mean(f1_score)

# # # AUC-ROC
# # fpr = dict()
# # tpr = dict()
# # roc_auc = dict()

# # for i in range(num_classes):
# #     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
# #     roc_auc[i] = auc(fpr[i], tpr[i])

# # # Print the overall values (Testing) including AUC-ROC
# # print('Overall Metrics:')
# # print(f'  Accuracy: {accuracy:.2f}')
# # print(f'  Precision: {overall_precision:.2f}')
# # print(f'  Recall: {overall_recall:.2f}')
# # print(f'  F1-Score: {overall_f1_score:.2f}')
# # print(f'  AUC-ROC: {roc_auc:.2f}')

# # # Plot ROC Curve
# # plt.figure(figsize=(10, 8))
# # for i in range(num_classes):
# #     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve')
# # plt.legend()
# # plt.show()

# # # Classification Report
# # class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
# # print("Classification Report:\n", class_report)

# # # Print the values
# # for i, class_name in enumerate(test_generator.class_indices.keys()):
# #     print(f'Class: {class_name}')
# #     print(f'  Accuracy: {accuracy:.2f}')
# #     print(f'  Precision: {precision[i]:.2f}')
# #     print(f'  Recall: {recall[i]:.2f}')
# #     print(f'  F1-Score: {f1_score[i]:.2f}')

# # # ROC Curve and AUC
# # fpr = dict()
# # tpr = dict()
# # roc_auc = dict()

# # # AUC ROC pada data pelatihan
# # roc_auc_test_macro = roc_auc_score(to_categorical(y_true, num_classes=num_classes), y_pred_probs, multi_class='ovr')

# # # Plot ROC Curve pada data pelatihan
# # plt.figure(figsize=(10, 8))
# # plt.plot(fpr, tpr, label=f'Macro (AUC = {roc_auc_test_macro:.2f})')

# # # for i in range(num_classes):
# # #     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
# # #     roc_auc[i] = auc(fpr[i], tpr[i])

# # # # Plot ROC Curve
# # # plt.figure(figsize=(10, 8))
# # # for i in range(num_classes):
# # #     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# # plt.plot([0, 1], [0, 1], 'k--', label='Random')
# # plt.xlabel('False Positive Rate')
# # plt.ylabel('True Positive Rate')
# # plt.title('ROC Curve (Testing)')
# # plt.legend()
# # plt.show()
# # plt.savefig("ROC_Curve_Test.png")

# %%
# # Evaluasi model pada data pelatihan
# y_train_true = train_generator.classes
# y_train_pred_probs = model.predict(train_generator)
# y_train_pred = np.argmax(y_train_pred_probs, axis=1)

# # Confusion Matrix pada data pelatihan
# conf_matrix_train = confusion_matrix(y_train_true, y_train_pred)
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix_train, annot=True, fmt='g', cmap='Blues', xticklabels=train_generator.class_indices.keys(), yticklabels=train_generator.class_indices.keys())
# plt.title('Confusion Matrix (Training)')
# plt.xlabel('Predicted')
# plt.ylabel('True')
# plt.show()
# plt.savefig("Confusion_Matrix_Train.png")

# # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix (Training)
# accuracy_train = np.trace(conf_matrix_train) / np.sum(conf_matrix_train)
# precision_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=0)
# recall_train = np.diag(conf_matrix_train) / np.sum(conf_matrix_train, axis=1)
# f1_score_train = 2 * (precision_train * recall_train) / (precision_train + recall_train)

# # Print the values (Training)
# for i, class_name in enumerate(train_generator.class_indices.keys()):
#     print(f'Class: {class_name}')
#     print(f'  Accuracy (Train): {accuracy_train:.2f}')
#     print(f'  Precision (Train): {precision_train[i]:.2f}')
#     print(f'  Recall (Train): {recall_train[i]:.2f}')
#     print(f'  F1-Score (Train): {f1_score_train[i]:.2f}')

# # ROC Curve and AUC pada data pelatihan
# fpr_train = dict()
# tpr_train = dict()
# roc_auc_train = dict()

# for i in range(num_classes):
#     fpr_train[i], tpr_train[i], _ = roc_curve(to_categorical(y_train_true, num_classes=num_classes)[:, i], y_train_pred_probs[:, i])
#     roc_auc_train[i] = auc(fpr_train[i], tpr_train[i])

# # Plot ROC Curve pada data pelatihan
# plt.figure(figsize=(10, 8))
# for i in range(num_classes):
#     plt.plot(fpr_train[i], tpr_train[i], label=f'Class {i} (AUC = {roc_auc_train[i]:.2f})')

# plt.plot([0, 1], [0, 1], 'k--', label='Random')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve (Training)')
# plt.legend()
# plt.show()
# plt.savefig("ROC_Curve_Train.png")

# %%
# Definisikan path folder data training dan testing
train_data_dir = '/kaggle/working/output_splitting/train/'
test_data_dir = '/kaggle/working/output_splitting/test/'

# Definisikan parameter untuk pelatihan model
input_shape = (224, 224, 3)
batch_size = 256
epochs = 200
num_classes = 2

# test_datagen = ImageDataGenerator(rescale=1.0/255)

# Buat generator data pelatihan dan pengujian tanpa augmentasi
train_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=input_shape[:2],  # Sesuaikan dengan input_shape
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=input_shape[:2],  # Sesuaikan dengan input_shape
    batch_size=batch_size,
    class_mode='categorical'
)

# Create a VGG19 model
vgg = VGG19(input_shape=input_shape , weights='imagenet', include_top=False)

# # Unfreeze the last three blocks (15th to 17th blocks)
# for layer in vgg.layers[:-4]:
#     layer.trainable = False
    
# # Create a new model on top of VGG19
# model = Sequential()
# model.add(vgg)

# # Additional Convolutional Layers
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=(2, 2)))

# # Flatten and Fully Connected Layers
# model.add(Flatten())
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(num_classes, activation='softmax'))

# model.summary()  

# This sets the base that the layers are not trainable. If we'd want to train the layers with custom data, these two lines can be ommitted. 
for layer in vgg.layers:
  layer.trainable = False
    
# Stacking a new simple convolutional network on top of it    
x = Flatten()(vgg.output)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(num_classes, activation='softmax')(x)

#Creating model object 
model = Model(inputs=vgg.input, outputs=x)

model.summary()

# # Define learning rate schedule function
# def lr_schedule(epoch):
#     initial_lr = 0.01
#     drop_factor = 0.5
#     epochs_drop = 10.0
#     min_lr = 1e-5
    
#     lr = initial_lr * math.pow(drop_factor, math.floor((1 + epoch) / epochs_drop))
#     return max(lr, min_lr)

# Define callbacks
checkpoint_vgg = ModelCheckpoint('model.save', monitor='val_loss', save_best_only=True, verbose=1)
early_stopping_vgg = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
log_dir = "logs/fit_vgg/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
# lr_scheduler = LearningRateScheduler(lr_schedule)  # Learning Rate Scheduler callback

callbacks = [checkpoint_vgg, early_stopping_vgg, tensorboard_callback]

#Compile the model 
sgd_optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
# adam_optimizer = Adam(learning_rate=0.01, clipnorm=1.0)
model.compile(loss='categorical_crossentropy', optimizer=sgd_optimizer, metrics=['accuracy'])
history = model.fit(train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)

# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig("LossVal_loss.png")

# accuracies
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig("AccVal_acc.png")

# Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
model = load_model('model.save')

# Evaluasi model pada data uji
y_true = test_generator.classes
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
plt.savefig("Confusion_Matrix.png")

# Classification Report
class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
print("Classification Report:\n", class_report)

# Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
f1_score = 2 * (precision * recall) / (precision + recall)

# Print the values
for i, class_name in enumerate(test_generator.class_indices.keys()):
    print(f'Class: {class_name}')
    print(f'  Accuracy: {accuracy:.2f}')
    print(f'  Precision: {precision[i]:.2f}')
    print(f'  Recall: {recall[i]:.2f}')
    print(f'  F1-Score: {f1_score[i]:.2f}')

# ROC Curve and AUC
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC Curve
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
plt.savefig("ROC_Curve.png")
# Out:
# Found 7956 images belonging to 2 classes.
# Found 3410 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  batch_normalization (Batch  (None, 25088)             100352
#  Normalization)
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  batch_normalization_1 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 2)                 2050
#
# =================================================================
# Total params: 45822018 (174.80 MB)
# Trainable params: 25745410 (98.21 MB)
# Non-trainable params: 20076608 (76.59 MB)
# _________________________________________________________________
# Epoch 1/200
# 32/32 [==============================] - ETA: 0s - loss: 2.4355 - accuracy: 0.9001
# Epoch 1: val_loss improved from inf to 2.19178, saving model to model.save
# 32/32 [==============================] - 62s 1s/step - loss: 2.4355 - accuracy: 0.9001 - val_loss: 2.1918 - val_accuracy: 0.9067
# Epoch 2/200
# 32/32 [==============================] - ETA: 0s - loss: 2.0583 - accuracy: 0.9619
# Epoch 2: val_loss improved from 2.19178 to 2.19058, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 2.0583 - accuracy: 0.9619 - val_loss: 2.1906 - val_accuracy: 0.8768
# Epoch 3/200
# 32/32 [==============================] - ETA: 0s - loss: 1.9963 - accuracy: 0.9794
# Epoch 3: val_loss improved from 2.19058 to 2.13661, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.9963 - accuracy: 0.9794 - val_loss: 2.1366 - val_accuracy: 0.9047
# Epoch 4/200
# 32/32 [==============================] - ETA: 0s - loss: 1.9687 - accuracy: 0.9808
# Epoch 4: val_loss improved from 2.13661 to 2.11319, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.9687 - accuracy: 0.9808 - val_loss: 2.1132 - val_accuracy: 0.9047
# Epoch 5/200
# 32/32 [==============================] - ETA: 0s - loss: 1.9575 - accuracy: 0.9776
# Epoch 5: val_loss did not improve from 2.11319
# 32/32 [==============================] - 32s 1s/step - loss: 1.9575 - accuracy: 0.9776 - val_loss: 2.2507 - val_accuracy: 0.8610
# Epoch 6/200
# 32/32 [==============================] - ETA: 0s - loss: 1.9492 - accuracy: 0.9720
# Epoch 6: val_loss did not improve from 2.11319
# 32/32 [==============================] - 32s 988ms/step - loss: 1.9492 - accuracy: 0.9720 - val_loss: 2.1918 - val_accuracy: 0.8707
# Epoch 7/200
# 32/32 [==============================] - ETA: 0s - loss: 1.8994 - accuracy: 0.9829
# Epoch 7: val_loss improved from 2.11319 to 2.02353, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.8994 - accuracy: 0.9829 - val_loss: 2.0235 - val_accuracy: 0.9282
# Epoch 8/200
# 32/32 [==============================] - ETA: 0s - loss: 1.8803 - accuracy: 0.9834
# Epoch 8: val_loss improved from 2.02353 to 1.98305, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.8803 - accuracy: 0.9834 - val_loss: 1.9830 - val_accuracy: 0.9284
# Epoch 9/200
# 32/32 [==============================] - ETA: 0s - loss: 1.8473 - accuracy: 0.9877
# Epoch 9: val_loss improved from 1.98305 to 1.90057, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.8473 - accuracy: 0.9877 - val_loss: 1.9006 - val_accuracy: 0.9548
# Epoch 10/200
# 32/32 [==============================] - ETA: 0s - loss: 1.8235 - accuracy: 0.9887
# Epoch 10: val_loss improved from 1.90057 to 1.88436, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.8235 - accuracy: 0.9887 - val_loss: 1.8844 - val_accuracy: 0.9669
# Epoch 11/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7970 - accuracy: 0.9904
# Epoch 11: val_loss improved from 1.88436 to 1.86780, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.7970 - accuracy: 0.9904 - val_loss: 1.8678 - val_accuracy: 0.9710
# Epoch 12/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7784 - accuracy: 0.9898
# Epoch 12: val_loss improved from 1.86780 to 1.82058, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.7784 - accuracy: 0.9898 - val_loss: 1.8206 - val_accuracy: 0.9821
# Epoch 13/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7528 - accuracy: 0.9902
# Epoch 13: val_loss improved from 1.82058 to 1.80394, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.7528 - accuracy: 0.9902 - val_loss: 1.8039 - val_accuracy: 0.9786
# Epoch 14/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7266 - accuracy: 0.9935
# Epoch 14: val_loss did not improve from 1.80394
# 32/32 [==============================] - 31s 979ms/step - loss: 1.7266 - accuracy: 0.9935 - val_loss: 1.8887 - val_accuracy: 0.9578
# Epoch 15/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7361 - accuracy: 0.9847
# Epoch 15: val_loss improved from 1.80394 to 1.78397, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.7361 - accuracy: 0.9847 - val_loss: 1.7840 - val_accuracy: 0.9724
# Epoch 16/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7079 - accuracy: 0.9858
# Epoch 16: val_loss improved from 1.78397 to 1.76291, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.7079 - accuracy: 0.9858 - val_loss: 1.7629 - val_accuracy: 0.9815
# Epoch 17/200
# 32/32 [==============================] - ETA: 0s - loss: 1.7057 - accuracy: 0.9827
# Epoch 17: val_loss improved from 1.76291 to 1.74812, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.7057 - accuracy: 0.9827 - val_loss: 1.7481 - val_accuracy: 0.9718
# Epoch 18/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6803 - accuracy: 0.9864
# Epoch 18: val_loss did not improve from 1.74812
# 32/32 [==============================] - 32s 990ms/step - loss: 1.6803 - accuracy: 0.9864 - val_loss: 1.8342 - val_accuracy: 0.9516
# Epoch 19/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6862 - accuracy: 0.9815
# Epoch 19: val_loss did not improve from 1.74812
# 32/32 [==============================] - 32s 989ms/step - loss: 1.6862 - accuracy: 0.9815 - val_loss: 1.7482 - val_accuracy: 0.9736
# Epoch 20/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6523 - accuracy: 0.9849
# Epoch 20: val_loss did not improve from 1.74812
# 32/32 [==============================] - 32s 987ms/step - loss: 1.6523 - accuracy: 0.9849 - val_loss: 1.8645 - val_accuracy: 0.9434
# Epoch 21/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6456 - accuracy: 0.9840
# Epoch 21: val_loss improved from 1.74812 to 1.68942, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.6456 - accuracy: 0.9840 - val_loss: 1.6894 - val_accuracy: 0.9765
# Epoch 22/200
# 32/32 [==============================] - ETA: 0s - loss: 1.6119 - accuracy: 0.9881
# Epoch 22: val_loss improved from 1.68942 to 1.67620, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.6119 - accuracy: 0.9881 - val_loss: 1.6762 - val_accuracy: 0.9762
# Epoch 23/200
# 32/32 [==============================] - ETA: 0s - loss: 1.5751 - accuracy: 0.9926
# Epoch 23: val_loss improved from 1.67620 to 1.63299, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.5751 - accuracy: 0.9926 - val_loss: 1.6330 - val_accuracy: 0.9836
# Epoch 24/200
# 32/32 [==============================] - ETA: 0s - loss: 1.5557 - accuracy: 0.9922
# Epoch 24: val_loss did not improve from 1.63299
# 32/32 [==============================] - 32s 991ms/step - loss: 1.5557 - accuracy: 0.9922 - val_loss: 1.6441 - val_accuracy: 0.9789
# Epoch 25/200
# 32/32 [==============================] - ETA: 0s - loss: 1.5377 - accuracy: 0.9930
# Epoch 25: val_loss improved from 1.63299 to 1.62606, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.5377 - accuracy: 0.9930 - val_loss: 1.6261 - val_accuracy: 0.9848
# Epoch 26/200
# 32/32 [==============================] - ETA: 0s - loss: 1.5210 - accuracy: 0.9925
# Epoch 26: val_loss improved from 1.62606 to 1.58037, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.5210 - accuracy: 0.9925 - val_loss: 1.5804 - val_accuracy: 0.9833
# Epoch 27/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4959 - accuracy: 0.9935
# Epoch 27: val_loss improved from 1.58037 to 1.56929, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.4959 - accuracy: 0.9935 - val_loss: 1.5693 - val_accuracy: 0.9795
# Epoch 28/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4760 - accuracy: 0.9948
# Epoch 28: val_loss improved from 1.56929 to 1.53884, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.4760 - accuracy: 0.9948 - val_loss: 1.5388 - val_accuracy: 0.9848
# Epoch 29/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4524 - accuracy: 0.9959
# Epoch 29: val_loss improved from 1.53884 to 1.51523, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.4524 - accuracy: 0.9959 - val_loss: 1.5152 - val_accuracy: 0.9833
# Epoch 30/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4444 - accuracy: 0.9925
# Epoch 30: val_loss did not improve from 1.51523
# 32/32 [==============================] - 32s 1s/step - loss: 1.4444 - accuracy: 0.9925 - val_loss: 1.5405 - val_accuracy: 0.9801
# Epoch 31/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4268 - accuracy: 0.9942
# Epoch 31: val_loss did not improve from 1.51523
# 32/32 [==============================] - 32s 991ms/step - loss: 1.4268 - accuracy: 0.9942 - val_loss: 1.5420 - val_accuracy: 0.9848
# Epoch 32/200
# 32/32 [==============================] - ETA: 0s - loss: 1.4052 - accuracy: 0.9959
# Epoch 32: val_loss did not improve from 1.51523
# 32/32 [==============================] - 32s 999ms/step - loss: 1.4052 - accuracy: 0.9959 - val_loss: 1.5360 - val_accuracy: 0.9850
# Epoch 33/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3871 - accuracy: 0.9966
# Epoch 33: val_loss improved from 1.51523 to 1.49116, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.3871 - accuracy: 0.9966 - val_loss: 1.4912 - val_accuracy: 0.9792
# Epoch 34/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3732 - accuracy: 0.9947
# Epoch 34: val_loss improved from 1.49116 to 1.46255, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.3732 - accuracy: 0.9947 - val_loss: 1.4625 - val_accuracy: 0.9894
# Epoch 35/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3606 - accuracy: 0.9955
# Epoch 35: val_loss did not improve from 1.46255
# 32/32 [==============================] - 32s 984ms/step - loss: 1.3606 - accuracy: 0.9955 - val_loss: 1.4721 - val_accuracy: 0.9862
# Epoch 36/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3406 - accuracy: 0.9952
# Epoch 36: val_loss improved from 1.46255 to 1.43746, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.3406 - accuracy: 0.9952 - val_loss: 1.4375 - val_accuracy: 0.9806
# Epoch 37/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3241 - accuracy: 0.9950
# Epoch 37: val_loss did not improve from 1.43746
# 32/32 [==============================] - 32s 983ms/step - loss: 1.3241 - accuracy: 0.9950 - val_loss: 1.4584 - val_accuracy: 0.9818
# Epoch 38/200
# 32/32 [==============================] - ETA: 0s - loss: 1.3028 - accuracy: 0.9975
# Epoch 38: val_loss improved from 1.43746 to 1.38804, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.3028 - accuracy: 0.9975 - val_loss: 1.3880 - val_accuracy: 0.9777
# Epoch 39/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2978 - accuracy: 0.9946
# Epoch 39: val_loss did not improve from 1.38804
# 32/32 [==============================] - 32s 988ms/step - loss: 1.2978 - accuracy: 0.9946 - val_loss: 1.3939 - val_accuracy: 0.9806
# Epoch 40/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2779 - accuracy: 0.9947
# Epoch 40: val_loss improved from 1.38804 to 1.37823, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.2779 - accuracy: 0.9947 - val_loss: 1.3782 - val_accuracy: 0.9886
# Epoch 41/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2666 - accuracy: 0.9952
# Epoch 41: val_loss did not improve from 1.37823
# 32/32 [==============================] - 31s 980ms/step - loss: 1.2666 - accuracy: 0.9952 - val_loss: 1.4467 - val_accuracy: 0.9830
# Epoch 42/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2488 - accuracy: 0.9952
# Epoch 42: val_loss did not improve from 1.37823
# 32/32 [==============================] - 32s 986ms/step - loss: 1.2488 - accuracy: 0.9952 - val_loss: 1.3930 - val_accuracy: 0.9804
# Epoch 43/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2396 - accuracy: 0.9950
# Epoch 43: val_loss did not improve from 1.37823
# 32/32 [==============================] - 32s 988ms/step - loss: 1.2396 - accuracy: 0.9950 - val_loss: 1.4029 - val_accuracy: 0.9848
# Epoch 44/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2292 - accuracy: 0.9933
# Epoch 44: val_loss did not improve from 1.37823
# 32/32 [==============================] - 32s 983ms/step - loss: 1.2292 - accuracy: 0.9933 - val_loss: 1.3875 - val_accuracy: 0.9710
# Epoch 45/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2285 - accuracy: 0.9933
# Epoch 45: val_loss improved from 1.37823 to 1.34070, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.2285 - accuracy: 0.9933 - val_loss: 1.3407 - val_accuracy: 0.9827
# Epoch 46/200
# 32/32 [==============================] - ETA: 0s - loss: 1.2167 - accuracy: 0.9894
# Epoch 46: val_loss did not improve from 1.34070
# 32/32 [==============================] - 32s 983ms/step - loss: 1.2167 - accuracy: 0.9894 - val_loss: 1.3544 - val_accuracy: 0.9795
# Epoch 47/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1969 - accuracy: 0.9936
# Epoch 47: val_loss improved from 1.34070 to 1.31296, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.1969 - accuracy: 0.9936 - val_loss: 1.3130 - val_accuracy: 0.9730
# Epoch 48/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1691 - accuracy: 0.9951
# Epoch 48: val_loss improved from 1.31296 to 1.30622, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.1691 - accuracy: 0.9951 - val_loss: 1.3062 - val_accuracy: 0.9812
# Epoch 49/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1636 - accuracy: 0.9943
# Epoch 49: val_loss did not improve from 1.30622
# 32/32 [==============================] - 32s 993ms/step - loss: 1.1636 - accuracy: 0.9943 - val_loss: 1.3439 - val_accuracy: 0.9768
# Epoch 50/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1629 - accuracy: 0.9904
# Epoch 50: val_loss did not improve from 1.30622
# 32/32 [==============================] - 32s 992ms/step - loss: 1.1629 - accuracy: 0.9904 - val_loss: 1.3468 - val_accuracy: 0.9733
# Epoch 51/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1561 - accuracy: 0.9894
# Epoch 51: val_loss improved from 1.30622 to 1.25420, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.1561 - accuracy: 0.9894 - val_loss: 1.2542 - val_accuracy: 0.9815
# Epoch 52/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1301 - accuracy: 0.9927
# Epoch 52: val_loss did not improve from 1.25420
# 32/32 [==============================] - 31s 981ms/step - loss: 1.1301 - accuracy: 0.9927 - val_loss: 1.2974 - val_accuracy: 0.9868
# Epoch 53/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1319 - accuracy: 0.9906
# Epoch 53: val_loss improved from 1.25420 to 1.24084, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.1319 - accuracy: 0.9906 - val_loss: 1.2408 - val_accuracy: 0.9786
# Epoch 54/200
# 32/32 [==============================] - ETA: 0s - loss: 1.1064 - accuracy: 0.9931
# Epoch 54: val_loss improved from 1.24084 to 1.23070, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 1.1064 - accuracy: 0.9931 - val_loss: 1.2307 - val_accuracy: 0.9804
# Epoch 55/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0903 - accuracy: 0.9946
# Epoch 55: val_loss improved from 1.23070 to 1.18501, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.0903 - accuracy: 0.9946 - val_loss: 1.1850 - val_accuracy: 0.9868
# Epoch 56/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0731 - accuracy: 0.9960
# Epoch 56: val_loss did not improve from 1.18501
# 32/32 [==============================] - 32s 985ms/step - loss: 1.0731 - accuracy: 0.9960 - val_loss: 1.2085 - val_accuracy: 0.9754
# Epoch 57/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0575 - accuracy: 0.9956
# Epoch 57: val_loss improved from 1.18501 to 1.16949, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.0575 - accuracy: 0.9956 - val_loss: 1.1695 - val_accuracy: 0.9821
# Epoch 58/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0571 - accuracy: 0.9941
# Epoch 58: val_loss did not improve from 1.16949
# 32/32 [==============================] - 31s 981ms/step - loss: 1.0571 - accuracy: 0.9941 - val_loss: 1.1904 - val_accuracy: 0.9783
# Epoch 59/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0404 - accuracy: 0.9943
# Epoch 59: val_loss did not improve from 1.16949
# 32/32 [==============================] - 31s 982ms/step - loss: 1.0404 - accuracy: 0.9943 - val_loss: 1.1919 - val_accuracy: 0.9713
# Epoch 60/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0322 - accuracy: 0.9940
# Epoch 60: val_loss improved from 1.16949 to 1.11431, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.0322 - accuracy: 0.9940 - val_loss: 1.1143 - val_accuracy: 0.9874
# Epoch 61/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0302 - accuracy: 0.9917
# Epoch 61: val_loss did not improve from 1.11431
# 32/32 [==============================] - 31s 982ms/step - loss: 1.0302 - accuracy: 0.9917 - val_loss: 1.1812 - val_accuracy: 0.9604
# Epoch 62/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0084 - accuracy: 0.9959
# Epoch 62: val_loss did not improve from 1.11431
# 32/32 [==============================] - 32s 982ms/step - loss: 1.0084 - accuracy: 0.9959 - val_loss: 1.2507 - val_accuracy: 0.9584
# Epoch 63/200
# 32/32 [==============================] - ETA: 0s - loss: 1.0024 - accuracy: 0.9936
# Epoch 63: val_loss improved from 1.11431 to 1.06655, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 1.0024 - accuracy: 0.9936 - val_loss: 1.0665 - val_accuracy: 0.9865
# Epoch 64/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9974 - accuracy: 0.9907
# Epoch 64: val_loss did not improve from 1.06655
# 32/32 [==============================] - 31s 979ms/step - loss: 0.9974 - accuracy: 0.9907 - val_loss: 1.1688 - val_accuracy: 0.9792
# Epoch 65/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9714 - accuracy: 0.9952
# Epoch 65: val_loss did not improve from 1.06655
# 32/32 [==============================] - 32s 994ms/step - loss: 0.9714 - accuracy: 0.9952 - val_loss: 1.1174 - val_accuracy: 0.9777
# Epoch 66/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9590 - accuracy: 0.9966
# Epoch 66: val_loss did not improve from 1.06655
# 32/32 [==============================] - 32s 986ms/step - loss: 0.9590 - accuracy: 0.9966 - val_loss: 1.0820 - val_accuracy: 0.9768
# Epoch 67/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9456 - accuracy: 0.9975
# Epoch 67: val_loss did not improve from 1.06655
# 32/32 [==============================] - 31s 977ms/step - loss: 0.9456 - accuracy: 0.9975 - val_loss: 1.0744 - val_accuracy: 0.9812
# Epoch 68/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9398 - accuracy: 0.9965
# Epoch 68: val_loss did not improve from 1.06655
# 32/32 [==============================] - 32s 1s/step - loss: 0.9398 - accuracy: 0.9965 - val_loss: 1.1367 - val_accuracy: 0.9701
# Epoch 69/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9271 - accuracy: 0.9962
# Epoch 69: val_loss did not improve from 1.06655
# 32/32 [==============================] - 32s 989ms/step - loss: 0.9271 - accuracy: 0.9962 - val_loss: 1.0891 - val_accuracy: 0.9757
# Epoch 70/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9098 - accuracy: 0.9979
# Epoch 70: val_loss did not improve from 1.06655
# 32/32 [==============================] - 32s 985ms/step - loss: 0.9098 - accuracy: 0.9979 - val_loss: 1.0672 - val_accuracy: 0.9798
# Epoch 71/200
# 32/32 [==============================] - ETA: 0s - loss: 0.9033 - accuracy: 0.9975
# Epoch 71: val_loss did not improve from 1.06655
# 32/32 [==============================] - 32s 996ms/step - loss: 0.9033 - accuracy: 0.9975 - val_loss: 1.0678 - val_accuracy: 0.9848
# Epoch 72/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8943 - accuracy: 0.9964
# Epoch 72: val_loss improved from 1.06655 to 1.02058, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.8943 - accuracy: 0.9964 - val_loss: 1.0206 - val_accuracy: 0.9853
# Epoch 73/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8796 - accuracy: 0.9974
# Epoch 73: val_loss did not improve from 1.02058
# 32/32 [==============================] - 32s 985ms/step - loss: 0.8796 - accuracy: 0.9974 - val_loss: 1.0224 - val_accuracy: 0.9798
# Epoch 74/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8701 - accuracy: 0.9970
# Epoch 74: val_loss did not improve from 1.02058
# 32/32 [==============================] - 32s 995ms/step - loss: 0.8701 - accuracy: 0.9970 - val_loss: 1.0449 - val_accuracy: 0.9804
# Epoch 75/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8597 - accuracy: 0.9970
# Epoch 75: val_loss did not improve from 1.02058
# 32/32 [==============================] - 32s 985ms/step - loss: 0.8597 - accuracy: 0.9970 - val_loss: 1.0484 - val_accuracy: 0.9765
# Epoch 76/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8508 - accuracy: 0.9977
# Epoch 76: val_loss did not improve from 1.02058
# 32/32 [==============================] - 32s 990ms/step - loss: 0.8508 - accuracy: 0.9977 - val_loss: 1.0429 - val_accuracy: 0.9777
# Epoch 77/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8553 - accuracy: 0.9938
# Epoch 77: val_loss improved from 1.02058 to 0.99737, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.8553 - accuracy: 0.9938 - val_loss: 0.9974 - val_accuracy: 0.9848
# Epoch 78/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8374 - accuracy: 0.9960
# Epoch 78: val_loss improved from 0.99737 to 0.96758, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.8374 - accuracy: 0.9960 - val_loss: 0.9676 - val_accuracy: 0.9827
# Epoch 79/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8222 - accuracy: 0.9967
# Epoch 79: val_loss did not improve from 0.96758
# 32/32 [==============================] - 31s 980ms/step - loss: 0.8222 - accuracy: 0.9967 - val_loss: 0.9802 - val_accuracy: 0.9771
# Epoch 80/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8144 - accuracy: 0.9977
# Epoch 80: val_loss did not improve from 0.96758
# 32/32 [==============================] - 32s 985ms/step - loss: 0.8144 - accuracy: 0.9977 - val_loss: 0.9913 - val_accuracy: 0.9821
# Epoch 81/200
# 32/32 [==============================] - ETA: 0s - loss: 0.8120 - accuracy: 0.9957
# Epoch 81: val_loss improved from 0.96758 to 0.94211, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.8120 - accuracy: 0.9957 - val_loss: 0.9421 - val_accuracy: 0.9853
# Epoch 82/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7912 - accuracy: 0.9976
# Epoch 82: val_loss improved from 0.94211 to 0.91852, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.7912 - accuracy: 0.9976 - val_loss: 0.9185 - val_accuracy: 0.9850
# Epoch 83/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7850 - accuracy: 0.9982
# Epoch 83: val_loss did not improve from 0.91852
# 32/32 [==============================] - 32s 984ms/step - loss: 0.7850 - accuracy: 0.9982 - val_loss: 0.9252 - val_accuracy: 0.9815
# Epoch 84/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7748 - accuracy: 0.9976
# Epoch 84: val_loss improved from 0.91852 to 0.88345, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.7748 - accuracy: 0.9976 - val_loss: 0.8835 - val_accuracy: 0.9865
# Epoch 85/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7647 - accuracy: 0.9986
# Epoch 85: val_loss did not improve from 0.88345
# 32/32 [==============================] - 32s 1s/step - loss: 0.7647 - accuracy: 0.9986 - val_loss: 0.9056 - val_accuracy: 0.9818
# Epoch 86/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7557 - accuracy: 0.9984
# Epoch 86: val_loss did not improve from 0.88345
# 32/32 [==============================] - 32s 991ms/step - loss: 0.7557 - accuracy: 0.9984 - val_loss: 0.9624 - val_accuracy: 0.9801
# Epoch 87/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7504 - accuracy: 0.9966
# Epoch 87: val_loss did not improve from 0.88345
# 32/32 [==============================] - 32s 1s/step - loss: 0.7504 - accuracy: 0.9966 - val_loss: 0.9089 - val_accuracy: 0.9833
# Epoch 88/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7442 - accuracy: 0.9965
# Epoch 88: val_loss did not improve from 0.88345
# 32/32 [==============================] - 32s 999ms/step - loss: 0.7442 - accuracy: 0.9965 - val_loss: 0.9023 - val_accuracy: 0.9795
# Epoch 89/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7340 - accuracy: 0.9971
# Epoch 89: val_loss did not improve from 0.88345
# 32/32 [==============================] - 32s 997ms/step - loss: 0.7340 - accuracy: 0.9971 - val_loss: 0.9296 - val_accuracy: 0.9824
# Epoch 90/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7269 - accuracy: 0.9974
# Epoch 90: val_loss did not improve from 0.88345
# 32/32 [==============================] - 32s 995ms/step - loss: 0.7269 - accuracy: 0.9974 - val_loss: 0.8926 - val_accuracy: 0.9818
# Epoch 91/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7212 - accuracy: 0.9950
# Epoch 91: val_loss did not improve from 0.88345
# 32/32 [==============================] - 32s 996ms/step - loss: 0.7212 - accuracy: 0.9950 - val_loss: 0.8906 - val_accuracy: 0.9830
# Epoch 92/200
# 32/32 [==============================] - ETA: 0s - loss: 0.7059 - accuracy: 0.9984
# Epoch 92: val_loss improved from 0.88345 to 0.85075, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.7059 - accuracy: 0.9984 - val_loss: 0.8508 - val_accuracy: 0.9845
# Epoch 93/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6998 - accuracy: 0.9975
# Epoch 93: val_loss improved from 0.85075 to 0.84237, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6998 - accuracy: 0.9975 - val_loss: 0.8424 - val_accuracy: 0.9842
# Epoch 94/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6932 - accuracy: 0.9974
# Epoch 94: val_loss did not improve from 0.84237
# 32/32 [==============================] - 32s 992ms/step - loss: 0.6932 - accuracy: 0.9974 - val_loss: 0.8639 - val_accuracy: 0.9845
# Epoch 95/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6843 - accuracy: 0.9969
# Epoch 95: val_loss improved from 0.84237 to 0.82193, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6843 - accuracy: 0.9969 - val_loss: 0.8219 - val_accuracy: 0.9859
# Epoch 96/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6769 - accuracy: 0.9977
# Epoch 96: val_loss improved from 0.82193 to 0.74785, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6769 - accuracy: 0.9977 - val_loss: 0.7479 - val_accuracy: 0.9889
# Epoch 97/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6683 - accuracy: 0.9974
# Epoch 97: val_loss improved from 0.74785 to 0.74353, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6683 - accuracy: 0.9974 - val_loss: 0.7435 - val_accuracy: 0.9868
# Epoch 98/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6596 - accuracy: 0.9971
# Epoch 98: val_loss did not improve from 0.74353
# 32/32 [==============================] - 32s 990ms/step - loss: 0.6596 - accuracy: 0.9971 - val_loss: 0.7712 - val_accuracy: 0.9853
# Epoch 99/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6543 - accuracy: 0.9970
# Epoch 99: val_loss improved from 0.74353 to 0.73955, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6543 - accuracy: 0.9970 - val_loss: 0.7396 - val_accuracy: 0.9871
# Epoch 100/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6444 - accuracy: 0.9972
# Epoch 100: val_loss did not improve from 0.73955
# 32/32 [==============================] - 31s 981ms/step - loss: 0.6444 - accuracy: 0.9972 - val_loss: 0.7516 - val_accuracy: 0.9842
# Epoch 101/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6533 - accuracy: 0.9950
# Epoch 101: val_loss did not improve from 0.73955
# 32/32 [==============================] - 32s 1s/step - loss: 0.6533 - accuracy: 0.9950 - val_loss: 0.8355 - val_accuracy: 0.9727
# Epoch 102/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6440 - accuracy: 0.9951
# Epoch 102: val_loss did not improve from 0.73955
# 32/32 [==============================] - 32s 982ms/step - loss: 0.6440 - accuracy: 0.9951 - val_loss: 0.7683 - val_accuracy: 0.9804
# Epoch 103/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6229 - accuracy: 0.9979
# Epoch 103: val_loss improved from 0.73955 to 0.73505, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6229 - accuracy: 0.9979 - val_loss: 0.7351 - val_accuracy: 0.9868
# Epoch 104/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6243 - accuracy: 0.9959
# Epoch 104: val_loss improved from 0.73505 to 0.69170, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.6243 - accuracy: 0.9959 - val_loss: 0.6917 - val_accuracy: 0.9891
# Epoch 105/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6141 - accuracy: 0.9976
# Epoch 105: val_loss did not improve from 0.69170
# 32/32 [==============================] - 32s 1s/step - loss: 0.6141 - accuracy: 0.9976 - val_loss: 0.7359 - val_accuracy: 0.9891
# Epoch 106/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6069 - accuracy: 0.9972
# Epoch 106: val_loss did not improve from 0.69170
# 32/32 [==============================] - 32s 1s/step - loss: 0.6069 - accuracy: 0.9972 - val_loss: 0.7358 - val_accuracy: 0.9853
# Epoch 107/200
# 32/32 [==============================] - ETA: 0s - loss: 0.6014 - accuracy: 0.9967
# Epoch 107: val_loss did not improve from 0.69170
# 32/32 [==============================] - 32s 998ms/step - loss: 0.6014 - accuracy: 0.9967 - val_loss: 0.6993 - val_accuracy: 0.9868
# Epoch 108/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5911 - accuracy: 0.9984
# Epoch 108: val_loss did not improve from 0.69170
# 32/32 [==============================] - 32s 1s/step - loss: 0.5911 - accuracy: 0.9984 - val_loss: 0.6961 - val_accuracy: 0.9865
# Epoch 109/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5859 - accuracy: 0.9980
# Epoch 109: val_loss improved from 0.69170 to 0.68063, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.5859 - accuracy: 0.9980 - val_loss: 0.6806 - val_accuracy: 0.9824
# Epoch 110/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5777 - accuracy: 0.9979
# Epoch 110: val_loss improved from 0.68063 to 0.66120, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.5777 - accuracy: 0.9979 - val_loss: 0.6612 - val_accuracy: 0.9856
# Epoch 111/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5736 - accuracy: 0.9967
# Epoch 111: val_loss did not improve from 0.66120
# 32/32 [==============================] - 32s 990ms/step - loss: 0.5736 - accuracy: 0.9967 - val_loss: 0.6806 - val_accuracy: 0.9848
# Epoch 112/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5678 - accuracy: 0.9962
# Epoch 112: val_loss did not improve from 0.66120
# 32/32 [==============================] - 32s 990ms/step - loss: 0.5678 - accuracy: 0.9962 - val_loss: 0.6837 - val_accuracy: 0.9830
# Epoch 113/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5609 - accuracy: 0.9971
# Epoch 113: val_loss improved from 0.66120 to 0.66043, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.5609 - accuracy: 0.9971 - val_loss: 0.6604 - val_accuracy: 0.9848
# Epoch 114/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5608 - accuracy: 0.9966
# Epoch 114: val_loss did not improve from 0.66043
# 32/32 [==============================] - 31s 983ms/step - loss: 0.5608 - accuracy: 0.9966 - val_loss: 0.7211 - val_accuracy: 0.9845
# Epoch 115/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5504 - accuracy: 0.9976
# Epoch 115: val_loss did not improve from 0.66043
# 32/32 [==============================] - 32s 992ms/step - loss: 0.5504 - accuracy: 0.9976 - val_loss: 0.6925 - val_accuracy: 0.9812
# Epoch 116/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5410 - accuracy: 0.9974
# Epoch 116: val_loss did not improve from 0.66043
# 32/32 [==============================] - 32s 991ms/step - loss: 0.5410 - accuracy: 0.9974 - val_loss: 0.6810 - val_accuracy: 0.9818
# Epoch 117/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5390 - accuracy: 0.9969
# Epoch 117: val_loss did not improve from 0.66043
# 32/32 [==============================] - 32s 989ms/step - loss: 0.5390 - accuracy: 0.9969 - val_loss: 0.6918 - val_accuracy: 0.9707
# Epoch 118/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5421 - accuracy: 0.9952
# Epoch 118: val_loss did not improve from 0.66043
# 32/32 [==============================] - 32s 997ms/step - loss: 0.5421 - accuracy: 0.9952 - val_loss: 0.6734 - val_accuracy: 0.9850
# Epoch 119/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5389 - accuracy: 0.9945
# Epoch 119: val_loss improved from 0.66043 to 0.65747, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.5389 - accuracy: 0.9945 - val_loss: 0.6575 - val_accuracy: 0.9874
# Epoch 120/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5258 - accuracy: 0.9977
# Epoch 120: val_loss did not improve from 0.65747
# 32/32 [==============================] - 32s 984ms/step - loss: 0.5258 - accuracy: 0.9977 - val_loss: 0.6729 - val_accuracy: 0.9806
# Epoch 121/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5162 - accuracy: 0.9977
# Epoch 121: val_loss did not improve from 0.65747
# 32/32 [==============================] - 32s 987ms/step - loss: 0.5162 - accuracy: 0.9977 - val_loss: 0.6661 - val_accuracy: 0.9842
# Epoch 122/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5180 - accuracy: 0.9967
# Epoch 122: val_loss did not improve from 0.65747
# 32/32 [==============================] - 32s 985ms/step - loss: 0.5180 - accuracy: 0.9967 - val_loss: 0.6690 - val_accuracy: 0.9848
# Epoch 123/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5059 - accuracy: 0.9976
# Epoch 123: val_loss did not improve from 0.65747
# 32/32 [==============================] - 32s 986ms/step - loss: 0.5059 - accuracy: 0.9976 - val_loss: 0.6599 - val_accuracy: 0.9821
# Epoch 124/200
# 32/32 [==============================] - ETA: 0s - loss: 0.5040 - accuracy: 0.9970
# Epoch 124: val_loss did not improve from 0.65747
# 32/32 [==============================] - 32s 989ms/step - loss: 0.5040 - accuracy: 0.9970 - val_loss: 0.6750 - val_accuracy: 0.9868
# Epoch 125/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4961 - accuracy: 0.9976
# Epoch 125: val_loss improved from 0.65747 to 0.62892, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4961 - accuracy: 0.9976 - val_loss: 0.6289 - val_accuracy: 0.9830
# Epoch 126/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4908 - accuracy: 0.9975
# Epoch 126: val_loss improved from 0.62892 to 0.60824, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4908 - accuracy: 0.9975 - val_loss: 0.6082 - val_accuracy: 0.9839
# Epoch 127/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4850 - accuracy: 0.9977
# Epoch 127: val_loss did not improve from 0.60824
# 32/32 [==============================] - 32s 988ms/step - loss: 0.4850 - accuracy: 0.9977 - val_loss: 0.6352 - val_accuracy: 0.9821
# Epoch 128/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4769 - accuracy: 0.9979
# Epoch 128: val_loss improved from 0.60824 to 0.60671, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4769 - accuracy: 0.9979 - val_loss: 0.6067 - val_accuracy: 0.9845
# Epoch 129/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4754 - accuracy: 0.9977
# Epoch 129: val_loss improved from 0.60671 to 0.56941, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4754 - accuracy: 0.9977 - val_loss: 0.5694 - val_accuracy: 0.9801
# Epoch 130/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4908 - accuracy: 0.9933
# Epoch 130: val_loss did not improve from 0.56941
# 32/32 [==============================] - 32s 987ms/step - loss: 0.4908 - accuracy: 0.9933 - val_loss: 0.6390 - val_accuracy: 0.9845
# Epoch 131/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4666 - accuracy: 0.9976
# Epoch 131: val_loss did not improve from 0.56941
# 32/32 [==============================] - 32s 993ms/step - loss: 0.4666 - accuracy: 0.9976 - val_loss: 0.6301 - val_accuracy: 0.9853
# Epoch 132/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4775 - accuracy: 0.9945
# Epoch 132: val_loss did not improve from 0.56941
# 32/32 [==============================] - 32s 989ms/step - loss: 0.4775 - accuracy: 0.9945 - val_loss: 0.6678 - val_accuracy: 0.9751
# Epoch 133/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4669 - accuracy: 0.9943
# Epoch 133: val_loss did not improve from 0.56941
# 32/32 [==============================] - 32s 998ms/step - loss: 0.4669 - accuracy: 0.9943 - val_loss: 0.6165 - val_accuracy: 0.9821
# Epoch 134/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4543 - accuracy: 0.9971
# Epoch 134: val_loss improved from 0.56941 to 0.56758, saving model to model.save
# 32/32 [==============================] - 34s 1s/step - loss: 0.4543 - accuracy: 0.9971 - val_loss: 0.5676 - val_accuracy: 0.9830
# Epoch 135/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4464 - accuracy: 0.9974
# Epoch 135: val_loss did not improve from 0.56758
# 32/32 [==============================] - 32s 983ms/step - loss: 0.4464 - accuracy: 0.9974 - val_loss: 0.6222 - val_accuracy: 0.9815
# Epoch 136/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4463 - accuracy: 0.9967
# Epoch 136: val_loss improved from 0.56758 to 0.54066, saving model to model.save
# 32/32 [==============================] - 36s 1s/step - loss: 0.4463 - accuracy: 0.9967 - val_loss: 0.5407 - val_accuracy: 0.9862
# Epoch 137/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4416 - accuracy: 0.9962
# Epoch 137: val_loss did not improve from 0.54066
# 32/32 [==============================] - 33s 1s/step - loss: 0.4416 - accuracy: 0.9962 - val_loss: 0.6388 - val_accuracy: 0.9824
# Epoch 138/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4366 - accuracy: 0.9974
# Epoch 138: val_loss did not improve from 0.54066
# 32/32 [==============================] - 32s 985ms/step - loss: 0.4366 - accuracy: 0.9974 - val_loss: 0.5502 - val_accuracy: 0.9848
# Epoch 139/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4296 - accuracy: 0.9974
# Epoch 139: val_loss improved from 0.54066 to 0.52654, saving model to model.save
# 32/32 [==============================] - 35s 1s/step - loss: 0.4296 - accuracy: 0.9974 - val_loss: 0.5265 - val_accuracy: 0.9836
# Epoch 140/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.9982
# Epoch 140: val_loss did not improve from 0.52654
# 32/32 [==============================] - 31s 979ms/step - loss: 0.4265 - accuracy: 0.9982 - val_loss: 0.5341 - val_accuracy: 0.9839
# Epoch 141/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4207 - accuracy: 0.9975
# Epoch 141: val_loss did not improve from 0.52654
# 32/32 [==============================] - 32s 1s/step - loss: 0.4207 - accuracy: 0.9975 - val_loss: 0.5902 - val_accuracy: 0.9862
# Epoch 142/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4157 - accuracy: 0.9981
# Epoch 142: val_loss did not improve from 0.52654
# 32/32 [==============================] - 31s 978ms/step - loss: 0.4157 - accuracy: 0.9981 - val_loss: 0.5440 - val_accuracy: 0.9815
# Epoch 143/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4155 - accuracy: 0.9971
# Epoch 143: val_loss did not improve from 0.52654
# 32/32 [==============================] - 32s 989ms/step - loss: 0.4155 - accuracy: 0.9971 - val_loss: 0.5888 - val_accuracy: 0.9821
# Epoch 144/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4130 - accuracy: 0.9975
# Epoch 144: val_loss did not improve from 0.52654
# 32/32 [==============================] - 31s 977ms/step - loss: 0.4130 - accuracy: 0.9975 - val_loss: 0.5816 - val_accuracy: 0.9824
# Epoch 145/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4081 - accuracy: 0.9966
# Epoch 145: val_loss did not improve from 0.52654
# 32/32 [==============================] - 32s 983ms/step - loss: 0.4081 - accuracy: 0.9966 - val_loss: 0.5557 - val_accuracy: 0.9818
# Epoch 146/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4124 - accuracy: 0.9956
# Epoch 146: val_loss did not improve from 0.52654
# 32/32 [==============================] - 32s 992ms/step - loss: 0.4124 - accuracy: 0.9956 - val_loss: 0.6274 - val_accuracy: 0.9783
# Epoch 147/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4078 - accuracy: 0.9947
# Epoch 147: val_loss did not improve from 0.52654
# 32/32 [==============================] - 32s 993ms/step - loss: 0.4078 - accuracy: 0.9947 - val_loss: 0.5612 - val_accuracy: 0.9809
# Epoch 148/200
# 32/32 [==============================] - ETA: 0s - loss: 0.4051 - accuracy: 0.9961
# Epoch 148: val_loss did not improve from 0.52654
# 32/32 [==============================] - 32s 984ms/step - loss: 0.4051 - accuracy: 0.9961 - val_loss: 0.5465 - val_accuracy: 0.9815
# Epoch 149/200
# 32/32 [==============================] - ETA: 0s - loss: 0.3947 - accuracy: 0.9972
# Epoch 149: val_loss did not improve from 0.52654
# Restoring model weights from the end of the best epoch: 139.
# 32/32 [==============================] - 32s 995ms/step - loss: 0.3947 - accuracy: 0.9972 - val_loss: 0.5428 - val_accuracy: 0.9789
# Epoch 149: early stopping
# 14/14 [==============================] - 8s 530ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#     cataract       0.50      0.50      0.50      1664
#       normal       0.52      0.52      0.52      1746
#
#     accuracy                           0.51      3410
#    macro avg       0.51      0.51      0.51      3410
# weighted avg       0.51      0.51      0.51      3410
#
# Class: cataract
#   Accuracy: 0.51
#   Precision: 0.50
#   Recall: 0.50
#   F1-Score: 0.50
# Class: normal
#   Accuracy: 0.51
#   Precision: 0.52
#   Recall: 0.52
#   F1-Score: 0.52

# %%
# # Load best model (model dengan val_accuracy terbaik) jika menggunakan ModelCheckpoint
# model = load_model('model.save')

# # Evaluasi model pada data uji
# y_true = test_generator.classes
# y_pred_probs = model.predict(test_generator)
# y_pred = np.argmax(y_pred_probs, axis=1)

# # Confusion Matrix
# conf_matrix = confusion_matrix(y_true, y_pred)
# plt.figure(figsize=(8, 6))
# sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
# plt.title('Confusion Matrix')
# plt.xlabel('Predicted')
# plt.ylabel('True')
# plt.show()
# plt.savefig("Confusion_Matrix.png")

# # Classification Report
# class_report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
# print("Classification Report:\n", class_report)

# # Calculate Accuracy, Precision, Recall, and F1-score from Confusion Matrix
# accuracy = np.trace(conf_matrix) / np.sum(conf_matrix)
# precision = np.diag(conf_matrix) / np.sum(conf_matrix, axis=0)
# recall = np.diag(conf_matrix) / np.sum(conf_matrix, axis=1)
# f1_score = 2 * (precision * recall) / (precision + recall)

# # Print the values
# for i, class_name in enumerate(test_generator.class_indices.keys()):
#     print(f'Class: {class_name}')
#     print(f'  Accuracy: {accuracy:.2f}')
#     print(f'  Precision: {precision[i]:.2f}')
#     print(f'  Recall: {recall[i]:.2f}')
#     print(f'  F1-Score: {f1_score[i]:.2f}')

# # ROC Curve and AUC
# fpr = dict()
# tpr = dict()
# roc_auc = dict()

# for i in range(num_classes):
#     fpr[i], tpr[i], _ = roc_curve(to_categorical(y_true, num_classes=num_classes)[:, i], y_pred_probs[:, i])
#     roc_auc[i] = auc(fpr[i], tpr[i])

# # Plot ROC Curve
# plt.figure(figsize=(10, 8))
# for i in range(num_classes):
#     plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

# plt.plot([0, 1], [0, 1], 'k--', label='Random')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve')
# plt.legend()
# plt.show()
# plt.savefig("ROC_Curve.png")

# %%
# import zipfile
# import os
# from IPython.display import FileLink

# def zip_dir(directory = os.curdir, file_name = 'directory.zip'):
#     os.chdir(directory)
#     zip_ref = zipfile.ZipFile(file_name, mode='w')
#     for folder, _, files in os.walk(directory):
#         for file in files:
#             if file_name in file:
#                 pass
#             else:
#                 zip_ref.write(os.path.join(folder, file))

#     return FileLink(file_name)

# zip_dir()
